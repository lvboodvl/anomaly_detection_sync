# %% [markdown]
# Deep Learning Models -- A collection of various deep learning architectures, models, and tips for TensorFlow and PyTorch in Jupyter Notebooks.
# - Author: Sebastian Raschka
# - GitHub Repository: https://github.com/rasbt/deeplearning-models

# %%
# %load_ext watermark
# %watermark -a 'Sebastian Raschka' -v -p torch
# Out:
# Sebastian Raschka
#
# CPython 3.5.2
# IPython 7.3.0
#
# torch 1.0.1.post2

# %% [markdown]
# - Runs on CPU or GPU (if available)

# %% [markdown]
# # Model Zoo -- Convolutional Conditional Variational Autoencoder
#
# ## (with labels in reconstruction loss)

# %% [markdown]
# A simple convolutional conditional variational autoencoder that compresses 768-pixel MNIST images down to a 50-pixel latent vector representation.
#
# This implementation concatenates the inputs with the class labels when computing the reconstruction loss as it is commonly done in non-convolutional conditional variational autoencoders. This leads to substantially poorer results compared to the implementation that does NOT concatenate the labels with the inputs to compute the reconstruction loss. For reference, see the implementation [./autoencoder-cnn-cvae_no-out-concat.ipynb](./autoencoder-cnn-cvae_no-out-concat.ipynb)

# %% [markdown]
# ## Imports

# %%
import time
import numpy as np
import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision import transforms


if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %%
##########################
### SETTINGS
##########################

# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('Device:', device)

# Hyperparameters
random_seed = 13456
learning_rate = 1e-4
num_epochs = 1000
batch_size = 256

# Architecture
num_classes = 2
num_features = 784
num_latent = 20
# Out:
# Device: cuda:0

# %%
# load dataset and cut it into train val part and shuffle them
data = np.loadtxt('sync_detection_data.txt')
label = np.loadtxt('sync_detection_label.txt')
N, D = np.shape(data)
label_int = np.zeros((N),dtype=int)
for k in range(N):
    label_int[k] = int(label[k])

ratio_train = 0.7
ind_cut = int(ratio_train * N)
ind = np.random.permutation(N)
train_data = data[ind[:ind_cut]]
train_datas = train_data[:256*40]
val_data = data[ind[ind_cut:]]

train_label = label[ind[:ind_cut]]
train_labels = train_label[:256*40]
val_label = label[ind[ind_cut:]]
np.shape(train_datas)
# Out:
# (10240, 784)

# %%
mean = np.mean(train_datas)
var = np.var(train_datas)
print('mean:')
print(mean)
print('sigma:')
sigma = np.sqrt(var)
print(sigma)
# preprocessing is so important
def data_in_one(inputdata):
    inputdata = (inputdata-inputdata.min())/(inputdata.max()-inputdata.min())
#    inputdata = 2.0 * inputdata - 1.0
    return inputdata

train_datas_process = data_in_one(train_data)
mean = np.mean(train_datas_process)
train_datas_process = train_datas_process
var = np.var(train_datas_process)
print('mean:')
print(mean)
print('sigma:')
sigma = np.sqrt(var)
print(sigma)
# Out:
# mean:
# -4.070974715805149
# sigma:
# 11.340051647575134
# mean:
# 0.5097777235025349
# sigma:
# 0.07382945753203313

# %% [markdown]
# ## Model

# %%
##########################
### MODEL
##########################


def to_onehot(labels, num_classes, device):

    labels_onehot = torch.zeros(labels.size()[0], num_classes).to(device)
    labels_onehot.scatter_(1, labels.view(-1, 1), 1)

    return labels_onehot


class ConditionalVariationalAutoencoder(torch.nn.Module):

    def __init__(self, num_features, num_latent, num_classes):
        super(ConditionalVariationalAutoencoder, self).__init__()
        
        self.num_classes = num_classes
        
        
        ###############
        # ENCODER
        ##############
        
        # calculate same padding:
        # (w - k + 2*p)/s + 1 = o
        # => p = (s(o-1) - w + k)/2

        self.enc_conv_1 = torch.nn.Conv2d(in_channels=1+self.num_classes,
                                          out_channels=16,
                                          kernel_size=(6, 6),
                                          stride=(2, 2),
                                          padding=0)

        self.enc_conv_2 = torch.nn.Conv2d(in_channels=16,
                                          out_channels=32,
                                          kernel_size=(4, 4),
                                          stride=(2, 2),
                                          padding=0)                 
        
        self.enc_conv_3 = torch.nn.Conv2d(in_channels=32,
                                          out_channels=64,
                                          kernel_size=(2, 2),
                                          stride=(2, 2),
                                          padding=0)                     
        
        self.z_mean = torch.nn.Linear(64*2*2, num_latent)
        # in the original paper (Kingma & Welling 2015, we use
        # have a z_mean and z_var, but the problem is that
        # the z_var can be negative, which would cause issues
        # in the log later. Hence we assume that latent vector
        # has a z_mean and z_log_var component, and when we need
        # the regular variance or std_dev, we simply use 
        # an exponential function
        self.z_log_var = torch.nn.Linear(64*2*2, num_latent)
        
        
        
        ###############
        # DECODER
        ##############
        
        self.dec_linear_1 = torch.nn.Linear(num_latent+self.num_classes, 64*2*2)
               
        self.dec_deconv_1 = torch.nn.ConvTranspose2d(in_channels=64,
                                                     out_channels=32,
                                                     kernel_size=(2, 2),
                                                     stride=(2, 2),
                                                     padding=0)
                                 
        self.dec_deconv_2 = torch.nn.ConvTranspose2d(in_channels=32,
                                                     out_channels=16,
                                                     kernel_size=(4, 4),
                                                     stride=(3, 3),
                                                     padding=1)
        
        self.dec_deconv_3 = torch.nn.ConvTranspose2d(in_channels=16,
                                                     out_channels=1+self.num_classes,
                                                     kernel_size=(6, 6),
                                                     stride=(3, 3),
                                                     padding=4)        


    def reparameterize(self, z_mu, z_log_var):
        # Sample epsilon from standard normal distribution
        eps = torch.randn(z_mu.size(0), z_mu.size(1)).to(device)
        # note that log(x^2) = 2*log(x); hence divide by 2 to get std_dev
        # i.e., std_dev = exp(log(std_dev^2)/2) = exp(log(var)/2)
        z = z_mu + eps * torch.exp(z_log_var/2.) 
        return z
        
    def encoder(self, features, targets):
        
        ### Add condition
        onehot_targets = to_onehot(targets, self.num_classes, device)
        onehot_targets = onehot_targets.view(-1, self.num_classes, 1, 1)
        
        ones = torch.ones(features.size()[0], 
                          self.num_classes,
                          features.size()[2], 
                          features.size()[3], 
                          dtype=features.dtype).to(device)
        ones = ones * onehot_targets
        x = torch.cat((features, ones), dim=1)
        
        x = self.enc_conv_1(x)
        x = F.leaky_relu(x)
        #print('conv1 out:', x.size())
        
        x = self.enc_conv_2(x)
        x = F.leaky_relu(x)
        #print('conv2 out:', x.size())
        
        x = self.enc_conv_3(x)
        x = F.leaky_relu(x)
        #print('conv3 out:', x.size())
        
        z_mean = self.z_mean(x.view(-1, 64*2*2))
        z_log_var = self.z_log_var(x.view(-1, 64*2*2))
        encoded = self.reparameterize(z_mean, z_log_var)
        return z_mean, z_log_var, encoded
    
    def decoder(self, encoded, targets):
        ### Add condition
        onehot_targets = to_onehot(targets, self.num_classes, device)
        encoded = torch.cat((encoded, onehot_targets), dim=1)        
        
        x = self.dec_linear_1(encoded)
        x = x.view(-1, 64, 2, 2)
        
        x = self.dec_deconv_1(x)
        x = F.leaky_relu(x)
        #print('deconv1 out:', x.size())
        
        x = self.dec_deconv_2(x)
        x = F.leaky_relu(x)
        #print('deconv2 out:', x.size())
        
        x = self.dec_deconv_3(x)
        x = F.leaky_relu(x)
        #print('deconv1 out:', x.size())
        
        decoded = torch.sigmoid(x)
        return decoded

    def forward(self, features, targets):
        
        z_mean, z_log_var, encoded = self.encoder(features, targets)
        decoded = self.decoder(encoded, targets)
        
        return z_mean, z_log_var, encoded, decoded

    
torch.manual_seed(random_seed)
model = ConditionalVariationalAutoencoder(num_features,
                                          num_latent,
                                          num_classes)
model = model.to(device)
    

##########################
### COST AND OPTIMIZER
##########################

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ## Training

# %%
resume_flag = False
if (resume_flag==True):
    checkpoint = torch.load(dir_name)
    model.load_state_dict(checkpoint['net'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    start_epoch = checkpoint['epoch'] + 1
else:    
    start_epoch = 0

start_time = time.time()

iters = int(256*40/batch_size)

for epoch in range(start_epoch,num_epochs):
    for batch_idx in range(iters):
        features = train_datas_process[batch_idx*batch_size:(batch_idx+1)*batch_size]
        targets = train_labels[batch_idx*batch_size:(batch_idx+1)*batch_size]
        targets = np.transpose(targets)
        features = torch.from_numpy(features)
        targets = torch.from_numpy(targets)
        features = features.to(device,torch.float32)
        features = features.view(batch_size,-1,28,28)
        targets = targets.to(device,dtype=torch.int64)

        ### FORWARD AND BACK PROP
        z_mean, z_log_var, encoded, decoded = model(features, targets)

        # cost = reconstruction loss + Kullback-Leibler divergence
        kl_divergence = (0.5 * (z_mean**2 + 
                                torch.exp(z_log_var) - z_log_var - 1)).sum()
        
        
        ### Add condition
        onehot_targets = to_onehot(targets, num_classes, device)
        onehot_targets = onehot_targets.view(-1, num_classes, 1, 1)
        
        ones = torch.ones(features.size()[0], 
                          num_classes,
                          features.size()[2], 
                          features.size()[3], 
                          dtype=features.dtype).to(device)
        ones = ones * onehot_targets
        x_con = torch.cat((features, ones), dim=1)
        
        
        ### Compute loss
        pixelwise_bce = F.binary_cross_entropy(decoded, x_con, reduction='sum')
        cost = kl_divergence + pixelwise_bce
        
        ### UPDATE MODEL PARAMETERS
        optimizer.zero_grad()
        cost.backward()
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 20:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | kl_divergence: %.4f | pixelwise_bce: %.4f | Cost: %.4f'  
                   %(epoch+1, num_epochs, batch_idx, 
                     iters, kl_divergence, pixelwise_bce, cost))
            
    print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
    
print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
# Out:
# Epoch: 001/1000 | Batch 000/040 | Cost: 418338.7500
# Epoch: 001/1000 | Batch 020/040 | Cost: 418540.0000
# Time elapsed: 0.02 min
# Epoch: 002/1000 | Batch 000/040 | Cost: 418106.1250
# Epoch: 002/1000 | Batch 020/040 | Cost: 418033.2812
# Time elapsed: 0.03 min
# Epoch: 003/1000 | Batch 000/040 | Cost: 416386.0625
# Epoch: 003/1000 | Batch 020/040 | Cost: 411040.5000
# Time elapsed: 0.03 min
# Epoch: 004/1000 | Batch 000/040 | Cost: 393010.0000
# Epoch: 004/1000 | Batch 020/040 | Cost: 367496.0938
# Time elapsed: 0.04 min
# Epoch: 005/1000 | Batch 000/040 | Cost: 354588.1875
# Epoch: 005/1000 | Batch 020/040 | Cost: 346168.9688
# Time elapsed: 0.04 min
# Epoch: 006/1000 | Batch 000/040 | Cost: 344131.3125
# Epoch: 006/1000 | Batch 020/040 | Cost: 340193.0312
# Time elapsed: 0.05 min
# Epoch: 007/1000 | Batch 000/040 | Cost: 339887.5312
# Epoch: 007/1000 | Batch 020/040 | Cost: 336359.8125
# Time elapsed: 0.05 min
# Epoch: 008/1000 | Batch 000/040 | Cost: 335868.8438
# Epoch: 008/1000 | Batch 020/040 | Cost: 330627.4375
# Time elapsed: 0.06 min
# Epoch: 009/1000 | Batch 000/040 | Cost: 325643.0625
# Epoch: 009/1000 | Batch 020/040 | Cost: 315492.8125
# Time elapsed: 0.06 min
# Epoch: 010/1000 | Batch 000/040 | Cost: 307587.5312
# Epoch: 010/1000 | Batch 020/040 | Cost: 298931.9062
# Time elapsed: 0.07 min
# Epoch: 011/1000 | Batch 000/040 | Cost: 293405.2500
# Epoch: 011/1000 | Batch 020/040 | Cost: 287690.5625
# Time elapsed: 0.08 min
# Epoch: 012/1000 | Batch 000/040 | Cost: 283303.9062
# Epoch: 012/1000 | Batch 020/040 | Cost: 276843.7500
# Time elapsed: 0.08 min
# Epoch: 013/1000 | Batch 000/040 | Cost: 271024.1562
# Epoch: 013/1000 | Batch 020/040 | Cost: 262126.1875
# Time elapsed: 0.09 min
# Epoch: 014/1000 | Batch 000/040 | Cost: 256085.5000
# Epoch: 014/1000 | Batch 020/040 | Cost: 247903.1406
# Time elapsed: 0.09 min
# Epoch: 015/1000 | Batch 000/040 | Cost: 243137.1094
# Epoch: 015/1000 | Batch 020/040 | Cost: 236976.0156
# Time elapsed: 0.10 min
# Epoch: 016/1000 | Batch 000/040 | Cost: 234228.0156
# Epoch: 016/1000 | Batch 020/040 | Cost: 229352.8594
# Time elapsed: 0.10 min
# Epoch: 017/1000 | Batch 000/040 | Cost: 228352.2656
# Epoch: 017/1000 | Batch 020/040 | Cost: 224530.2188
# Time elapsed: 0.11 min
# Epoch: 018/1000 | Batch 000/040 | Cost: 224094.1406
# Epoch: 018/1000 | Batch 020/040 | Cost: 220563.5312
# Time elapsed: 0.11 min
# Epoch: 019/1000 | Batch 000/040 | Cost: 221304.4844
# Epoch: 019/1000 | Batch 020/040 | Cost: 217846.4531
# Time elapsed: 0.12 min
# Epoch: 020/1000 | Batch 000/040 | Cost: 218595.6406
# Epoch: 020/1000 | Batch 020/040 | Cost: 215904.6250
# Time elapsed: 0.12 min
# Epoch: 021/1000 | Batch 000/040 | Cost: 216863.1875
# Epoch: 021/1000 | Batch 020/040 | Cost: 213973.5781
# Time elapsed: 0.13 min
# Epoch: 022/1000 | Batch 000/040 | Cost: 215390.4531
# Epoch: 022/1000 | Batch 020/040 | Cost: 212827.1250
# Time elapsed: 0.13 min
# Epoch: 023/1000 | Batch 000/040 | Cost: 214141.0000
# Epoch: 023/1000 | Batch 020/040 | Cost: 211602.0000
# Time elapsed: 0.14 min
# Epoch: 024/1000 | Batch 000/040 | Cost: 213090.3750
# Epoch: 024/1000 | Batch 020/040 | Cost: 210441.6094
# Time elapsed: 0.14 min
# Epoch: 025/1000 | Batch 000/040 | Cost: 212107.5781
# Epoch: 025/1000 | Batch 020/040 | Cost: 209559.5312
# Time elapsed: 0.15 min
# Epoch: 026/1000 | Batch 000/040 | Cost: 211320.8125
# Epoch: 026/1000 | Batch 020/040 | Cost: 208588.1094
# Time elapsed: 0.15 min
# Epoch: 027/1000 | Batch 000/040 | Cost: 210283.5781
# Epoch: 027/1000 | Batch 020/040 | Cost: 208057.6562
# Time elapsed: 0.16 min
# Epoch: 028/1000 | Batch 000/040 | Cost: 209821.7969
# Epoch: 028/1000 | Batch 020/040 | Cost: 207504.9062
# Time elapsed: 0.17 min
# Epoch: 029/1000 | Batch 000/040 | Cost: 209366.3125
# Epoch: 029/1000 | Batch 020/040 | Cost: 206952.9688
# Time elapsed: 0.17 min
# Epoch: 030/1000 | Batch 000/040 | Cost: 208866.5625
# Epoch: 030/1000 | Batch 020/040 | Cost: 206266.8438
# Time elapsed: 0.18 min
# Epoch: 031/1000 | Batch 000/040 | Cost: 208266.8438
# Epoch: 031/1000 | Batch 020/040 | Cost: 206051.2344
# Time elapsed: 0.18 min
# Epoch: 032/1000 | Batch 000/040 | Cost: 207828.3281
# Epoch: 032/1000 | Batch 020/040 | Cost: 205521.3906
# Time elapsed: 0.19 min
# Epoch: 033/1000 | Batch 000/040 | Cost: 207368.4219
# Epoch: 033/1000 | Batch 020/040 | Cost: 205226.8125
# Time elapsed: 0.19 min
# Epoch: 034/1000 | Batch 000/040 | Cost: 207209.0938
# Epoch: 034/1000 | Batch 020/040 | Cost: 204743.6875
# Time elapsed: 0.20 min
# Epoch: 035/1000 | Batch 000/040 | Cost: 206588.9531
# Epoch: 035/1000 | Batch 020/040 | Cost: 204325.8281
# Time elapsed: 0.20 min
# Epoch: 036/1000 | Batch 000/040 | Cost: 206442.3594
# Epoch: 036/1000 | Batch 020/040 | Cost: 204143.9844
# Time elapsed: 0.21 min
# Epoch: 037/1000 | Batch 000/040 | Cost: 205901.4219
# Epoch: 037/1000 | Batch 020/040 | Cost: 203732.5156
# Time elapsed: 0.21 min
# Epoch: 038/1000 | Batch 000/040 | Cost: 205733.0156
# Epoch: 038/1000 | Batch 020/040 | Cost: 203296.8281
# Time elapsed: 0.22 min
# Epoch: 039/1000 | Batch 000/040 | Cost: 205291.6094
# Epoch: 039/1000 | Batch 020/040 | Cost: 202965.7656
# Time elapsed: 0.22 min
# Epoch: 040/1000 | Batch 000/040 | Cost: 204870.0469
# Epoch: 040/1000 | Batch 020/040 | Cost: 202842.5781
# Time elapsed: 0.23 min
# Epoch: 041/1000 | Batch 000/040 | Cost: 204601.5625
# Epoch: 041/1000 | Batch 020/040 | Cost: 202351.4062
# Time elapsed: 0.23 min
# Epoch: 042/1000 | Batch 000/040 | Cost: 204290.4844
# Epoch: 042/1000 | Batch 020/040 | Cost: 201947.4375
# Time elapsed: 0.24 min
# Epoch: 043/1000 | Batch 000/040 | Cost: 203895.8594
# Epoch: 043/1000 | Batch 020/040 | Cost: 201829.6875
# Time elapsed: 0.24 min
# Epoch: 044/1000 | Batch 000/040 | Cost: 203598.5469
# Epoch: 044/1000 | Batch 020/040 | Cost: 201410.0312
# Time elapsed: 0.25 min
# Epoch: 045/1000 | Batch 000/040 | Cost: 203160.8125
# Epoch: 045/1000 | Batch 020/040 | Cost: 200859.1094
# Time elapsed: 0.25 min
# Epoch: 046/1000 | Batch 000/040 | Cost: 202820.8281
# Epoch: 046/1000 | Batch 020/040 | Cost: 200381.3906
# Time elapsed: 0.26 min
# Epoch: 047/1000 | Batch 000/040 | Cost: 202378.9375
# Epoch: 047/1000 | Batch 020/040 | Cost: 199896.0312
# Time elapsed: 0.26 min
# Epoch: 048/1000 | Batch 000/040 | Cost: 201677.8750
# Epoch: 048/1000 | Batch 020/040 | Cost: 199510.0469
# Time elapsed: 0.27 min
# Epoch: 049/1000 | Batch 000/040 | Cost: 200927.8438
# Epoch: 049/1000 | Batch 020/040 | Cost: 198691.0000
# Time elapsed: 0.28 min
# Epoch: 050/1000 | Batch 000/040 | Cost: 199966.2812
# Epoch: 050/1000 | Batch 020/040 | Cost: 197375.6094
# Time elapsed: 0.28 min
# Epoch: 051/1000 | Batch 000/040 | Cost: 198878.9844
# Epoch: 051/1000 | Batch 020/040 | Cost: 196313.5469
# Time elapsed: 0.29 min
# Epoch: 052/1000 | Batch 000/040 | Cost: 197711.4688
# Epoch: 052/1000 | Batch 020/040 | Cost: 194946.7344
# Time elapsed: 0.29 min
# Epoch: 053/1000 | Batch 000/040 | Cost: 195937.5156
# Epoch: 053/1000 | Batch 020/040 | Cost: 192857.3906
# Time elapsed: 0.30 min
# Epoch: 054/1000 | Batch 000/040 | Cost: 193902.7344
# Epoch: 054/1000 | Batch 020/040 | Cost: 190570.3281
# Time elapsed: 0.30 min
# Epoch: 055/1000 | Batch 000/040 | Cost: 191162.0625
# Epoch: 055/1000 | Batch 020/040 | Cost: 188132.6719
# Time elapsed: 0.31 min
# Epoch: 056/1000 | Batch 000/040 | Cost: 188441.0781
# Epoch: 056/1000 | Batch 020/040 | Cost: 185560.5312
# Time elapsed: 0.31 min
# Epoch: 057/1000 | Batch 000/040 | Cost: 185685.3906
# Epoch: 057/1000 | Batch 020/040 | Cost: 182818.6094
# Time elapsed: 0.32 min
# Epoch: 058/1000 | Batch 000/040 | Cost: 182353.5000
# Epoch: 058/1000 | Batch 020/040 | Cost: 179830.2344
# Time elapsed: 0.32 min
# Epoch: 059/1000 | Batch 000/040 | Cost: 179420.5312
# Epoch: 059/1000 | Batch 020/040 | Cost: 176747.5781
# Time elapsed: 0.33 min
# Epoch: 060/1000 | Batch 000/040 | Cost: 176655.2812
# Epoch: 060/1000 | Batch 020/040 | Cost: 173963.7656
# Time elapsed: 0.33 min
# Epoch: 061/1000 | Batch 000/040 | Cost: 174082.8125
# Epoch: 061/1000 | Batch 020/040 | Cost: 171488.0625
# Time elapsed: 0.34 min
# Epoch: 062/1000 | Batch 000/040 | Cost: 171694.7188
# Epoch: 062/1000 | Batch 020/040 | Cost: 169347.1875
# Time elapsed: 0.34 min
# Epoch: 063/1000 | Batch 000/040 | Cost: 169533.2031
# Epoch: 063/1000 | Batch 020/040 | Cost: 167631.5625
# Time elapsed: 0.35 min
# Epoch: 064/1000 | Batch 000/040 | Cost: 167263.5625
# Epoch: 064/1000 | Batch 020/040 | Cost: 165472.1406
# Time elapsed: 0.35 min
# Epoch: 065/1000 | Batch 000/040 | Cost: 165792.1562
# Epoch: 065/1000 | Batch 020/040 | Cost: 163838.5625
# Time elapsed: 0.36 min
# Epoch: 066/1000 | Batch 000/040 | Cost: 163912.5312
# Epoch: 066/1000 | Batch 020/040 | Cost: 163220.2969
# Time elapsed: 0.36 min
# Epoch: 067/1000 | Batch 000/040 | Cost: 162354.1406
# Epoch: 067/1000 | Batch 020/040 | Cost: 160711.0938
# Time elapsed: 0.37 min
# Epoch: 068/1000 | Batch 000/040 | Cost: 160869.8750
# Epoch: 068/1000 | Batch 020/040 | Cost: 159730.6875
# Time elapsed: 0.38 min
# Epoch: 069/1000 | Batch 000/040 | Cost: 159692.6875
# Epoch: 069/1000 | Batch 020/040 | Cost: 158574.2500
# Time elapsed: 0.38 min
# Epoch: 070/1000 | Batch 000/040 | Cost: 158659.8125
# Epoch: 070/1000 | Batch 020/040 | Cost: 157545.1406
# Time elapsed: 0.39 min
# Epoch: 071/1000 | Batch 000/040 | Cost: 157515.1875
# Epoch: 071/1000 | Batch 020/040 | Cost: 156502.0156
# Time elapsed: 0.39 min
# Epoch: 072/1000 | Batch 000/040 | Cost: 156650.7969
# Epoch: 072/1000 | Batch 020/040 | Cost: 155628.9688
# Time elapsed: 0.40 min
# Epoch: 073/1000 | Batch 000/040 | Cost: 155909.2188
# Epoch: 073/1000 | Batch 020/040 | Cost: 154897.3750
# Time elapsed: 0.40 min
# Epoch: 074/1000 | Batch 000/040 | Cost: 154941.7500
# Epoch: 074/1000 | Batch 020/040 | Cost: 154242.6719
# Time elapsed: 0.41 min
# Epoch: 075/1000 | Batch 000/040 | Cost: 154278.3281
# Epoch: 075/1000 | Batch 020/040 | Cost: 153694.8906
# Time elapsed: 0.41 min
# Epoch: 076/1000 | Batch 000/040 | Cost: 153532.3438
# Epoch: 076/1000 | Batch 020/040 | Cost: 152788.1875
# Time elapsed: 0.42 min
# Epoch: 077/1000 | Batch 000/040 | Cost: 153117.4375
# Epoch: 077/1000 | Batch 020/040 | Cost: 152301.2812
# Time elapsed: 0.42 min
# Epoch: 078/1000 | Batch 000/040 | Cost: 152445.5469
# Epoch: 078/1000 | Batch 020/040 | Cost: 151624.5000
# Time elapsed: 0.43 min
# Epoch: 079/1000 | Batch 000/040 | Cost: 151791.2969
# Epoch: 079/1000 | Batch 020/040 | Cost: 151241.3750
# Time elapsed: 0.43 min
# Epoch: 080/1000 | Batch 000/040 | Cost: 151187.2188
# Epoch: 080/1000 | Batch 020/040 | Cost: 151740.3594
# Time elapsed: 0.44 min
# Epoch: 081/1000 | Batch 000/040 | Cost: 151174.7500
# Epoch: 081/1000 | Batch 020/040 | Cost: 150423.5938
# Time elapsed: 0.44 min
# Epoch: 082/1000 | Batch 000/040 | Cost: 150490.3125
# Epoch: 082/1000 | Batch 020/040 | Cost: 149797.1562
# Time elapsed: 0.45 min
# Epoch: 083/1000 | Batch 000/040 | Cost: 149765.1094
# Epoch: 083/1000 | Batch 020/040 | Cost: 149476.8281
# Time elapsed: 0.45 min
# Epoch: 084/1000 | Batch 000/040 | Cost: 149838.0469
# Epoch: 084/1000 | Batch 020/040 | Cost: 149130.3125
# Time elapsed: 0.46 min
# Epoch: 085/1000 | Batch 000/040 | Cost: 150045.7031
# Epoch: 085/1000 | Batch 020/040 | Cost: 148949.0469
# Time elapsed: 0.46 min
# Epoch: 086/1000 | Batch 000/040 | Cost: 149042.9375
# Epoch: 086/1000 | Batch 020/040 | Cost: 148612.7031
# Time elapsed: 0.47 min
# Epoch: 087/1000 | Batch 000/040 | Cost: 148584.0469
# Epoch: 087/1000 | Batch 020/040 | Cost: 148469.1250
# Time elapsed: 0.47 min
# Epoch: 088/1000 | Batch 000/040 | Cost: 148464.7500
# Epoch: 088/1000 | Batch 020/040 | Cost: 148068.0938
# Time elapsed: 0.48 min
# Epoch: 089/1000 | Batch 000/040 | Cost: 147913.9531
# Epoch: 089/1000 | Batch 020/040 | Cost: 147463.7969
# Time elapsed: 0.49 min
# Epoch: 090/1000 | Batch 000/040 | Cost: 147777.1562
# Epoch: 090/1000 | Batch 020/040 | Cost: 147247.4375
# Time elapsed: 0.49 min
# Epoch: 091/1000 | Batch 000/040 | Cost: 147689.6094
# Epoch: 091/1000 | Batch 020/040 | Cost: 147408.6406
# Time elapsed: 0.50 min
# Epoch: 092/1000 | Batch 000/040 | Cost: 147578.4688
# Epoch: 092/1000 | Batch 020/040 | Cost: 147090.2812
# Time elapsed: 0.50 min
# Epoch: 093/1000 | Batch 000/040 | Cost: 146996.0625
# Epoch: 093/1000 | Batch 020/040 | Cost: 146598.4531
# Time elapsed: 0.51 min
# Epoch: 094/1000 | Batch 000/040 | Cost: 146881.3281
# Epoch: 094/1000 | Batch 020/040 | Cost: 146751.1875
# Time elapsed: 0.51 min
# Epoch: 095/1000 | Batch 000/040 | Cost: 146515.2500
# Epoch: 095/1000 | Batch 020/040 | Cost: 146618.7500
# Time elapsed: 0.52 min
# Epoch: 096/1000 | Batch 000/040 | Cost: 146863.4219
# Epoch: 096/1000 | Batch 020/040 | Cost: 146250.2344
# Time elapsed: 0.52 min
# Epoch: 097/1000 | Batch 000/040 | Cost: 146089.0938
# Epoch: 097/1000 | Batch 020/040 | Cost: 145941.5938
# Time elapsed: 0.53 min
# Epoch: 098/1000 | Batch 000/040 | Cost: 146349.4062
# Epoch: 098/1000 | Batch 020/040 | Cost: 145661.1406
# Time elapsed: 0.53 min
# Epoch: 099/1000 | Batch 000/040 | Cost: 146182.3750
# Epoch: 099/1000 | Batch 020/040 | Cost: 145554.0625
# Time elapsed: 0.54 min
# Epoch: 100/1000 | Batch 000/040 | Cost: 146233.8125
# Epoch: 100/1000 | Batch 020/040 | Cost: 145914.1094
# Time elapsed: 0.54 min
# Epoch: 101/1000 | Batch 000/040 | Cost: 145682.7656
# Epoch: 101/1000 | Batch 020/040 | Cost: 145661.9531
# Time elapsed: 0.55 min
# Epoch: 102/1000 | Batch 000/040 | Cost: 145624.9531
# Epoch: 102/1000 | Batch 020/040 | Cost: 145092.6719
# Time elapsed: 0.55 min
# Epoch: 103/1000 | Batch 000/040 | Cost: 145248.3125
# Epoch: 103/1000 | Batch 020/040 | Cost: 144942.2500
# Time elapsed: 0.56 min
# Epoch: 104/1000 | Batch 000/040 | Cost: 145053.9688
# Epoch: 104/1000 | Batch 020/040 | Cost: 152324.7344
# Time elapsed: 0.56 min
# Epoch: 105/1000 | Batch 000/040 | Cost: 145252.8906
# Epoch: 105/1000 | Batch 020/040 | Cost: 144798.8281
# Time elapsed: 0.57 min
# Epoch: 106/1000 | Batch 000/040 | Cost: 144623.0312
# Epoch: 106/1000 | Batch 020/040 | Cost: 144593.9844
# Time elapsed: 0.57 min
# Epoch: 107/1000 | Batch 000/040 | Cost: 144908.8438
# Epoch: 107/1000 | Batch 020/040 | Cost: 144398.3594
# Time elapsed: 0.58 min
# Epoch: 108/1000 | Batch 000/040 | Cost: 145025.0000
# Epoch: 108/1000 | Batch 020/040 | Cost: 144196.7656
# Time elapsed: 0.59 min
# Epoch: 109/1000 | Batch 000/040 | Cost: 144436.8750
# Epoch: 109/1000 | Batch 020/040 | Cost: 144089.5156
# Time elapsed: 0.59 min
# Epoch: 110/1000 | Batch 000/040 | Cost: 144204.5156
# Epoch: 110/1000 | Batch 020/040 | Cost: 144062.7969
# Time elapsed: 0.60 min
# Epoch: 111/1000 | Batch 000/040 | Cost: 144175.7969
# Epoch: 111/1000 | Batch 020/040 | Cost: 144090.9688
# Time elapsed: 0.60 min
# Epoch: 112/1000 | Batch 000/040 | Cost: 144198.2031
# Epoch: 112/1000 | Batch 020/040 | Cost: 143904.7656
# Time elapsed: 0.61 min
# Epoch: 113/1000 | Batch 000/040 | Cost: 143879.3750
# Epoch: 113/1000 | Batch 020/040 | Cost: 143699.0312
# Time elapsed: 0.61 min
# Epoch: 114/1000 | Batch 000/040 | Cost: 144030.9062
# Epoch: 114/1000 | Batch 020/040 | Cost: 143847.7344
# Time elapsed: 0.62 min
# Epoch: 115/1000 | Batch 000/040 | Cost: 143790.7188
# Epoch: 115/1000 | Batch 020/040 | Cost: 143626.0938
# Time elapsed: 0.62 min
# Epoch: 116/1000 | Batch 000/040 | Cost: 143945.4531
# Epoch: 116/1000 | Batch 020/040 | Cost: 144113.1250
# Time elapsed: 0.63 min
# Epoch: 117/1000 | Batch 000/040 | Cost: 143597.9375
# Epoch: 117/1000 | Batch 020/040 | Cost: 143474.5000
# Time elapsed: 0.63 min
# Epoch: 118/1000 | Batch 000/040 | Cost: 143849.6562
# Epoch: 118/1000 | Batch 020/040 | Cost: 143624.6562
# Time elapsed: 0.64 min
# Epoch: 119/1000 | Batch 000/040 | Cost: 145913.4062
# Epoch: 119/1000 | Batch 020/040 | Cost: 143780.5312
# Time elapsed: 0.64 min
# Epoch: 120/1000 | Batch 000/040 | Cost: 143497.5312
# Epoch: 120/1000 | Batch 020/040 | Cost: 143271.2344
# Time elapsed: 0.65 min
# Epoch: 121/1000 | Batch 000/040 | Cost: 143287.5000
# Epoch: 121/1000 | Batch 020/040 | Cost: 143085.6562
# Time elapsed: 0.65 min
# Epoch: 122/1000 | Batch 000/040 | Cost: 143075.0156
# Epoch: 122/1000 | Batch 020/040 | Cost: 142907.4375
# Time elapsed: 0.66 min
# Epoch: 123/1000 | Batch 000/040 | Cost: 143510.5312
# Epoch: 123/1000 | Batch 020/040 | Cost: 142987.0000
# Time elapsed: 0.66 min
# Epoch: 124/1000 | Batch 000/040 | Cost: 142950.3125
# Epoch: 124/1000 | Batch 020/040 | Cost: 143080.0312
# Time elapsed: 0.67 min
# Epoch: 125/1000 | Batch 000/040 | Cost: 143090.3750
# Epoch: 125/1000 | Batch 020/040 | Cost: 142871.4531
# Time elapsed: 0.67 min
# Epoch: 126/1000 | Batch 000/040 | Cost: 143005.7656
# Epoch: 126/1000 | Batch 020/040 | Cost: 143024.1406
# Time elapsed: 0.68 min
# Epoch: 127/1000 | Batch 000/040 | Cost: 143096.9531
# Epoch: 127/1000 | Batch 020/040 | Cost: 142739.0000
# Time elapsed: 0.69 min
# Epoch: 128/1000 | Batch 000/040 | Cost: 142627.4062
# Epoch: 128/1000 | Batch 020/040 | Cost: 142716.1562
# Time elapsed: 0.69 min
# Epoch: 129/1000 | Batch 000/040 | Cost: 142869.3906
# Epoch: 129/1000 | Batch 020/040 | Cost: 142714.3750
# Time elapsed: 0.70 min
# Epoch: 130/1000 | Batch 000/040 | Cost: 143218.9062
# Epoch: 130/1000 | Batch 020/040 | Cost: 142846.5156
# Time elapsed: 0.70 min
# Epoch: 131/1000 | Batch 000/040 | Cost: 142810.3281
# Epoch: 131/1000 | Batch 020/040 | Cost: 143080.9531
# Time elapsed: 0.71 min
# Epoch: 132/1000 | Batch 000/040 | Cost: 142496.5312
# Epoch: 132/1000 | Batch 020/040 | Cost: 142376.7031
# Time elapsed: 0.71 min
# Epoch: 133/1000 | Batch 000/040 | Cost: 142507.7031
# Epoch: 133/1000 | Batch 020/040 | Cost: 142485.7500
# Time elapsed: 0.72 min
# Epoch: 134/1000 | Batch 000/040 | Cost: 142862.7969
# Epoch: 134/1000 | Batch 020/040 | Cost: 142772.6875
# Time elapsed: 0.72 min
# Epoch: 135/1000 | Batch 000/040 | Cost: 142474.1250
# Epoch: 135/1000 | Batch 020/040 | Cost: 142557.4844
# Time elapsed: 0.73 min
# Epoch: 136/1000 | Batch 000/040 | Cost: 142685.2500
# Epoch: 136/1000 | Batch 020/040 | Cost: 142341.3125
# Time elapsed: 0.73 min
# Epoch: 137/1000 | Batch 000/040 | Cost: 142299.9219
# Epoch: 137/1000 | Batch 020/040 | Cost: 142302.4531
# Time elapsed: 0.74 min
# Epoch: 138/1000 | Batch 000/040 | Cost: 142399.5156
# Epoch: 138/1000 | Batch 020/040 | Cost: 142400.8906
# Time elapsed: 0.74 min
# Epoch: 139/1000 | Batch 000/040 | Cost: 142541.1250
# Epoch: 139/1000 | Batch 020/040 | Cost: 142177.7656
# Time elapsed: 0.75 min
# Epoch: 140/1000 | Batch 000/040 | Cost: 142221.9844
# Epoch: 140/1000 | Batch 020/040 | Cost: 142032.3125
# Time elapsed: 0.75 min
# Epoch: 141/1000 | Batch 000/040 | Cost: 142262.1406
# Epoch: 141/1000 | Batch 020/040 | Cost: 141976.7344
# Time elapsed: 0.76 min
# Epoch: 142/1000 | Batch 000/040 | Cost: 142069.8594
# Epoch: 142/1000 | Batch 020/040 | Cost: 142150.5469
# Time elapsed: 0.76 min
# Epoch: 143/1000 | Batch 000/040 | Cost: 142107.4062
# Epoch: 143/1000 | Batch 020/040 | Cost: 142061.8750
# Time elapsed: 0.77 min
# Epoch: 144/1000 | Batch 000/040 | Cost: 142054.5625
# Epoch: 144/1000 | Batch 020/040 | Cost: 141843.1875
# Time elapsed: 0.77 min
# Epoch: 145/1000 | Batch 000/040 | Cost: 142076.6875
# Epoch: 145/1000 | Batch 020/040 | Cost: 142001.2969
# Time elapsed: 0.78 min
# Epoch: 146/1000 | Batch 000/040 | Cost: 142013.8750
# Epoch: 146/1000 | Batch 020/040 | Cost: 141774.4062
# Time elapsed: 0.78 min
# Epoch: 147/1000 | Batch 000/040 | Cost: 141823.0469
# Epoch: 147/1000 | Batch 020/040 | Cost: 141960.3750
# Time elapsed: 0.79 min
# Epoch: 148/1000 | Batch 000/040 | Cost: 141793.6719
# Epoch: 148/1000 | Batch 020/040 | Cost: 141761.7500
# Time elapsed: 0.80 min
# Epoch: 149/1000 | Batch 000/040 | Cost: 141774.8594
# Epoch: 149/1000 | Batch 020/040 | Cost: 141987.2344
# Time elapsed: 0.80 min
# Epoch: 150/1000 | Batch 000/040 | Cost: 141979.2344
# Epoch: 150/1000 | Batch 020/040 | Cost: 142186.3438
# Time elapsed: 0.81 min
# Epoch: 151/1000 | Batch 000/040 | Cost: 141705.3438
# Epoch: 151/1000 | Batch 020/040 | Cost: 141625.9844
# Time elapsed: 0.81 min
# Epoch: 152/1000 | Batch 000/040 | Cost: 141652.1250
# Epoch: 152/1000 | Batch 020/040 | Cost: 141705.1875
# Time elapsed: 0.82 min
# Epoch: 153/1000 | Batch 000/040 | Cost: 141674.3281
# Epoch: 153/1000 | Batch 020/040 | Cost: 142070.0469
# Time elapsed: 0.82 min
# Epoch: 154/1000 | Batch 000/040 | Cost: 142030.9688
# Epoch: 154/1000 | Batch 020/040 | Cost: 141682.2344
# Time elapsed: 0.83 min
# Epoch: 155/1000 | Batch 000/040 | Cost: 141661.1406
# Epoch: 155/1000 | Batch 020/040 | Cost: 141927.8281
# Time elapsed: 0.83 min
# Epoch: 156/1000 | Batch 000/040 | Cost: 142101.9844
# Epoch: 156/1000 | Batch 020/040 | Cost: 141687.5625
# Time elapsed: 0.84 min
# Epoch: 157/1000 | Batch 000/040 | Cost: 141677.7812
# Epoch: 157/1000 | Batch 020/040 | Cost: 141478.8125
# Time elapsed: 0.84 min
# Epoch: 158/1000 | Batch 000/040 | Cost: 141477.3906
# Epoch: 158/1000 | Batch 020/040 | Cost: 141605.2500
# Time elapsed: 0.85 min
# Epoch: 159/1000 | Batch 000/040 | Cost: 141534.8750
# Epoch: 159/1000 | Batch 020/040 | Cost: 141549.3750
# Time elapsed: 0.85 min
# Epoch: 160/1000 | Batch 000/040 | Cost: 141350.5469
# Epoch: 160/1000 | Batch 020/040 | Cost: 141273.8750
# Time elapsed: 0.86 min
# Epoch: 161/1000 | Batch 000/040 | Cost: 141709.2188
# Epoch: 161/1000 | Batch 020/040 | Cost: 141906.7344
# Time elapsed: 0.86 min
# Epoch: 162/1000 | Batch 000/040 | Cost: 141705.3906
# Epoch: 162/1000 | Batch 020/040 | Cost: 141424.8281
# Time elapsed: 0.87 min
# Epoch: 163/1000 | Batch 000/040 | Cost: 141437.3281
# Epoch: 163/1000 | Batch 020/040 | Cost: 141616.0000
# Time elapsed: 0.87 min
# Epoch: 164/1000 | Batch 000/040 | Cost: 141351.3750
# Epoch: 164/1000 | Batch 020/040 | Cost: 141264.6875
# Time elapsed: 0.88 min
# Epoch: 165/1000 | Batch 000/040 | Cost: 141389.6562
# Epoch: 165/1000 | Batch 020/040 | Cost: 141471.5000
# Time elapsed: 0.88 min
# Epoch: 166/1000 | Batch 000/040 | Cost: 141394.9375
# Epoch: 166/1000 | Batch 020/040 | Cost: 141256.8906
# Time elapsed: 0.89 min
# Epoch: 167/1000 | Batch 000/040 | Cost: 141265.3281
# Epoch: 167/1000 | Batch 020/040 | Cost: 141340.5938
# Time elapsed: 0.90 min
# Epoch: 168/1000 | Batch 000/040 | Cost: 141270.5938
# Epoch: 168/1000 | Batch 020/040 | Cost: 144281.5469
# Time elapsed: 0.90 min
# Epoch: 169/1000 | Batch 000/040 | Cost: 141533.4062
# Epoch: 169/1000 | Batch 020/040 | Cost: 141490.5000
# Time elapsed: 0.91 min
# Epoch: 170/1000 | Batch 000/040 | Cost: 141282.9844
# Epoch: 170/1000 | Batch 020/040 | Cost: 141141.8281
# Time elapsed: 0.91 min
# Epoch: 171/1000 | Batch 000/040 | Cost: 141272.6250
# Epoch: 171/1000 | Batch 020/040 | Cost: 141316.4219
# Time elapsed: 0.92 min
# Epoch: 172/1000 | Batch 000/040 | Cost: 141262.8594
# Epoch: 172/1000 | Batch 020/040 | Cost: 141118.3750
# Time elapsed: 0.92 min
# Epoch: 173/1000 | Batch 000/040 | Cost: 141250.4375
# Epoch: 173/1000 | Batch 020/040 | Cost: 141206.8281
# Time elapsed: 0.93 min
# Epoch: 174/1000 | Batch 000/040 | Cost: 141121.7656
# Epoch: 174/1000 | Batch 020/040 | Cost: 141029.6562
# Time elapsed: 0.93 min
# Epoch: 175/1000 | Batch 000/040 | Cost: 141186.3594
# Epoch: 175/1000 | Batch 020/040 | Cost: 141049.3906
# Time elapsed: 0.94 min
# Epoch: 176/1000 | Batch 000/040 | Cost: 141223.0000
# Epoch: 176/1000 | Batch 020/040 | Cost: 141364.9844
# Time elapsed: 0.94 min
# Epoch: 177/1000 | Batch 000/040 | Cost: 141227.7031
# Epoch: 177/1000 | Batch 020/040 | Cost: 140998.7812
# Time elapsed: 0.95 min
# Epoch: 178/1000 | Batch 000/040 | Cost: 141080.7344
# Epoch: 178/1000 | Batch 020/040 | Cost: 141213.2500
# Time elapsed: 0.95 min
# Epoch: 179/1000 | Batch 000/040 | Cost: 141311.1250
# Epoch: 179/1000 | Batch 020/040 | Cost: 140991.0000
# Time elapsed: 0.96 min
# Epoch: 180/1000 | Batch 000/040 | Cost: 140927.8125
# Epoch: 180/1000 | Batch 020/040 | Cost: 140935.8438
# Time elapsed: 0.96 min
# Epoch: 181/1000 | Batch 000/040 | Cost: 141504.7812
# Epoch: 181/1000 | Batch 020/040 | Cost: 141202.2031
# Time elapsed: 0.97 min
# Epoch: 182/1000 | Batch 000/040 | Cost: 140956.1094
# Epoch: 182/1000 | Batch 020/040 | Cost: 141644.5938
# Time elapsed: 0.97 min
# Epoch: 183/1000 | Batch 000/040 | Cost: 141487.4688
# Epoch: 183/1000 | Batch 020/040 | Cost: 141267.9844
# Time elapsed: 0.98 min
# Epoch: 184/1000 | Batch 000/040 | Cost: 141093.5156
# Epoch: 184/1000 | Batch 020/040 | Cost: 141157.7031
# Time elapsed: 0.98 min
# Epoch: 185/1000 | Batch 000/040 | Cost: 141300.9219
# Epoch: 185/1000 | Batch 020/040 | Cost: 141095.6875
# Time elapsed: 0.99 min
# Epoch: 186/1000 | Batch 000/040 | Cost: 141027.4844
# Epoch: 186/1000 | Batch 020/040 | Cost: 140837.3594
# Time elapsed: 0.99 min
# Epoch: 187/1000 | Batch 000/040 | Cost: 141453.6406
# Epoch: 187/1000 | Batch 020/040 | Cost: 141541.6406
# Time elapsed: 1.00 min
# Epoch: 188/1000 | Batch 000/040 | Cost: 141367.8594
# Epoch: 188/1000 | Batch 020/040 | Cost: 141042.0312
# Time elapsed: 1.01 min
# Epoch: 189/1000 | Batch 000/040 | Cost: 140948.0312
# Epoch: 189/1000 | Batch 020/040 | Cost: 140908.2031
# Time elapsed: 1.01 min
# Epoch: 190/1000 | Batch 000/040 | Cost: 140822.2344
# Epoch: 190/1000 | Batch 020/040 | Cost: 140868.2188
# Time elapsed: 1.02 min
# Epoch: 191/1000 | Batch 000/040 | Cost: 141030.0625
# Epoch: 191/1000 | Batch 020/040 | Cost: 141183.6250
# Time elapsed: 1.02 min
# Epoch: 192/1000 | Batch 000/040 | Cost: 141204.9531
# Epoch: 192/1000 | Batch 020/040 | Cost: 141037.5312
# Time elapsed: 1.03 min
# Epoch: 193/1000 | Batch 000/040 | Cost: 141053.8281
# Epoch: 193/1000 | Batch 020/040 | Cost: 140916.8594
# Time elapsed: 1.03 min
# Epoch: 194/1000 | Batch 000/040 | Cost: 140854.2188
# Epoch: 194/1000 | Batch 020/040 | Cost: 140747.2188
# Time elapsed: 1.04 min
# Epoch: 195/1000 | Batch 000/040 | Cost: 140891.9844
# Epoch: 195/1000 | Batch 020/040 | Cost: 141371.6094
# Time elapsed: 1.04 min
# Epoch: 196/1000 | Batch 000/040 | Cost: 141227.2344
# Epoch: 196/1000 | Batch 020/040 | Cost: 140946.6562
# Time elapsed: 1.05 min
# Epoch: 197/1000 | Batch 000/040 | Cost: 140828.6250
# Epoch: 197/1000 | Batch 020/040 | Cost: 140723.6719
# Time elapsed: 1.05 min
# Epoch: 198/1000 | Batch 000/040 | Cost: 140839.5469
# Epoch: 198/1000 | Batch 020/040 | Cost: 140649.0938
# Time elapsed: 1.06 min
# Epoch: 199/1000 | Batch 000/040 | Cost: 141007.5469
# Epoch: 199/1000 | Batch 020/040 | Cost: 140971.4062
# Time elapsed: 1.06 min
# Epoch: 200/1000 | Batch 000/040 | Cost: 140782.1406
# Epoch: 200/1000 | Batch 020/040 | Cost: 140659.9375
# Time elapsed: 1.07 min
# Epoch: 201/1000 | Batch 000/040 | Cost: 140628.7344
# Epoch: 201/1000 | Batch 020/040 | Cost: 140601.8438
# Time elapsed: 1.07 min
# Epoch: 202/1000 | Batch 000/040 | Cost: 141635.1875
# Epoch: 202/1000 | Batch 020/040 | Cost: 140807.2969
# Time elapsed: 1.08 min
# Epoch: 203/1000 | Batch 000/040 | Cost: 140750.2969
# Epoch: 203/1000 | Batch 020/040 | Cost: 140625.0156
# Time elapsed: 1.08 min
# Epoch: 204/1000 | Batch 000/040 | Cost: 140599.6406
# Epoch: 204/1000 | Batch 020/040 | Cost: 145352.9531
# Time elapsed: 1.09 min
# Epoch: 205/1000 | Batch 000/040 | Cost: 140952.0469
# Epoch: 205/1000 | Batch 020/040 | Cost: 140864.9219
# Time elapsed: 1.09 min
# Epoch: 206/1000 | Batch 000/040 | Cost: 140692.3281
# Epoch: 206/1000 | Batch 020/040 | Cost: 140590.9375
# Time elapsed: 1.10 min
# Epoch: 207/1000 | Batch 000/040 | Cost: 140549.7031
# Epoch: 207/1000 | Batch 020/040 | Cost: 140758.4062
# Time elapsed: 1.11 min
# Epoch: 208/1000 | Batch 000/040 | Cost: 140651.7188
# Epoch: 208/1000 | Batch 020/040 | Cost: 141110.6562
# Time elapsed: 1.11 min
# Epoch: 209/1000 | Batch 000/040 | Cost: 141554.1406
# Epoch: 209/1000 | Batch 020/040 | Cost: 141227.6094
# Time elapsed: 1.12 min
# Epoch: 210/1000 | Batch 000/040 | Cost: 141042.0781
# Epoch: 210/1000 | Batch 020/040 | Cost: 140798.1562
# Time elapsed: 1.12 min
# Epoch: 211/1000 | Batch 000/040 | Cost: 140688.4375
# Epoch: 211/1000 | Batch 020/040 | Cost: 140512.7344
# Time elapsed: 1.13 min
# Epoch: 212/1000 | Batch 000/040 | Cost: 140474.7031
# Epoch: 212/1000 | Batch 020/040 | Cost: 140741.4844
# Time elapsed: 1.13 min
# Epoch: 213/1000 | Batch 000/040 | Cost: 140700.3125
# Epoch: 213/1000 | Batch 020/040 | Cost: 140508.8594
# Time elapsed: 1.14 min
# Epoch: 214/1000 | Batch 000/040 | Cost: 144825.5781
# Epoch: 214/1000 | Batch 020/040 | Cost: 140746.0781
# Time elapsed: 1.14 min
# Epoch: 215/1000 | Batch 000/040 | Cost: 140707.9375
# Epoch: 215/1000 | Batch 020/040 | Cost: 140585.0156
# Time elapsed: 1.15 min
# Epoch: 216/1000 | Batch 000/040 | Cost: 140574.2188
# Epoch: 216/1000 | Batch 020/040 | Cost: 140600.2969
# Time elapsed: 1.15 min
# Epoch: 217/1000 | Batch 000/040 | Cost: 140578.5781
# Epoch: 217/1000 | Batch 020/040 | Cost: 140482.4375
# Time elapsed: 1.16 min
# Epoch: 218/1000 | Batch 000/040 | Cost: 140675.0469
# Epoch: 218/1000 | Batch 020/040 | Cost: 140586.5312
# Time elapsed: 1.16 min
# Epoch: 219/1000 | Batch 000/040 | Cost: 141053.5312
# Epoch: 219/1000 | Batch 020/040 | Cost: 140946.2969
# Time elapsed: 1.17 min
# Epoch: 220/1000 | Batch 000/040 | Cost: 140723.5312
# Epoch: 220/1000 | Batch 020/040 | Cost: 140578.2812
# Time elapsed: 1.17 min
# Epoch: 221/1000 | Batch 000/040 | Cost: 140622.1250
# Epoch: 221/1000 | Batch 020/040 | Cost: 140474.7500
# Time elapsed: 1.18 min
# Epoch: 222/1000 | Batch 000/040 | Cost: 140461.0938
# Epoch: 222/1000 | Batch 020/040 | Cost: 140583.0781
# Time elapsed: 1.18 min
# Epoch: 223/1000 | Batch 000/040 | Cost: 140665.5469
# Epoch: 223/1000 | Batch 020/040 | Cost: 140616.6094
# Time elapsed: 1.19 min
# Epoch: 224/1000 | Batch 000/040 | Cost: 140574.7344
# Epoch: 224/1000 | Batch 020/040 | Cost: 140489.3906
# Time elapsed: 1.19 min
# Epoch: 225/1000 | Batch 000/040 | Cost: 140374.5469
# Epoch: 225/1000 | Batch 020/040 | Cost: 140357.7500
# Time elapsed: 1.20 min
# Epoch: 226/1000 | Batch 000/040 | Cost: 140383.6875
# Epoch: 226/1000 | Batch 020/040 | Cost: 140434.9375
# Time elapsed: 1.20 min
# Epoch: 227/1000 | Batch 000/040 | Cost: 140486.9219
# Epoch: 227/1000 | Batch 020/040 | Cost: 140312.4844
# Time elapsed: 1.21 min
# Epoch: 228/1000 | Batch 000/040 | Cost: 140370.9688
# Epoch: 228/1000 | Batch 020/040 | Cost: 140379.2812
# Time elapsed: 1.22 min
# Epoch: 229/1000 | Batch 000/040 | Cost: 140314.2656
# Epoch: 229/1000 | Batch 020/040 | Cost: 140275.2188
# Time elapsed: 1.22 min
# Epoch: 230/1000 | Batch 000/040 | Cost: 140363.1719
# Epoch: 230/1000 | Batch 020/040 | Cost: 140464.6719
# Time elapsed: 1.23 min
# Epoch: 231/1000 | Batch 000/040 | Cost: 140833.1406
# Epoch: 231/1000 | Batch 020/040 | Cost: 140427.9531
# Time elapsed: 1.23 min
# Epoch: 232/1000 | Batch 000/040 | Cost: 140501.4375
# Epoch: 232/1000 | Batch 020/040 | Cost: 140447.5000
# Time elapsed: 1.24 min
# Epoch: 233/1000 | Batch 000/040 | Cost: 140383.2031
# Epoch: 233/1000 | Batch 020/040 | Cost: 140995.4531
# Time elapsed: 1.24 min
# Epoch: 234/1000 | Batch 000/040 | Cost: 141899.4375
# Epoch: 234/1000 | Batch 020/040 | Cost: 140584.2344
# Time elapsed: 1.25 min
# Epoch: 235/1000 | Batch 000/040 | Cost: 140503.3750
# Epoch: 235/1000 | Batch 020/040 | Cost: 140473.7969
# Time elapsed: 1.25 min
# Epoch: 236/1000 | Batch 000/040 | Cost: 140311.0625
# Epoch: 236/1000 | Batch 020/040 | Cost: 140383.4375
# Time elapsed: 1.26 min
# Epoch: 237/1000 | Batch 000/040 | Cost: 140314.4062
# Epoch: 237/1000 | Batch 020/040 | Cost: 140324.2969
# Time elapsed: 1.26 min
# Epoch: 238/1000 | Batch 000/040 | Cost: 140366.1562
# Epoch: 238/1000 | Batch 020/040 | Cost: 140333.2656
# Time elapsed: 1.27 min
# Epoch: 239/1000 | Batch 000/040 | Cost: 140600.8750
# Epoch: 239/1000 | Batch 020/040 | Cost: 140596.5312
# Time elapsed: 1.27 min
# Epoch: 240/1000 | Batch 000/040 | Cost: 140786.8906
# Epoch: 240/1000 | Batch 020/040 | Cost: 140377.2344
# Time elapsed: 1.28 min
# Epoch: 241/1000 | Batch 000/040 | Cost: 140407.1562
# Epoch: 241/1000 | Batch 020/040 | Cost: 140362.2500
# Time elapsed: 1.28 min
# Epoch: 242/1000 | Batch 000/040 | Cost: 140502.6094
# Epoch: 242/1000 | Batch 020/040 | Cost: 140760.9219
# Time elapsed: 1.29 min
# Epoch: 243/1000 | Batch 000/040 | Cost: 140372.4688
# Epoch: 243/1000 | Batch 020/040 | Cost: 140333.5625
# Time elapsed: 1.29 min
# Epoch: 244/1000 | Batch 000/040 | Cost: 140204.9375
# Epoch: 244/1000 | Batch 020/040 | Cost: 140354.1719
# Time elapsed: 1.30 min
# Epoch: 245/1000 | Batch 000/040 | Cost: 140291.2812
# Epoch: 245/1000 | Batch 020/040 | Cost: 140268.8594
# Time elapsed: 1.30 min
# Epoch: 246/1000 | Batch 000/040 | Cost: 140351.4375
# Epoch: 246/1000 | Batch 020/040 | Cost: 140435.1562
# Time elapsed: 1.31 min
# Epoch: 247/1000 | Batch 000/040 | Cost: 140362.4219
# Epoch: 247/1000 | Batch 020/040 | Cost: 140274.4688
# Time elapsed: 1.32 min
# Epoch: 248/1000 | Batch 000/040 | Cost: 140521.3438
# Epoch: 248/1000 | Batch 020/040 | Cost: 140525.5938
# Time elapsed: 1.32 min
# Epoch: 249/1000 | Batch 000/040 | Cost: 140661.9844
# Epoch: 249/1000 | Batch 020/040 | Cost: 140601.8281
# Time elapsed: 1.33 min
# Epoch: 250/1000 | Batch 000/040 | Cost: 140566.4375
# Epoch: 250/1000 | Batch 020/040 | Cost: 140398.0781
# Time elapsed: 1.33 min
# Epoch: 251/1000 | Batch 000/040 | Cost: 140226.3438
# Epoch: 251/1000 | Batch 020/040 | Cost: 140340.7656
# Time elapsed: 1.34 min
# Epoch: 252/1000 | Batch 000/040 | Cost: 140259.2188
# Epoch: 252/1000 | Batch 020/040 | Cost: 140085.5469
# Time elapsed: 1.34 min
# Epoch: 253/1000 | Batch 000/040 | Cost: 140405.2969
# Epoch: 253/1000 | Batch 020/040 | Cost: 140709.8281
# Time elapsed: 1.35 min
# Epoch: 254/1000 | Batch 000/040 | Cost: 140341.2344
# Epoch: 254/1000 | Batch 020/040 | Cost: 140264.0312
# Time elapsed: 1.35 min
# Epoch: 255/1000 | Batch 000/040 | Cost: 140375.8125
# Epoch: 255/1000 | Batch 020/040 | Cost: 140294.5000
# Time elapsed: 1.36 min
# Epoch: 256/1000 | Batch 000/040 | Cost: 140340.4375
# Epoch: 256/1000 | Batch 020/040 | Cost: 141256.4062
# Time elapsed: 1.36 min
# Epoch: 257/1000 | Batch 000/040 | Cost: 140781.5000
# Epoch: 257/1000 | Batch 020/040 | Cost: 140529.7188
# Time elapsed: 1.37 min
# Epoch: 258/1000 | Batch 000/040 | Cost: 140301.6406
# Epoch: 258/1000 | Batch 020/040 | Cost: 140202.5156
# Time elapsed: 1.37 min
# Epoch: 259/1000 | Batch 000/040 | Cost: 140307.7344
# Epoch: 259/1000 | Batch 020/040 | Cost: 140163.2812
# Time elapsed: 1.38 min
# Epoch: 260/1000 | Batch 000/040 | Cost: 140577.4062
# Epoch: 260/1000 | Batch 020/040 | Cost: 140483.5469
# Time elapsed: 1.38 min
# Epoch: 261/1000 | Batch 000/040 | Cost: 140431.7500
# Epoch: 261/1000 | Batch 020/040 | Cost: 140322.1562
# Time elapsed: 1.39 min
# Epoch: 262/1000 | Batch 000/040 | Cost: 140383.9531
# Epoch: 262/1000 | Batch 020/040 | Cost: 140488.7500
# Time elapsed: 1.39 min
# Epoch: 263/1000 | Batch 000/040 | Cost: 140428.8125
# Epoch: 263/1000 | Batch 020/040 | Cost: 140200.2500
# Time elapsed: 1.40 min
# Epoch: 264/1000 | Batch 000/040 | Cost: 140209.5469
# Epoch: 264/1000 | Batch 020/040 | Cost: 140676.9844
# Time elapsed: 1.40 min
# Epoch: 265/1000 | Batch 000/040 | Cost: 140530.2656
# Epoch: 265/1000 | Batch 020/040 | Cost: 140364.6562
# Time elapsed: 1.41 min
# Epoch: 266/1000 | Batch 000/040 | Cost: 140214.9844
# Epoch: 266/1000 | Batch 020/040 | Cost: 140305.1562
# Time elapsed: 1.41 min
# Epoch: 267/1000 | Batch 000/040 | Cost: 140129.1250
# Epoch: 267/1000 | Batch 020/040 | Cost: 140241.5781
# Time elapsed: 1.42 min
# Epoch: 268/1000 | Batch 000/040 | Cost: 140347.8906
# Epoch: 268/1000 | Batch 020/040 | Cost: 140288.3438
# Time elapsed: 1.43 min
# Epoch: 269/1000 | Batch 000/040 | Cost: 141233.4062
# Epoch: 269/1000 | Batch 020/040 | Cost: 140869.6562
# Time elapsed: 1.43 min
# Epoch: 270/1000 | Batch 000/040 | Cost: 140415.4062
# Epoch: 270/1000 | Batch 020/040 | Cost: 140435.2500
# Time elapsed: 1.44 min
# Epoch: 271/1000 | Batch 000/040 | Cost: 140137.5469
# Epoch: 271/1000 | Batch 020/040 | Cost: 140543.5156
# Time elapsed: 1.44 min
# Epoch: 272/1000 | Batch 000/040 | Cost: 140576.2500
# Epoch: 272/1000 | Batch 020/040 | Cost: 140252.5469
# Time elapsed: 1.45 min
# Epoch: 273/1000 | Batch 000/040 | Cost: 140226.1406
# Epoch: 273/1000 | Batch 020/040 | Cost: 140253.6094
# Time elapsed: 1.45 min
# Epoch: 274/1000 | Batch 000/040 | Cost: 140463.1250
# Epoch: 274/1000 | Batch 020/040 | Cost: 140376.9219
# Time elapsed: 1.46 min
# Epoch: 275/1000 | Batch 000/040 | Cost: 140206.7188
# Epoch: 275/1000 | Batch 020/040 | Cost: 140108.0625
# Time elapsed: 1.46 min
# Epoch: 276/1000 | Batch 000/040 | Cost: 140191.3906
# Epoch: 276/1000 | Batch 020/040 | Cost: 140182.7812
# Time elapsed: 1.47 min
# Epoch: 277/1000 | Batch 000/040 | Cost: 141631.9844
# Epoch: 277/1000 | Batch 020/040 | Cost: 141449.5156
# Time elapsed: 1.47 min
# Epoch: 278/1000 | Batch 000/040 | Cost: 141023.8438
# Epoch: 278/1000 | Batch 020/040 | Cost: 140548.4844
# Time elapsed: 1.48 min
# Epoch: 279/1000 | Batch 000/040 | Cost: 140343.0938
# Epoch: 279/1000 | Batch 020/040 | Cost: 140501.2812
# Time elapsed: 1.48 min
# Epoch: 280/1000 | Batch 000/040 | Cost: 140599.4375
# Epoch: 280/1000 | Batch 020/040 | Cost: 140489.8281
# Time elapsed: 1.49 min
# Epoch: 281/1000 | Batch 000/040 | Cost: 140386.8906
# Epoch: 281/1000 | Batch 020/040 | Cost: 140260.0000
# Time elapsed: 1.49 min
# Epoch: 282/1000 | Batch 000/040 | Cost: 140138.1562
# Epoch: 282/1000 | Batch 020/040 | Cost: 140189.5781
# Time elapsed: 1.50 min
# Epoch: 283/1000 | Batch 000/040 | Cost: 140320.1562
# Epoch: 283/1000 | Batch 020/040 | Cost: 140179.9688
# Time elapsed: 1.50 min
# Epoch: 284/1000 | Batch 000/040 | Cost: 140167.7188
# Epoch: 284/1000 | Batch 020/040 | Cost: 140922.0156
# Time elapsed: 1.51 min
# Epoch: 285/1000 | Batch 000/040 | Cost: 140786.4375
# Epoch: 285/1000 | Batch 020/040 | Cost: 140447.3906
# Time elapsed: 1.51 min
# Epoch: 286/1000 | Batch 000/040 | Cost: 140223.1094
# Epoch: 286/1000 | Batch 020/040 | Cost: 140131.8281
# Time elapsed: 1.52 min
# Epoch: 287/1000 | Batch 000/040 | Cost: 140126.5000
# Epoch: 287/1000 | Batch 020/040 | Cost: 140160.4375
# Time elapsed: 1.52 min
# Epoch: 288/1000 | Batch 000/040 | Cost: 140040.4062
# Epoch: 288/1000 | Batch 020/040 | Cost: 140191.5156
# Time elapsed: 1.53 min
# Epoch: 289/1000 | Batch 000/040 | Cost: 140178.6875
# Epoch: 289/1000 | Batch 020/040 | Cost: 140045.7656
# Time elapsed: 1.54 min
# Epoch: 290/1000 | Batch 000/040 | Cost: 139994.7812
# Epoch: 290/1000 | Batch 020/040 | Cost: 139998.5938
# Time elapsed: 1.54 min
# Epoch: 291/1000 | Batch 000/040 | Cost: 139998.4219
# Epoch: 291/1000 | Batch 020/040 | Cost: 140300.9062
# Time elapsed: 1.55 min
# Epoch: 292/1000 | Batch 000/040 | Cost: 140501.6719
# Epoch: 292/1000 | Batch 020/040 | Cost: 140185.7812
# Time elapsed: 1.55 min
# Epoch: 293/1000 | Batch 000/040 | Cost: 140090.7031
# Epoch: 293/1000 | Batch 020/040 | Cost: 140093.0000
# Time elapsed: 1.56 min
# Epoch: 294/1000 | Batch 000/040 | Cost: 140155.8906
# Epoch: 294/1000 | Batch 020/040 | Cost: 140038.0469
# Time elapsed: 1.56 min
# Epoch: 295/1000 | Batch 000/040 | Cost: 139992.3594
# Epoch: 295/1000 | Batch 020/040 | Cost: 140138.9219
# Time elapsed: 1.57 min
# Epoch: 296/1000 | Batch 000/040 | Cost: 140102.5625
# Epoch: 296/1000 | Batch 020/040 | Cost: 140947.5781
# Time elapsed: 1.57 min
# Epoch: 297/1000 | Batch 000/040 | Cost: 140962.2500
# Epoch: 297/1000 | Batch 020/040 | Cost: 140390.8906
# Time elapsed: 1.58 min
# Epoch: 298/1000 | Batch 000/040 | Cost: 140077.3281
# Epoch: 298/1000 | Batch 020/040 | Cost: 140104.1875
# Time elapsed: 1.58 min
# Epoch: 299/1000 | Batch 000/040 | Cost: 140203.6562
# Epoch: 299/1000 | Batch 020/040 | Cost: 140130.9062
# Time elapsed: 1.59 min
# Epoch: 300/1000 | Batch 000/040 | Cost: 140073.5156
# Epoch: 300/1000 | Batch 020/040 | Cost: 140015.9062
# Time elapsed: 1.59 min
# Epoch: 301/1000 | Batch 000/040 | Cost: 140330.9688
# Epoch: 301/1000 | Batch 020/040 | Cost: 140294.6406
# Time elapsed: 1.60 min
# Epoch: 302/1000 | Batch 000/040 | Cost: 140280.6094
# Epoch: 302/1000 | Batch 020/040 | Cost: 140130.5000
# Time elapsed: 1.60 min
# Epoch: 303/1000 | Batch 000/040 | Cost: 140222.7188
# Epoch: 303/1000 | Batch 020/040 | Cost: 140161.1406
# Time elapsed: 1.61 min
# Epoch: 304/1000 | Batch 000/040 | Cost: 140048.3281
# Epoch: 304/1000 | Batch 020/040 | Cost: 140180.5000
# Time elapsed: 1.61 min
# Epoch: 305/1000 | Batch 000/040 | Cost: 140178.2188
# Epoch: 305/1000 | Batch 020/040 | Cost: 140109.4219
# Time elapsed: 1.62 min
# Epoch: 306/1000 | Batch 000/040 | Cost: 140145.6250
# Epoch: 306/1000 | Batch 020/040 | Cost: 140299.6562
# Time elapsed: 1.62 min
# Epoch: 307/1000 | Batch 000/040 | Cost: 140141.9688
# Epoch: 307/1000 | Batch 020/040 | Cost: 140092.5000
# Time elapsed: 1.63 min
# Epoch: 308/1000 | Batch 000/040 | Cost: 140327.4219
# Epoch: 308/1000 | Batch 020/040 | Cost: 140222.0156
# Time elapsed: 1.64 min
# Epoch: 309/1000 | Batch 000/040 | Cost: 140184.5312
# Epoch: 309/1000 | Batch 020/040 | Cost: 140142.1094
# Time elapsed: 1.64 min
# Epoch: 310/1000 | Batch 000/040 | Cost: 140214.8906
# Epoch: 310/1000 | Batch 020/040 | Cost: 140174.7969
# Time elapsed: 1.65 min
# Epoch: 311/1000 | Batch 000/040 | Cost: 140109.9844
# Epoch: 311/1000 | Batch 020/040 | Cost: 140155.3281
# Time elapsed: 1.65 min
# Epoch: 312/1000 | Batch 000/040 | Cost: 140294.7656
# Epoch: 312/1000 | Batch 020/040 | Cost: 140099.7812
# Time elapsed: 1.66 min
# Epoch: 313/1000 | Batch 000/040 | Cost: 140055.2031
# Epoch: 313/1000 | Batch 020/040 | Cost: 140055.3906
# Time elapsed: 1.66 min
# Epoch: 314/1000 | Batch 000/040 | Cost: 139985.0781
# Epoch: 314/1000 | Batch 020/040 | Cost: 140611.8438
# Time elapsed: 1.67 min
# Epoch: 315/1000 | Batch 000/040 | Cost: 140609.0469
# Epoch: 315/1000 | Batch 020/040 | Cost: 140644.6875
# Time elapsed: 1.67 min
# Epoch: 316/1000 | Batch 000/040 | Cost: 140392.3906
# Epoch: 316/1000 | Batch 020/040 | Cost: 140165.7188
# Time elapsed: 1.68 min
# Epoch: 317/1000 | Batch 000/040 | Cost: 140456.1094
# Epoch: 317/1000 | Batch 020/040 | Cost: 140097.4375
# Time elapsed: 1.68 min
# Epoch: 318/1000 | Batch 000/040 | Cost: 140671.0000
# Epoch: 318/1000 | Batch 020/040 | Cost: 140427.6094
# Time elapsed: 1.69 min
# Epoch: 319/1000 | Batch 000/040 | Cost: 140210.5000
# Epoch: 319/1000 | Batch 020/040 | Cost: 140488.4062
# Time elapsed: 1.69 min
# Epoch: 320/1000 | Batch 000/040 | Cost: 140544.6250
# Epoch: 320/1000 | Batch 020/040 | Cost: 140259.1250
# Time elapsed: 1.70 min
# Epoch: 321/1000 | Batch 000/040 | Cost: 140082.1875
# Epoch: 321/1000 | Batch 020/040 | Cost: 140035.6719
# Time elapsed: 1.70 min
# Epoch: 322/1000 | Batch 000/040 | Cost: 139953.4219
# Epoch: 322/1000 | Batch 020/040 | Cost: 139899.5312
# Time elapsed: 1.71 min
# Epoch: 323/1000 | Batch 000/040 | Cost: 140218.9375
# Epoch: 323/1000 | Batch 020/040 | Cost: 140042.2812
# Time elapsed: 1.71 min
# Epoch: 324/1000 | Batch 000/040 | Cost: 140063.9062
# Epoch: 324/1000 | Batch 020/040 | Cost: 140246.7812
# Time elapsed: 1.72 min
# Epoch: 325/1000 | Batch 000/040 | Cost: 139895.8125
# Epoch: 325/1000 | Batch 020/040 | Cost: 139846.3438
# Time elapsed: 1.72 min
# Epoch: 326/1000 | Batch 000/040 | Cost: 139868.0000
# Epoch: 326/1000 | Batch 020/040 | Cost: 139962.6250
# Time elapsed: 1.73 min
# Epoch: 327/1000 | Batch 000/040 | Cost: 140292.5000
# Epoch: 327/1000 | Batch 020/040 | Cost: 140462.4062
# Time elapsed: 1.73 min
# Epoch: 328/1000 | Batch 000/040 | Cost: 140149.4062
# Epoch: 328/1000 | Batch 020/040 | Cost: 140308.8281
# Time elapsed: 1.74 min
# Epoch: 329/1000 | Batch 000/040 | Cost: 140561.9844
# Epoch: 329/1000 | Batch 020/040 | Cost: 140247.5781
# Time elapsed: 1.75 min
# Epoch: 330/1000 | Batch 000/040 | Cost: 140061.8750
# Epoch: 330/1000 | Batch 020/040 | Cost: 139950.4531
# Time elapsed: 1.75 min
# Epoch: 331/1000 | Batch 000/040 | Cost: 139923.7812
# Epoch: 331/1000 | Batch 020/040 | Cost: 140403.3125
# Time elapsed: 1.76 min
# Epoch: 332/1000 | Batch 000/040 | Cost: 140599.0938
# Epoch: 332/1000 | Batch 020/040 | Cost: 140292.5156
# Time elapsed: 1.76 min
# Epoch: 333/1000 | Batch 000/040 | Cost: 140132.5156
# Epoch: 333/1000 | Batch 020/040 | Cost: 139943.4062
# Time elapsed: 1.77 min
# Epoch: 334/1000 | Batch 000/040 | Cost: 140341.0938
# Epoch: 334/1000 | Batch 020/040 | Cost: 140239.8750
# Time elapsed: 1.77 min
# Epoch: 335/1000 | Batch 000/040 | Cost: 140088.3438
# Epoch: 335/1000 | Batch 020/040 | Cost: 139959.5625
# Time elapsed: 1.78 min
# Epoch: 336/1000 | Batch 000/040 | Cost: 140226.1094
# Epoch: 336/1000 | Batch 020/040 | Cost: 141085.6875
# Time elapsed: 1.78 min
# Epoch: 337/1000 | Batch 000/040 | Cost: 141216.8906
# Epoch: 337/1000 | Batch 020/040 | Cost: 140752.5312
# Time elapsed: 1.79 min
# Epoch: 338/1000 | Batch 000/040 | Cost: 140442.9375
# Epoch: 338/1000 | Batch 020/040 | Cost: 140177.4844
# Time elapsed: 1.79 min
# Epoch: 339/1000 | Batch 000/040 | Cost: 140330.6094
# Epoch: 339/1000 | Batch 020/040 | Cost: 140462.5156
# Time elapsed: 1.80 min
# Epoch: 340/1000 | Batch 000/040 | Cost: 140348.5938
# Epoch: 340/1000 | Batch 020/040 | Cost: 140444.8125
# Time elapsed: 1.80 min
# Epoch: 341/1000 | Batch 000/040 | Cost: 140345.8125
# Epoch: 341/1000 | Batch 020/040 | Cost: 140171.7969
# Time elapsed: 1.81 min
# Epoch: 342/1000 | Batch 000/040 | Cost: 140019.6406
# Epoch: 342/1000 | Batch 020/040 | Cost: 139924.8438
# Time elapsed: 1.81 min
# Epoch: 343/1000 | Batch 000/040 | Cost: 140013.9688
# Epoch: 343/1000 | Batch 020/040 | Cost: 140194.4844
# Time elapsed: 1.82 min
# Epoch: 344/1000 | Batch 000/040 | Cost: 140372.1719
# Epoch: 344/1000 | Batch 020/040 | Cost: 140232.6875
# Time elapsed: 1.82 min
# Epoch: 345/1000 | Batch 000/040 | Cost: 140056.2656
# Epoch: 345/1000 | Batch 020/040 | Cost: 140633.6250
# Time elapsed: 1.83 min
# Epoch: 346/1000 | Batch 000/040 | Cost: 140667.4531
# Epoch: 346/1000 | Batch 020/040 | Cost: 140664.9062
# Time elapsed: 1.83 min
# Epoch: 347/1000 | Batch 000/040 | Cost: 140543.6250
# Epoch: 347/1000 | Batch 020/040 | Cost: 140276.0781
# Time elapsed: 1.84 min
# Epoch: 348/1000 | Batch 000/040 | Cost: 140102.8281
# Epoch: 348/1000 | Batch 020/040 | Cost: 140015.0781
# Time elapsed: 1.85 min
# Epoch: 349/1000 | Batch 000/040 | Cost: 139971.5000
# Epoch: 349/1000 | Batch 020/040 | Cost: 140016.4844
# Time elapsed: 1.85 min
# Epoch: 350/1000 | Batch 000/040 | Cost: 139926.6094
# Epoch: 350/1000 | Batch 020/040 | Cost: 140010.4219
# Time elapsed: 1.86 min
# Epoch: 351/1000 | Batch 000/040 | Cost: 139928.9062
# Epoch: 351/1000 | Batch 020/040 | Cost: 140068.7344
# Time elapsed: 1.86 min
# Epoch: 352/1000 | Batch 000/040 | Cost: 140087.7188
# Epoch: 352/1000 | Batch 020/040 | Cost: 139936.3906
# Time elapsed: 1.87 min
# Epoch: 353/1000 | Batch 000/040 | Cost: 139935.4844
# Epoch: 353/1000 | Batch 020/040 | Cost: 139924.3750
# Time elapsed: 1.87 min
# Epoch: 354/1000 | Batch 000/040 | Cost: 140311.4375
# Epoch: 354/1000 | Batch 020/040 | Cost: 140384.2031
# Time elapsed: 1.88 min
# Epoch: 355/1000 | Batch 000/040 | Cost: 140200.3594
# Epoch: 355/1000 | Batch 020/040 | Cost: 140050.1562
# Time elapsed: 1.88 min
# Epoch: 356/1000 | Batch 000/040 | Cost: 139986.8750
# Epoch: 356/1000 | Batch 020/040 | Cost: 140102.8906
# Time elapsed: 1.89 min
# Epoch: 357/1000 | Batch 000/040 | Cost: 140072.9219
# Epoch: 357/1000 | Batch 020/040 | Cost: 139958.0312
# Time elapsed: 1.89 min
# Epoch: 358/1000 | Batch 000/040 | Cost: 140055.0625
# Epoch: 358/1000 | Batch 020/040 | Cost: 139908.2500
# Time elapsed: 1.90 min
# Epoch: 359/1000 | Batch 000/040 | Cost: 140151.1875
# Epoch: 359/1000 | Batch 020/040 | Cost: 140506.6875
# Time elapsed: 1.90 min
# Epoch: 360/1000 | Batch 000/040 | Cost: 140845.6250
# Epoch: 360/1000 | Batch 020/040 | Cost: 140507.9062
# Time elapsed: 1.91 min
# Epoch: 361/1000 | Batch 000/040 | Cost: 140522.0469
# Epoch: 361/1000 | Batch 020/040 | Cost: 140255.2031
# Time elapsed: 1.91 min
# Epoch: 362/1000 | Batch 000/040 | Cost: 140144.3906
# Epoch: 362/1000 | Batch 020/040 | Cost: 139931.8281
# Time elapsed: 1.92 min
# Epoch: 363/1000 | Batch 000/040 | Cost: 140092.7031
# Epoch: 363/1000 | Batch 020/040 | Cost: 140045.0000
# Time elapsed: 1.92 min
# Epoch: 364/1000 | Batch 000/040 | Cost: 139985.6562
# Epoch: 364/1000 | Batch 020/040 | Cost: 140024.5625
# Time elapsed: 1.93 min
# Epoch: 365/1000 | Batch 000/040 | Cost: 140089.3281
# Epoch: 365/1000 | Batch 020/040 | Cost: 139967.8594
# Time elapsed: 1.93 min
# Epoch: 366/1000 | Batch 000/040 | Cost: 140326.3906
# Epoch: 366/1000 | Batch 020/040 | Cost: 140288.4062
# Time elapsed: 1.94 min
# Epoch: 367/1000 | Batch 000/040 | Cost: 140384.0781
# Epoch: 367/1000 | Batch 020/040 | Cost: 140162.4219
# Time elapsed: 1.95 min
# Epoch: 368/1000 | Batch 000/040 | Cost: 140036.2969
# Epoch: 368/1000 | Batch 020/040 | Cost: 139934.5625
# Time elapsed: 1.95 min
# Epoch: 369/1000 | Batch 000/040 | Cost: 140018.1406
# Epoch: 369/1000 | Batch 020/040 | Cost: 139968.5156
# Time elapsed: 1.96 min
# Epoch: 370/1000 | Batch 000/040 | Cost: 139971.9531
# Epoch: 370/1000 | Batch 020/040 | Cost: 139965.7188
# Time elapsed: 1.96 min
# Epoch: 371/1000 | Batch 000/040 | Cost: 140204.1875
# Epoch: 371/1000 | Batch 020/040 | Cost: 140178.7500
# Time elapsed: 1.97 min
# Epoch: 372/1000 | Batch 000/040 | Cost: 140212.1562
# Epoch: 372/1000 | Batch 020/040 | Cost: 140090.8438
# Time elapsed: 1.97 min
# Epoch: 373/1000 | Batch 000/040 | Cost: 139972.1719
# Epoch: 373/1000 | Batch 020/040 | Cost: 139932.9219
# Time elapsed: 1.98 min
# Epoch: 374/1000 | Batch 000/040 | Cost: 140041.7031
# Epoch: 374/1000 | Batch 020/040 | Cost: 140023.6406
# Time elapsed: 1.98 min
# Epoch: 375/1000 | Batch 000/040 | Cost: 140042.3594
# Epoch: 375/1000 | Batch 020/040 | Cost: 140307.4219
# Time elapsed: 1.99 min
# Epoch: 376/1000 | Batch 000/040 | Cost: 140267.3125
# Epoch: 376/1000 | Batch 020/040 | Cost: 140081.6406
# Time elapsed: 1.99 min
# Epoch: 377/1000 | Batch 000/040 | Cost: 139948.7500
# Epoch: 377/1000 | Batch 020/040 | Cost: 139941.3281
# Time elapsed: 2.00 min
# Epoch: 378/1000 | Batch 000/040 | Cost: 140251.8281
# Epoch: 378/1000 | Batch 020/040 | Cost: 140208.0781
# ...
# Epoch: 875/1000 | Batch 020/040 | Cost: 140562.1562
# Time elapsed: 4.63 min
# Epoch: 876/1000 | Batch 000/040 | Cost: 139807.1875
# Epoch: 876/1000 | Batch 020/040 | Cost: 139598.6094
# Time elapsed: 4.63 min
# Epoch: 877/1000 | Batch 000/040 | Cost: 139504.5000
# Epoch: 877/1000 | Batch 020/040 | Cost: 139506.4531
# Time elapsed: 4.64 min
# Epoch: 878/1000 | Batch 000/040 | Cost: 139598.3125
# Epoch: 878/1000 | Batch 020/040 | Cost: 139522.3906
# Time elapsed: 4.64 min
# Epoch: 879/1000 | Batch 000/040 | Cost: 139507.5312
# Epoch: 879/1000 | Batch 020/040 | Cost: 139608.1406
# Time elapsed: 4.65 min
# Epoch: 880/1000 | Batch 000/040 | Cost: 139735.3750
# Epoch: 880/1000 | Batch 020/040 | Cost: 139632.0312
# Time elapsed: 4.65 min
# Epoch: 881/1000 | Batch 000/040 | Cost: 139576.7188
# Epoch: 881/1000 | Batch 020/040 | Cost: 139458.4375
# Time elapsed: 4.66 min
# Epoch: 882/1000 | Batch 000/040 | Cost: 139452.4062
# Epoch: 882/1000 | Batch 020/040 | Cost: 139421.5312
# Time elapsed: 4.66 min
# Epoch: 883/1000 | Batch 000/040 | Cost: 139513.1250
# Epoch: 883/1000 | Batch 020/040 | Cost: 139539.8125
# Time elapsed: 4.67 min
# Epoch: 884/1000 | Batch 000/040 | Cost: 139531.5312
# Epoch: 884/1000 | Batch 020/040 | Cost: 139488.0312
# Time elapsed: 4.67 min
# Epoch: 885/1000 | Batch 000/040 | Cost: 139553.0156
# Epoch: 885/1000 | Batch 020/040 | Cost: 139781.2344
# Time elapsed: 4.68 min
# Epoch: 886/1000 | Batch 000/040 | Cost: 139458.7188
# Epoch: 886/1000 | Batch 020/040 | Cost: 139537.2812
# Time elapsed: 4.68 min
# Epoch: 887/1000 | Batch 000/040 | Cost: 139632.6250
# Epoch: 887/1000 | Batch 020/040 | Cost: 139472.9531
# Time elapsed: 4.69 min
# Epoch: 888/1000 | Batch 000/040 | Cost: 139560.7031
# Epoch: 888/1000 | Batch 020/040 | Cost: 139473.6875
# Time elapsed: 4.69 min
# Epoch: 889/1000 | Batch 000/040 | Cost: 139439.2031
# Epoch: 889/1000 | Batch 020/040 | Cost: 139532.7188
# Time elapsed: 4.70 min
# Epoch: 890/1000 | Batch 000/040 | Cost: 139490.4219
# Epoch: 890/1000 | Batch 020/040 | Cost: 139539.7812
# Time elapsed: 4.70 min
# Epoch: 891/1000 | Batch 000/040 | Cost: 139657.3438
# Epoch: 891/1000 | Batch 020/040 | Cost: 139667.0156
# Time elapsed: 4.71 min
# Epoch: 892/1000 | Batch 000/040 | Cost: 139608.5625
# Epoch: 892/1000 | Batch 020/040 | Cost: 139525.3906
# Time elapsed: 4.72 min
# Epoch: 893/1000 | Batch 000/040 | Cost: 139550.3438
# Epoch: 893/1000 | Batch 020/040 | Cost: 139668.2812
# Time elapsed: 4.72 min
# Epoch: 894/1000 | Batch 000/040 | Cost: 139719.1094
# Epoch: 894/1000 | Batch 020/040 | Cost: 139665.1719
# Time elapsed: 4.73 min
# Epoch: 895/1000 | Batch 000/040 | Cost: 139549.9375
# Epoch: 895/1000 | Batch 020/040 | Cost: 139521.7500
# Time elapsed: 4.73 min
# Epoch: 896/1000 | Batch 000/040 | Cost: 139620.8281
# Epoch: 896/1000 | Batch 020/040 | Cost: 139556.0000
# Time elapsed: 4.74 min
# Epoch: 897/1000 | Batch 000/040 | Cost: 139613.1875
# Epoch: 897/1000 | Batch 020/040 | Cost: 139694.6094
# Time elapsed: 4.74 min
# Epoch: 898/1000 | Batch 000/040 | Cost: 139568.1406
# Epoch: 898/1000 | Batch 020/040 | Cost: 140090.8750
# Time elapsed: 4.75 min
# Epoch: 899/1000 | Batch 000/040 | Cost: 139679.1719
# Epoch: 899/1000 | Batch 020/040 | Cost: 139651.6562
# Time elapsed: 4.75 min
# Epoch: 900/1000 | Batch 000/040 | Cost: 139625.7812
# Epoch: 900/1000 | Batch 020/040 | Cost: 139523.8906
# Time elapsed: 4.76 min
# Epoch: 901/1000 | Batch 000/040 | Cost: 139502.0938
# Epoch: 901/1000 | Batch 020/040 | Cost: 139591.3125
# Time elapsed: 4.76 min
# Epoch: 902/1000 | Batch 000/040 | Cost: 139738.4531
# Epoch: 902/1000 | Batch 020/040 | Cost: 139591.3125
# Time elapsed: 4.77 min
# Epoch: 903/1000 | Batch 000/040 | Cost: 139483.4219
# Epoch: 903/1000 | Batch 020/040 | Cost: 139566.4219
# Time elapsed: 4.78 min
# Epoch: 904/1000 | Batch 000/040 | Cost: 139529.8906
# Epoch: 904/1000 | Batch 020/040 | Cost: 139455.9062
# Time elapsed: 4.78 min
# Epoch: 905/1000 | Batch 000/040 | Cost: 139452.2188
# Epoch: 905/1000 | Batch 020/040 | Cost: 139936.0156
# Time elapsed: 4.79 min
# Epoch: 906/1000 | Batch 000/040 | Cost: 139612.9375
# Epoch: 906/1000 | Batch 020/040 | Cost: 139503.1719
# Time elapsed: 4.79 min
# Epoch: 907/1000 | Batch 000/040 | Cost: 139488.2344
# Epoch: 907/1000 | Batch 020/040 | Cost: 139549.5938
# Time elapsed: 4.80 min
# Epoch: 908/1000 | Batch 000/040 | Cost: 140089.9844
# Epoch: 908/1000 | Batch 020/040 | Cost: 139534.2188
# Time elapsed: 4.80 min
# Epoch: 909/1000 | Batch 000/040 | Cost: 139616.2344
# Epoch: 909/1000 | Batch 020/040 | Cost: 139571.7031
# Time elapsed: 4.81 min
# Epoch: 910/1000 | Batch 000/040 | Cost: 139458.7812
# Epoch: 910/1000 | Batch 020/040 | Cost: 139408.1875
# Time elapsed: 4.81 min
# Epoch: 911/1000 | Batch 000/040 | Cost: 139541.0625
# Epoch: 911/1000 | Batch 020/040 | Cost: 139633.1406
# Time elapsed: 4.82 min
# Epoch: 912/1000 | Batch 000/040 | Cost: 139659.8906
# Epoch: 912/1000 | Batch 020/040 | Cost: 139544.7656
# Time elapsed: 4.82 min
# Epoch: 913/1000 | Batch 000/040 | Cost: 139669.4219
# Epoch: 913/1000 | Batch 020/040 | Cost: 139602.8125
# Time elapsed: 4.83 min
# Epoch: 914/1000 | Batch 000/040 | Cost: 139468.7656
# Epoch: 914/1000 | Batch 020/040 | Cost: 139538.7344
# Time elapsed: 4.83 min
# Epoch: 915/1000 | Batch 000/040 | Cost: 139465.2969
# Epoch: 915/1000 | Batch 020/040 | Cost: 139421.3906
# Time elapsed: 4.84 min
# Epoch: 916/1000 | Batch 000/040 | Cost: 139927.3125
# Epoch: 916/1000 | Batch 020/040 | Cost: 139670.5469
# Time elapsed: 4.85 min
# Epoch: 917/1000 | Batch 000/040 | Cost: 139515.0156
# Epoch: 917/1000 | Batch 020/040 | Cost: 139545.7188
# Time elapsed: 4.85 min
# Epoch: 918/1000 | Batch 000/040 | Cost: 139466.6250
# Epoch: 918/1000 | Batch 020/040 | Cost: 139424.3906
# Time elapsed: 4.86 min
# Epoch: 919/1000 | Batch 000/040 | Cost: 139443.2969
# Epoch: 919/1000 | Batch 020/040 | Cost: 139475.9844
# Time elapsed: 4.86 min
# Epoch: 920/1000 | Batch 000/040 | Cost: 139416.5156
# Epoch: 920/1000 | Batch 020/040 | Cost: 139534.1406
# Time elapsed: 4.87 min
# Epoch: 921/1000 | Batch 000/040 | Cost: 139502.0469
# Epoch: 921/1000 | Batch 020/040 | Cost: 139515.4688
# Time elapsed: 4.87 min
# Epoch: 922/1000 | Batch 000/040 | Cost: 139410.0938
# Epoch: 922/1000 | Batch 020/040 | Cost: 139577.1250
# Time elapsed: 4.88 min
# Epoch: 923/1000 | Batch 000/040 | Cost: 139545.5625
# Epoch: 923/1000 | Batch 020/040 | Cost: 139410.8594
# Time elapsed: 4.88 min
# Epoch: 924/1000 | Batch 000/040 | Cost: 139509.2031
# Epoch: 924/1000 | Batch 020/040 | Cost: 139604.5156
# Time elapsed: 4.89 min
# Epoch: 925/1000 | Batch 000/040 | Cost: 139684.1719
# Epoch: 925/1000 | Batch 020/040 | Cost: 139829.6562
# Time elapsed: 4.89 min
# Epoch: 926/1000 | Batch 000/040 | Cost: 139716.0156
# Epoch: 926/1000 | Batch 020/040 | Cost: 139571.0781
# Time elapsed: 4.90 min
# Epoch: 927/1000 | Batch 000/040 | Cost: 139446.0938
# Epoch: 927/1000 | Batch 020/040 | Cost: 139398.3438
# Time elapsed: 4.90 min
# Epoch: 928/1000 | Batch 000/040 | Cost: 140713.4844
# Epoch: 928/1000 | Batch 020/040 | Cost: 139404.4844
# Time elapsed: 4.91 min
# Epoch: 929/1000 | Batch 000/040 | Cost: 139501.8750
# Epoch: 929/1000 | Batch 020/040 | Cost: 139664.0938
# Time elapsed: 4.91 min
# Epoch: 930/1000 | Batch 000/040 | Cost: 139692.4375
# Epoch: 930/1000 | Batch 020/040 | Cost: 139453.5000
# Time elapsed: 4.92 min
# Epoch: 931/1000 | Batch 000/040 | Cost: 139438.8281
# Epoch: 931/1000 | Batch 020/040 | Cost: 144765.0469
# Time elapsed: 4.92 min
# Epoch: 932/1000 | Batch 000/040 | Cost: 139536.2656
# Epoch: 932/1000 | Batch 020/040 | Cost: 139528.4531
# Time elapsed: 4.93 min
# Epoch: 933/1000 | Batch 000/040 | Cost: 139515.4219
# Epoch: 933/1000 | Batch 020/040 | Cost: 139355.5312
# Time elapsed: 4.93 min
# Epoch: 934/1000 | Batch 000/040 | Cost: 139427.3594
# Epoch: 934/1000 | Batch 020/040 | Cost: 139517.3438
# Time elapsed: 4.94 min
# Epoch: 935/1000 | Batch 000/040 | Cost: 140252.8594
# Epoch: 935/1000 | Batch 020/040 | Cost: 139546.1875
# Time elapsed: 4.95 min
# Epoch: 936/1000 | Batch 000/040 | Cost: 139512.3438
# Epoch: 936/1000 | Batch 020/040 | Cost: 139690.3281
# Time elapsed: 4.95 min
# Epoch: 937/1000 | Batch 000/040 | Cost: 139619.3438
# Epoch: 937/1000 | Batch 020/040 | Cost: 139481.0000
# Time elapsed: 4.96 min
# Epoch: 938/1000 | Batch 000/040 | Cost: 139440.6562
# Epoch: 938/1000 | Batch 020/040 | Cost: 139433.2969
# Time elapsed: 4.96 min
# Epoch: 939/1000 | Batch 000/040 | Cost: 139410.5781
# Epoch: 939/1000 | Batch 020/040 | Cost: 139475.5469
# Time elapsed: 4.97 min
# Epoch: 940/1000 | Batch 000/040 | Cost: 140007.2500
# Epoch: 940/1000 | Batch 020/040 | Cost: 139572.1875
# Time elapsed: 4.97 min
# Epoch: 941/1000 | Batch 000/040 | Cost: 139475.1719
# Epoch: 941/1000 | Batch 020/040 | Cost: 139405.3906
# Time elapsed: 4.98 min
# Epoch: 942/1000 | Batch 000/040 | Cost: 139450.5156
# Epoch: 942/1000 | Batch 020/040 | Cost: 139411.9062
# Time elapsed: 4.98 min
# Epoch: 943/1000 | Batch 000/040 | Cost: 139471.8594
# Epoch: 943/1000 | Batch 020/040 | Cost: 139395.0625
# Time elapsed: 4.99 min
# Epoch: 944/1000 | Batch 000/040 | Cost: 139420.9531
# Epoch: 944/1000 | Batch 020/040 | Cost: 139499.6562
# Time elapsed: 4.99 min
# Epoch: 945/1000 | Batch 000/040 | Cost: 139410.4844
# Epoch: 945/1000 | Batch 020/040 | Cost: 139359.8438
# Time elapsed: 5.00 min
# Epoch: 946/1000 | Batch 000/040 | Cost: 139551.7812
# Epoch: 946/1000 | Batch 020/040 | Cost: 139503.9375
# Time elapsed: 5.00 min
# Epoch: 947/1000 | Batch 000/040 | Cost: 139472.7500
# Epoch: 947/1000 | Batch 020/040 | Cost: 139472.2344
# Time elapsed: 5.01 min
# Epoch: 948/1000 | Batch 000/040 | Cost: 139383.4375
# Epoch: 948/1000 | Batch 020/040 | Cost: 139395.2656
# Time elapsed: 5.01 min
# Epoch: 949/1000 | Batch 000/040 | Cost: 139417.0312
# Epoch: 949/1000 | Batch 020/040 | Cost: 139494.3125
# Time elapsed: 5.02 min
# Epoch: 950/1000 | Batch 000/040 | Cost: 139436.0781
# Epoch: 950/1000 | Batch 020/040 | Cost: 139383.5000
# Time elapsed: 5.02 min
# Epoch: 951/1000 | Batch 000/040 | Cost: 139487.8125
# Epoch: 951/1000 | Batch 020/040 | Cost: 139619.6875
# Time elapsed: 5.03 min
# Epoch: 952/1000 | Batch 000/040 | Cost: 139504.6406
# Epoch: 952/1000 | Batch 020/040 | Cost: 139635.1875
# Time elapsed: 5.03 min
# Epoch: 953/1000 | Batch 000/040 | Cost: 139528.3125
# Epoch: 953/1000 | Batch 020/040 | Cost: 139479.1094
# Time elapsed: 5.04 min
# Epoch: 954/1000 | Batch 000/040 | Cost: 139400.7656
# Epoch: 954/1000 | Batch 020/040 | Cost: 139396.8594
# Time elapsed: 5.04 min
# Epoch: 955/1000 | Batch 000/040 | Cost: 139570.2344
# Epoch: 955/1000 | Batch 020/040 | Cost: 139308.7188
# Time elapsed: 5.05 min
# Epoch: 956/1000 | Batch 000/040 | Cost: 139414.9688
# Epoch: 956/1000 | Batch 020/040 | Cost: 139469.8594
# Time elapsed: 5.06 min
# Epoch: 957/1000 | Batch 000/040 | Cost: 139456.2812
# Epoch: 957/1000 | Batch 020/040 | Cost: 139382.3438
# Time elapsed: 5.06 min
# Epoch: 958/1000 | Batch 000/040 | Cost: 139455.1719
# Epoch: 958/1000 | Batch 020/040 | Cost: 139554.6719
# Time elapsed: 5.07 min
# Epoch: 959/1000 | Batch 000/040 | Cost: 139421.0312
# Epoch: 959/1000 | Batch 020/040 | Cost: 139382.7812
# Time elapsed: 5.07 min
# Epoch: 960/1000 | Batch 000/040 | Cost: 140754.7812
# Epoch: 960/1000 | Batch 020/040 | Cost: 139380.1719
# Time elapsed: 5.08 min
# Epoch: 961/1000 | Batch 000/040 | Cost: 139391.0000
# Epoch: 961/1000 | Batch 020/040 | Cost: 139389.1719
# Time elapsed: 5.08 min
# Epoch: 962/1000 | Batch 000/040 | Cost: 139408.6094
# Epoch: 962/1000 | Batch 020/040 | Cost: 139360.0781
# Time elapsed: 5.09 min
# Epoch: 963/1000 | Batch 000/040 | Cost: 139481.5312
# Epoch: 963/1000 | Batch 020/040 | Cost: 139424.9062
# Time elapsed: 5.09 min
# Epoch: 964/1000 | Batch 000/040 | Cost: 139446.7344
# Epoch: 964/1000 | Batch 020/040 | Cost: 139470.1562
# Time elapsed: 5.10 min
# Epoch: 965/1000 | Batch 000/040 | Cost: 139525.4531
# Epoch: 965/1000 | Batch 020/040 | Cost: 139439.9062
# Time elapsed: 5.10 min
# Epoch: 966/1000 | Batch 000/040 | Cost: 139418.9688
# Epoch: 966/1000 | Batch 020/040 | Cost: 139347.1406
# Time elapsed: 5.11 min
# Epoch: 967/1000 | Batch 000/040 | Cost: 139459.3594
# Epoch: 967/1000 | Batch 020/040 | Cost: 139422.2031
# Time elapsed: 5.11 min
# Epoch: 968/1000 | Batch 000/040 | Cost: 139443.0312
# Epoch: 968/1000 | Batch 020/040 | Cost: 139473.2188
# Time elapsed: 5.12 min
# Epoch: 969/1000 | Batch 000/040 | Cost: 139451.7188
# Epoch: 969/1000 | Batch 020/040 | Cost: 139429.8906
# Time elapsed: 5.12 min
# Epoch: 970/1000 | Batch 000/040 | Cost: 139430.7969
# Epoch: 970/1000 | Batch 020/040 | Cost: 139435.5781
# Time elapsed: 5.13 min
# Epoch: 971/1000 | Batch 000/040 | Cost: 139399.7969
# Epoch: 971/1000 | Batch 020/040 | Cost: 139405.0000
# Time elapsed: 5.13 min
# Epoch: 972/1000 | Batch 000/040 | Cost: 139548.9062
# Epoch: 972/1000 | Batch 020/040 | Cost: 139496.6094
# Time elapsed: 5.14 min
# Epoch: 973/1000 | Batch 000/040 | Cost: 139442.7969
# Epoch: 973/1000 | Batch 020/040 | Cost: 139357.8594
# Time elapsed: 5.14 min
# Epoch: 974/1000 | Batch 000/040 | Cost: 139438.0625
# Epoch: 974/1000 | Batch 020/040 | Cost: 139359.8594
# Time elapsed: 5.15 min
# Epoch: 975/1000 | Batch 000/040 | Cost: 139471.9688
# Epoch: 975/1000 | Batch 020/040 | Cost: 139454.2812
# Time elapsed: 5.16 min
# Epoch: 976/1000 | Batch 000/040 | Cost: 139367.1562
# Epoch: 976/1000 | Batch 020/040 | Cost: 139347.8438
# Time elapsed: 5.16 min
# Epoch: 977/1000 | Batch 000/040 | Cost: 139447.6719
# Epoch: 977/1000 | Batch 020/040 | Cost: 139465.0469
# Time elapsed: 5.17 min
# Epoch: 978/1000 | Batch 000/040 | Cost: 139401.3438
# Epoch: 978/1000 | Batch 020/040 | Cost: 139448.2031
# Time elapsed: 5.17 min
# Epoch: 979/1000 | Batch 000/040 | Cost: 139502.8281
# Epoch: 979/1000 | Batch 020/040 | Cost: 139446.2188
# Time elapsed: 5.18 min
# Epoch: 980/1000 | Batch 000/040 | Cost: 139424.2188
# Epoch: 980/1000 | Batch 020/040 | Cost: 139388.5625
# Time elapsed: 5.18 min
# Epoch: 981/1000 | Batch 000/040 | Cost: 139504.8281
# Epoch: 981/1000 | Batch 020/040 | Cost: 139331.3594
# Time elapsed: 5.19 min
# Epoch: 982/1000 | Batch 000/040 | Cost: 139671.9844
# Epoch: 982/1000 | Batch 020/040 | Cost: 139434.5312
# Time elapsed: 5.19 min
# Epoch: 983/1000 | Batch 000/040 | Cost: 139377.3281
# Epoch: 983/1000 | Batch 020/040 | Cost: 139383.5625
# Time elapsed: 5.20 min
# Epoch: 984/1000 | Batch 000/040 | Cost: 139353.8906
# Epoch: 984/1000 | Batch 020/040 | Cost: 139404.0781
# Time elapsed: 5.20 min
# Epoch: 985/1000 | Batch 000/040 | Cost: 139418.2500
# Epoch: 985/1000 | Batch 020/040 | Cost: 139457.4688
# Time elapsed: 5.21 min
# Epoch: 986/1000 | Batch 000/040 | Cost: 139379.0781
# Epoch: 986/1000 | Batch 020/040 | Cost: 139414.3594
# Time elapsed: 5.21 min
# Epoch: 987/1000 | Batch 000/040 | Cost: 139310.3594
# Epoch: 987/1000 | Batch 020/040 | Cost: 139330.1250
# Time elapsed: 5.22 min
# Epoch: 988/1000 | Batch 000/040 | Cost: 139438.0156
# Epoch: 988/1000 | Batch 020/040 | Cost: 139481.5156
# Time elapsed: 5.22 min
# Epoch: 989/1000 | Batch 000/040 | Cost: 139420.4531
# Epoch: 989/1000 | Batch 020/040 | Cost: 139351.5156
# Time elapsed: 5.23 min
# Epoch: 990/1000 | Batch 000/040 | Cost: 139339.1250
# Epoch: 990/1000 | Batch 020/040 | Cost: 139412.5312
# Time elapsed: 5.23 min
# Epoch: 991/1000 | Batch 000/040 | Cost: 139372.5469
# Epoch: 991/1000 | Batch 020/040 | Cost: 139378.6562
# Time elapsed: 5.24 min
# Epoch: 992/1000 | Batch 000/040 | Cost: 139366.2344
# Epoch: 992/1000 | Batch 020/040 | Cost: 139332.4219
# Time elapsed: 5.24 min
# Epoch: 993/1000 | Batch 000/040 | Cost: 139422.0156
# Epoch: 993/1000 | Batch 020/040 | Cost: 139354.2812
# Time elapsed: 5.25 min
# Epoch: 994/1000 | Batch 000/040 | Cost: 139477.3281
# Epoch: 994/1000 | Batch 020/040 | Cost: 139485.1562
# Time elapsed: 5.26 min
# Epoch: 995/1000 | Batch 000/040 | Cost: 139523.8594
# Epoch: 995/1000 | Batch 020/040 | Cost: 139408.4219
# Time elapsed: 5.26 min
# Epoch: 996/1000 | Batch 000/040 | Cost: 139436.5469
# Epoch: 996/1000 | Batch 020/040 | Cost: 139389.8750
# Time elapsed: 5.27 min
# Epoch: 997/1000 | Batch 000/040 | Cost: 139424.9844
# Epoch: 997/1000 | Batch 020/040 | Cost: 139517.7656
# Time elapsed: 5.27 min
# Epoch: 998/1000 | Batch 000/040 | Cost: 139413.2031
# Epoch: 998/1000 | Batch 020/040 | Cost: 139330.9375
# Time elapsed: 5.28 min
# Epoch: 999/1000 | Batch 000/040 | Cost: 139338.7656
# Epoch: 999/1000 | Batch 020/040 | Cost: 139461.4375
# Time elapsed: 5.28 min
# Epoch: 1000/1000 | Batch 000/040 | Cost: 139464.8594
# Epoch: 1000/1000 | Batch 020/040 | Cost: 139484.5938
# Time elapsed: 5.29 min
# Total Training Time: 5.29 min

# %%
state = {'net':model.state_dict(), 'optimizer':optimizer.state_dict(), 'epoch':epoch }
dir_name = 'model_cnn' + str(epoch) + '.pth'
torch.save(state, dir_name)
print (dir_name)
# Out:
# model_cnn999.pth

# %% [markdown]
# # Evaluation

# %% [markdown]
# ### Reconstruction

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['savefig.dpi'] = 120
plt.rcParams['figure.dpi'] = 120

# from sklearn.manifold import TSNE
from sklearn.decomposition import TruncatedSVD

z_run = z_mean.to(torch.device('cpu'))
z_run = z_run.detach().numpy()
PCA_model = TruncatedSVD(n_components=3).fit(z_run)
z_run_reduced = PCA_model.transform(z_run)
ground_truth = targets.to(torch.device('cpu'))
for k in range(batch_size):
    if ground_truth[k] ==1:
#z_mean, z_log_var, encoded, decoded = model(features, targets)
        plot1 = plt.scatter(z_run_reduced[k, 0], z_run_reduced[k, 1], c='b', marker='*', linewidths=0)
    else:
        plot2 = plt.scatter(z_run_reduced[k, 0], z_run_reduced[k, 1], c='r', marker='o', linewidths=0)        
plt.legend([plot1, plot2],('normal','abnormal'), loc='best')
plt.title('PCA on z_run')
plt.grid()
plt.show()

# %%
def data_to_real(inputdata):
    inputdata = inputdata * (inputdata.max()-inputdata.min()) + inputdata.min()
#    inputdata = 2.0 * inputdata - 1.0
    return inputdata

# %%
features1 = features.view(-1,28*28)
input_data = features1.to(torch.device('cpu'))
input_data = input_data.detach().numpy()
input_data = data_to_real(input_data)
input_data = input_data[:,:783]
de = model.decoder(z_mean, targets) # replace decoded by z_mean

decoded_data = de.to(torch.device('cpu'))
decoded_data = decoded_data.view(-1,28*28)
decoded_data = decoded_data.detach().numpy()
decoded_data = data_to_real(decoded_data)
decoded_data = decoded_data[:,:783]
idxx = np.random.randint(0,batch_size-1)
plt.plot(input_data[idxx],'b')
plt.plot(decoded_data[idxx],'r')
plt.grid()
plt.show()

# %% [markdown]
# ### New random-conditional images

# %%
for i in range(2):
    labels = torch.tensor([i]*batch_size).to(device)
    n_images = labels.size()[0]
    rand_features = torch.randn(n_images, num_latent).to(device)
    new_te = model.decoder(rand_features, labels)
    new_te = new_te.view(-1,28*28)
    curr_te = new_te.detach().to(torch.device('cpu'))
    curr_te = curr_te.detach().numpy()
    curr_te = data_to_real(curr_te)
    curr_te = curr_te[:,:783]
    idxx = np.random.randint(0,batch_size-1)
    plt.plot(curr_te[idxx])
    print('label')
    print(label[idxx])
    plt.grid()
    plt.show()
# Out:
# label
# 1.0
# label
# 1.0

# %%
# %watermark -iv
# Out:
# numpy       1.15.4
# torch       1.0.0
