# %%
import time
import numpy as np
import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision import transforms
from torch.autograd import Variable

if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %%
##########################
### SETTINGS
##########################

# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('Device:', device)

# Hyperparameters ///////////////////////////////////////////////////////////////////////////////////////////
random_seed = 569
learning_rate = 1e-3
num_epochs = 1000
batch_size = 16
#///////////////////////////////////////////////////////////////////////////////////////////

# Architecture
input_size = 28*28
num_classes = 2
#num_features = 784
hidden_size = 200 #500
time_step = 1
num_latent = 256
num_layers = 2
# Out:
# Device: cuda:0

# %%
# load dataset and cut it into train val part and shuffle them
data = np.loadtxt('sync_detection_data.txt')
label = np.loadtxt('sync_detection_label.txt')
N, D = np.shape(data)
label_int = np.zeros((N),dtype=int)
for k in range(N):
    label_int[k] = int(label[k])

ratio_train = 0.2 # 0.7
ind_cut = int(ratio_train * N)
ind = np.random.permutation(N)
train_data = data[ind[:ind_cut]]
train_datas = train_data[:256*40]
val_data = data[ind[ind_cut:]]

train_label = label[ind[:ind_cut]]
train_labels = train_label[:256*40]
val_label = label[ind[ind_cut:]]
print('dataset cutting success!--------------------')
print(np.shape(train_datas))

#mean = np.mean(train_datas)
#var = np.var(train_datas)
#print('preprocess----------------------------------')
#print('mean:')
#print(mean)
#print('sigma:')
#sigma = np.sqrt(var)
#print(sigma)
print('preprocess---------------------------------------------')
# preprocessing is so important
def data_in_one(inputdata):
    inputdata = (inputdata-inputdata.min())/(inputdata.max()-inputdata.min())
#    inputdata = 2.0 * inputdata - 1.0
    return inputdata

train_datas_process = data_in_one(train_data)
mean = np.mean(train_datas_process)
var = np.var(train_datas_process)
print('mean:')
print(mean)
print('sigma:')
sigma = np.sqrt(var)
print(sigma)
# Out:
# dataset cutting success!--------------------
# (3433, 784)
# preprocess---------------------------------------------
# mean:
# 0.4648102095854036
# sigma:
# 0.0862057755231081

# %%
np.shape(val_data)
# Out:
# (13735, 784)

# %%
##########################
### MODEL
##########################
print('model----------------------------------------------------------------------------------')

class VariationalAutoencoder(torch.nn.Module):

    def __init__(self, input_size, hidden_size, num_latent, time_step):
        super(VariationalAutoencoder, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.time_step = time_step
        self.encoder_lstm = torch.nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
#        self.fc = nn.Linear(hidden_size, num_classes)        
        ### ENCODER
#        self.hidden_1 = torch.nn.Linear(num_features, num_hidden_1)
        self.z_mean = torch.nn.Linear(hidden_size, num_latent)
        # in the original paper (Kingma & Welling 2015, we use
        # have a z_mean and z_var, but the problem is that
        # the z_var can be negative, which would cause issues
        # in the log later. Hence we assume that latent vector
        # has a z_mean and z_log_var component, and when we need
        # the regular variance or std_dev, we simply use 
        # an exponential function
        self.z_log_var = torch.nn.Linear(hidden_size, num_latent)
        
        
        ### DECODER
        self.linear_3 = torch.nn.Linear(num_latent, hidden_size*self.time_step)
        self.decoder_lstm = torch.nn.LSTM(hidden_size, input_size*time_step, num_layers, batch_first=True)

#        self.linear_4 = torch.nn.Linear(num_hidden_1, num_features)

    def reparameterize(self, z_mu, z_log_var):
        # Sample epsilon from standard normal distribution
        eps = torch.randn(z_mu.size(0), z_mu.size(1)).to(device)
        # note that log(x^2) = 2*log(x); hence divide by 2 to get std_dev
        # i.e., std_dev = exp(log(std_dev^2)/2) = exp(log(var)/2)
        z = z_mu + eps * torch.exp(z_log_var/2.) 
        return z
        
    def encoder(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        x,_ = self.encoder_lstm(x, (h0, c0))
        x = x[:, -1, :]
        x = x.view(-1,self.hidden_size)
        z_mean = self.z_mean(x)
#        z_mean = F.leaky_relu(z_mean, negative_slope=0.0001)
        z_log_var = self.z_log_var(x)
#        z_log_var = F.leaky_relu(z_log_var, negative_slope=0.0001)
        encoded = self.reparameterize(z_mean, z_log_var)
        return z_mean, z_log_var, encoded
    
    def decoder(self, encoded):
        x = self.linear_3(encoded)
#        x = F.leaky_relu(x, negative_slope=0.0001)
        x = x.view(-1,self.time_step, self.hidden_size)
        h1 = torch.zeros(self.num_layers, x.size(0), self.input_size*self.time_step).to(device) 
        c1 = torch.zeros(self.num_layers, x.size(0), self.input_size*self.time_step).to(device)
        x,_ = self.decoder_lstm(x,(h1,c1))
        x = x[:,-1,:]
        x = torch.sigmoid(x) #0~1
        decoded = x.contiguous().view(-1,self.time_step,self.input_size)
        return decoded

    def forward(self, x):
        
        z_mean, z_log_var, encoded = self.encoder(x)
        decoded = self.decoder(encoded)
#        decoded = decoded.contiguous().view(-1,784)
        return z_mean, z_log_var, encoded, decoded

    
torch.manual_seed(random_seed)
model = VariationalAutoencoder(input_size, hidden_size, num_latent, time_step)
model = model.to(device)
    
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# model----------------------------------------------------------------------------------

# %%
# dir_name = 'model_43.pth'
resume_flag = False
if (resume_flag==True):
    checkpoint = torch.load(dir_name)
    model.load_state_dict(checkpoint['net'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    start_epoch = checkpoint['epoch'] + 1
else:    
    start_epoch = 0

# %%
print('training ----------------------------------------------------------')
start_time = time.time()
iters = int(256*40/batch_size)
for epoch in range(start_epoch,num_epochs):
    for batch_idx in range(iters):
        features = train_datas_process[batch_idx*batch_size:(batch_idx+1)*batch_size]
#        targets = train_labels[batch_idx*batch_size:(batch_idx+1)*batch_size]
#        targets = np.transpose(targets)
        features = torch.from_numpy(features)
#        targets = torch.from_numpy(targets)
        features = features.to(device,torch.float32)
        features = features.view(-1, time_step, input_size)
        f = Variable(features)
#        targets = targets.to(device,dtype=torch.int64)

        ### FORWARD AND BACK PROP
        z_mean, z_log_var, encoded, decoded = model(f)

        # cost = reconstruction loss + Kullback-Leibler divergence
        kl_divergence = (0.5 * (z_mean**2 + 
                                torch.exp(z_log_var) - z_log_var - 1)).sum()
        
        # add condition
#        x_con = torch.cat((features, to_onehot(targets, num_classes, device)), dim=1)
        
        pixelwise_bce = F.binary_cross_entropy(decoded, features, reduction='sum')
#        pixelwise_bce = 0.0
        cost = kl_divergence + pixelwise_bce
        optimizer.zero_grad()
        cost.backward()
        
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 40:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | kl_divergence: %.4f | pixelwise_bce: %.4f | Cost: %.4f'  
                   %(epoch+1, num_epochs, batch_idx, 
                     iters, kl_divergence, pixelwise_bce, cost))
        
    print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
    
print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
# Out:
# training ----------------------------------------------------------
# Epoch: 001/1000 | Batch 000/640 | kl_divergence: 5.7703 | pixelwise_bce: 8694.8574 | Cost: 8700.6279
# Epoch: 001/1000 | Batch 040/640 | kl_divergence: 1.7827 | pixelwise_bce: 8667.5303 | Cost: 8669.3135
# Epoch: 001/1000 | Batch 080/640 | kl_divergence: 13.8069 | pixelwise_bce: 8592.1641 | Cost: 8605.9707
# Epoch: 001/1000 | Batch 120/640 | kl_divergence: 35.3035 | pixelwise_bce: 8517.6826 | Cost: 8552.9863
# Epoch: 001/1000 | Batch 160/640 | kl_divergence: 21.7773 | pixelwise_bce: 8602.9297 | Cost: 8624.7070
# Epoch: 001/1000 | Batch 200/640 | kl_divergence: 10.0195 | pixelwise_bce: 8665.9600 | Cost: 8675.9795
# Epoch: 001/1000 | Batch 240/640 | kl_divergence: 12.6612 | pixelwise_bce: 8665.1709 | Cost: 8677.8320
# Epoch: 001/1000 | Batch 280/640 | kl_divergence: 10.5909 | pixelwise_bce: 8649.9688 | Cost: 8660.5596
# Epoch: 001/1000 | Batch 320/640 | kl_divergence: 22.7979 | pixelwise_bce: 8527.1074 | Cost: 8549.9053
# Epoch: 001/1000 | Batch 360/640 | kl_divergence: 17.7262 | pixelwise_bce: 8629.6602 | Cost: 8647.3867
# Epoch: 001/1000 | Batch 400/640 | kl_divergence: 14.4000 | pixelwise_bce: 8694.6572 | Cost: 8709.0576
# Epoch: 001/1000 | Batch 440/640 | kl_divergence: 35.0666 | pixelwise_bce: 8496.1279 | Cost: 8531.1943
# Epoch: 001/1000 | Batch 480/640 | kl_divergence: 21.2875 | pixelwise_bce: 8604.9473 | Cost: 8626.2344
# Epoch: 001/1000 | Batch 520/640 | kl_divergence: 18.5253 | pixelwise_bce: 8638.7783 | Cost: 8657.3037
# Epoch: 001/1000 | Batch 560/640 | kl_divergence: 16.3392 | pixelwise_bce: 8611.5205 | Cost: 8627.8594
# Epoch: 001/1000 | Batch 600/640 | kl_divergence: 18.8292 | pixelwise_bce: 8596.3701 | Cost: 8615.1992
# Time elapsed: 0.09 min
# Epoch: 002/1000 | Batch 000/640 | kl_divergence: 21.3130 | pixelwise_bce: 8574.2354 | Cost: 8595.5488
# Epoch: 002/1000 | Batch 040/640 | kl_divergence: 21.6656 | pixelwise_bce: 8621.0449 | Cost: 8642.7109
# Epoch: 002/1000 | Batch 080/640 | kl_divergence: 18.5926 | pixelwise_bce: 8603.5879 | Cost: 8622.1807
# Epoch: 002/1000 | Batch 120/640 | kl_divergence: 30.3580 | pixelwise_bce: 8526.4697 | Cost: 8556.8281
# Epoch: 002/1000 | Batch 160/640 | kl_divergence: 18.6860 | pixelwise_bce: 8579.1953 | Cost: 8597.8809
# Epoch: 002/1000 | Batch 200/640 | kl_divergence: 13.0919 | pixelwise_bce: 8662.9590 | Cost: 8676.0508
# Epoch: 002/1000 | Batch 240/640 | kl_divergence: 14.0990 | pixelwise_bce: 8668.9492 | Cost: 8683.0479
# Epoch: 002/1000 | Batch 280/640 | kl_divergence: 14.0089 | pixelwise_bce: 8650.3008 | Cost: 8664.3096
# Epoch: 002/1000 | Batch 320/640 | kl_divergence: 36.8985 | pixelwise_bce: 8515.8887 | Cost: 8552.7871
# Epoch: 002/1000 | Batch 360/640 | kl_divergence: 15.6917 | pixelwise_bce: 8628.1260 | Cost: 8643.8174
# Epoch: 002/1000 | Batch 400/640 | kl_divergence: 8.5580 | pixelwise_bce: 8679.9746 | Cost: 8688.5322
# Epoch: 002/1000 | Batch 440/640 | kl_divergence: 30.8742 | pixelwise_bce: 8502.9883 | Cost: 8533.8623
# Epoch: 002/1000 | Batch 480/640 | kl_divergence: 23.4333 | pixelwise_bce: 8611.4551 | Cost: 8634.8887
# Epoch: 002/1000 | Batch 520/640 | kl_divergence: 12.7912 | pixelwise_bce: 8649.0449 | Cost: 8661.8359
# Epoch: 002/1000 | Batch 560/640 | kl_divergence: 16.4097 | pixelwise_bce: 8618.4414 | Cost: 8634.8516
# Epoch: 002/1000 | Batch 600/640 | kl_divergence: 22.1225 | pixelwise_bce: 8610.2617 | Cost: 8632.3838
# Time elapsed: 0.18 min
# Epoch: 003/1000 | Batch 000/640 | kl_divergence: 21.1321 | pixelwise_bce: 8549.1191 | Cost: 8570.2510
# Epoch: 003/1000 | Batch 040/640 | kl_divergence: 22.5114 | pixelwise_bce: 8623.1133 | Cost: 8645.6250
# Epoch: 003/1000 | Batch 080/640 | kl_divergence: 17.3172 | pixelwise_bce: 8572.2979 | Cost: 8589.6152
# Epoch: 003/1000 | Batch 120/640 | kl_divergence: 28.4283 | pixelwise_bce: 8518.1328 | Cost: 8546.5615
# Epoch: 003/1000 | Batch 160/640 | kl_divergence: 23.8058 | pixelwise_bce: 8583.9053 | Cost: 8607.7109
# Epoch: 003/1000 | Batch 200/640 | kl_divergence: 14.8828 | pixelwise_bce: 8652.4863 | Cost: 8667.3691
# Epoch: 003/1000 | Batch 240/640 | kl_divergence: 14.6059 | pixelwise_bce: 8641.8330 | Cost: 8656.4385
# Epoch: 003/1000 | Batch 280/640 | kl_divergence: 13.6047 | pixelwise_bce: 8661.3799 | Cost: 8674.9844
# Epoch: 003/1000 | Batch 320/640 | kl_divergence: 29.5510 | pixelwise_bce: 8496.1758 | Cost: 8525.7266
# Epoch: 003/1000 | Batch 360/640 | kl_divergence: 15.8927 | pixelwise_bce: 8616.0908 | Cost: 8631.9834
# Epoch: 003/1000 | Batch 400/640 | kl_divergence: 10.6083 | pixelwise_bce: 8659.4150 | Cost: 8670.0234
# Epoch: 003/1000 | Batch 440/640 | kl_divergence: 34.7397 | pixelwise_bce: 8493.7197 | Cost: 8528.4590
# Epoch: 003/1000 | Batch 480/640 | kl_divergence: 17.2474 | pixelwise_bce: 8612.7852 | Cost: 8630.0322
# Epoch: 003/1000 | Batch 520/640 | kl_divergence: 15.0917 | pixelwise_bce: 8624.8730 | Cost: 8639.9648
# Epoch: 003/1000 | Batch 560/640 | kl_divergence: 21.0001 | pixelwise_bce: 8617.2793 | Cost: 8638.2793
# Epoch: 003/1000 | Batch 600/640 | kl_divergence: 34.7915 | pixelwise_bce: 8619.4463 | Cost: 8654.2373
# Time elapsed: 0.27 min
# Epoch: 004/1000 | Batch 000/640 | kl_divergence: 25.6660 | pixelwise_bce: 8571.0410 | Cost: 8596.7070
# Epoch: 004/1000 | Batch 040/640 | kl_divergence: 20.8423 | pixelwise_bce: 8607.9512 | Cost: 8628.7939
# Epoch: 004/1000 | Batch 080/640 | kl_divergence: 20.7824 | pixelwise_bce: 8575.5098 | Cost: 8596.2920
# Epoch: 004/1000 | Batch 120/640 | kl_divergence: 33.9845 | pixelwise_bce: 8501.9150 | Cost: 8535.8994
# Epoch: 004/1000 | Batch 160/640 | kl_divergence: 16.9183 | pixelwise_bce: 8570.2402 | Cost: 8587.1582
# Epoch: 004/1000 | Batch 200/640 | kl_divergence: 17.4322 | pixelwise_bce: 8649.4863 | Cost: 8666.9189
# Epoch: 004/1000 | Batch 240/640 | kl_divergence: 24.1508 | pixelwise_bce: 8660.5986 | Cost: 8684.7490
# Epoch: 004/1000 | Batch 280/640 | kl_divergence: 13.4523 | pixelwise_bce: 8668.4932 | Cost: 8681.9453
# Epoch: 004/1000 | Batch 320/640 | kl_divergence: 29.4916 | pixelwise_bce: 8494.2871 | Cost: 8523.7783
# Epoch: 004/1000 | Batch 360/640 | kl_divergence: 14.9962 | pixelwise_bce: 8619.0859 | Cost: 8634.0820
# Epoch: 004/1000 | Batch 400/640 | kl_divergence: 12.0945 | pixelwise_bce: 8701.3359 | Cost: 8713.4307
# Epoch: 004/1000 | Batch 440/640 | kl_divergence: 35.4498 | pixelwise_bce: 8518.5518 | Cost: 8554.0020
# Epoch: 004/1000 | Batch 480/640 | kl_divergence: 22.6732 | pixelwise_bce: 8598.5205 | Cost: 8621.1934
# Epoch: 004/1000 | Batch 520/640 | kl_divergence: 25.9298 | pixelwise_bce: 8653.3496 | Cost: 8679.2793
# Epoch: 004/1000 | Batch 560/640 | kl_divergence: 17.0968 | pixelwise_bce: 8642.2363 | Cost: 8659.3330
# Epoch: 004/1000 | Batch 600/640 | kl_divergence: 25.6108 | pixelwise_bce: 8606.3271 | Cost: 8631.9375
# Time elapsed: 0.37 min
# Epoch: 005/1000 | Batch 000/640 | kl_divergence: 22.0409 | pixelwise_bce: 8544.9609 | Cost: 8567.0020
# Epoch: 005/1000 | Batch 040/640 | kl_divergence: 21.3604 | pixelwise_bce: 8619.6670 | Cost: 8641.0273
# Epoch: 005/1000 | Batch 080/640 | kl_divergence: 20.7093 | pixelwise_bce: 8585.3320 | Cost: 8606.0410
# Epoch: 005/1000 | Batch 120/640 | kl_divergence: 35.4659 | pixelwise_bce: 8501.5371 | Cost: 8537.0029
# Epoch: 005/1000 | Batch 160/640 | kl_divergence: 24.5439 | pixelwise_bce: 8600.7129 | Cost: 8625.2568
# Epoch: 005/1000 | Batch 200/640 | kl_divergence: 18.9431 | pixelwise_bce: 8683.5996 | Cost: 8702.5430
# Epoch: 005/1000 | Batch 240/640 | kl_divergence: 19.0912 | pixelwise_bce: 8633.7979 | Cost: 8652.8887
# Epoch: 005/1000 | Batch 280/640 | kl_divergence: 18.1850 | pixelwise_bce: 8668.2832 | Cost: 8686.4678
# Epoch: 005/1000 | Batch 320/640 | kl_divergence: 28.9041 | pixelwise_bce: 8500.7783 | Cost: 8529.6826
# Epoch: 005/1000 | Batch 360/640 | kl_divergence: 17.1577 | pixelwise_bce: 8599.4199 | Cost: 8616.5781
# Epoch: 005/1000 | Batch 400/640 | kl_divergence: 14.0007 | pixelwise_bce: 8664.5039 | Cost: 8678.5049
# Epoch: 005/1000 | Batch 440/640 | kl_divergence: 42.0035 | pixelwise_bce: 8486.9932 | Cost: 8528.9971
# Epoch: 005/1000 | Batch 480/640 | kl_divergence: 22.8170 | pixelwise_bce: 8596.6006 | Cost: 8619.4180
# Epoch: 005/1000 | Batch 520/640 | kl_divergence: 15.5131 | pixelwise_bce: 8670.8271 | Cost: 8686.3398
# Epoch: 005/1000 | Batch 560/640 | kl_divergence: 27.1586 | pixelwise_bce: 8594.1006 | Cost: 8621.2588
# Epoch: 005/1000 | Batch 600/640 | kl_divergence: 22.2228 | pixelwise_bce: 8610.9609 | Cost: 8633.1836
# Time elapsed: 0.46 min
# Epoch: 006/1000 | Batch 000/640 | kl_divergence: 29.5747 | pixelwise_bce: 8535.5820 | Cost: 8565.1572
# Epoch: 006/1000 | Batch 040/640 | kl_divergence: 17.8169 | pixelwise_bce: 8625.1484 | Cost: 8642.9658
# Epoch: 006/1000 | Batch 080/640 | kl_divergence: 20.0220 | pixelwise_bce: 8590.6045 | Cost: 8610.6270
# Epoch: 006/1000 | Batch 120/640 | kl_divergence: 32.4671 | pixelwise_bce: 8503.9844 | Cost: 8536.4512
# Epoch: 006/1000 | Batch 160/640 | kl_divergence: 18.3117 | pixelwise_bce: 8596.1797 | Cost: 8614.4912
# Epoch: 006/1000 | Batch 200/640 | kl_divergence: 17.7558 | pixelwise_bce: 8641.4033 | Cost: 8659.1592
# Epoch: 006/1000 | Batch 240/640 | kl_divergence: 18.4295 | pixelwise_bce: 8647.7100 | Cost: 8666.1396
# Epoch: 006/1000 | Batch 280/640 | kl_divergence: 16.2928 | pixelwise_bce: 8673.8770 | Cost: 8690.1699
# Epoch: 006/1000 | Batch 320/640 | kl_divergence: 33.5156 | pixelwise_bce: 8492.5059 | Cost: 8526.0215
# Epoch: 006/1000 | Batch 360/640 | kl_divergence: 13.6428 | pixelwise_bce: 8631.6602 | Cost: 8645.3027
# Epoch: 006/1000 | Batch 400/640 | kl_divergence: 12.3669 | pixelwise_bce: 8672.9551 | Cost: 8685.3223
# Epoch: 006/1000 | Batch 440/640 | kl_divergence: 37.8684 | pixelwise_bce: 8477.7217 | Cost: 8515.5898
# Epoch: 006/1000 | Batch 480/640 | kl_divergence: 21.5759 | pixelwise_bce: 8610.7852 | Cost: 8632.3613
# Epoch: 006/1000 | Batch 520/640 | kl_divergence: 20.4821 | pixelwise_bce: 8646.1240 | Cost: 8666.6064
# Epoch: 006/1000 | Batch 560/640 | kl_divergence: 18.7030 | pixelwise_bce: 8603.5254 | Cost: 8622.2285
# Epoch: 006/1000 | Batch 600/640 | kl_divergence: 27.7454 | pixelwise_bce: 8595.7598 | Cost: 8623.5049
# Time elapsed: 0.55 min
# Epoch: 007/1000 | Batch 000/640 | kl_divergence: 26.0317 | pixelwise_bce: 8559.9160 | Cost: 8585.9473
# Epoch: 007/1000 | Batch 040/640 | kl_divergence: 17.6467 | pixelwise_bce: 8620.2646 | Cost: 8637.9111
# Epoch: 007/1000 | Batch 080/640 | kl_divergence: 20.1944 | pixelwise_bce: 8620.9219 | Cost: 8641.1162
# Epoch: 007/1000 | Batch 120/640 | kl_divergence: 32.4444 | pixelwise_bce: 8570.4336 | Cost: 8602.8779
# Epoch: 007/1000 | Batch 160/640 | kl_divergence: 19.7307 | pixelwise_bce: 8578.9092 | Cost: 8598.6396
# Epoch: 007/1000 | Batch 200/640 | kl_divergence: 18.4511 | pixelwise_bce: 8629.2432 | Cost: 8647.6943
# Epoch: 007/1000 | Batch 240/640 | kl_divergence: 18.5116 | pixelwise_bce: 8634.1035 | Cost: 8652.6152
# Epoch: 007/1000 | Batch 280/640 | kl_divergence: 16.3435 | pixelwise_bce: 8654.3750 | Cost: 8670.7188
# Epoch: 007/1000 | Batch 320/640 | kl_divergence: 30.9494 | pixelwise_bce: 8497.7725 | Cost: 8528.7217
# Epoch: 007/1000 | Batch 360/640 | kl_divergence: 17.4413 | pixelwise_bce: 8603.7217 | Cost: 8621.1631
# Epoch: 007/1000 | Batch 400/640 | kl_divergence: 13.2735 | pixelwise_bce: 8674.1562 | Cost: 8687.4297
# Epoch: 007/1000 | Batch 440/640 | kl_divergence: 35.1867 | pixelwise_bce: 8508.1064 | Cost: 8543.2930
# Epoch: 007/1000 | Batch 480/640 | kl_divergence: 20.6760 | pixelwise_bce: 8601.0459 | Cost: 8621.7217
# Epoch: 007/1000 | Batch 520/640 | kl_divergence: 23.2866 | pixelwise_bce: 8622.4893 | Cost: 8645.7764
# Epoch: 007/1000 | Batch 560/640 | kl_divergence: 19.5800 | pixelwise_bce: 8624.6094 | Cost: 8644.1895
# Epoch: 007/1000 | Batch 600/640 | kl_divergence: 24.1512 | pixelwise_bce: 8603.7461 | Cost: 8627.8975
# Time elapsed: 0.64 min
# Epoch: 008/1000 | Batch 000/640 | kl_divergence: 24.8109 | pixelwise_bce: 8543.8945 | Cost: 8568.7051
# Epoch: 008/1000 | Batch 040/640 | kl_divergence: 27.1111 | pixelwise_bce: 8617.7363 | Cost: 8644.8477
# Epoch: 008/1000 | Batch 080/640 | kl_divergence: 20.4725 | pixelwise_bce: 8604.4609 | Cost: 8624.9336
# Epoch: 008/1000 | Batch 120/640 | kl_divergence: 28.9984 | pixelwise_bce: 8496.4326 | Cost: 8525.4307
# Epoch: 008/1000 | Batch 160/640 | kl_divergence: 21.4175 | pixelwise_bce: 8579.3525 | Cost: 8600.7695
# Epoch: 008/1000 | Batch 200/640 | kl_divergence: 18.0547 | pixelwise_bce: 8642.4766 | Cost: 8660.5312
# Epoch: 008/1000 | Batch 240/640 | kl_divergence: 17.9663 | pixelwise_bce: 8621.4248 | Cost: 8639.3906
# Epoch: 008/1000 | Batch 280/640 | kl_divergence: 17.3268 | pixelwise_bce: 8672.5674 | Cost: 8689.8945
# Epoch: 008/1000 | Batch 320/640 | kl_divergence: 26.3509 | pixelwise_bce: 8519.7363 | Cost: 8546.0869
# Epoch: 008/1000 | Batch 360/640 | kl_divergence: 21.1085 | pixelwise_bce: 8603.2383 | Cost: 8624.3467
# Epoch: 008/1000 | Batch 400/640 | kl_divergence: 11.4579 | pixelwise_bce: 8665.4023 | Cost: 8676.8604
# Epoch: 008/1000 | Batch 440/640 | kl_divergence: 31.8101 | pixelwise_bce: 8494.4297 | Cost: 8526.2402
# Epoch: 008/1000 | Batch 480/640 | kl_divergence: 26.5397 | pixelwise_bce: 8584.4863 | Cost: 8611.0264
# Epoch: 008/1000 | Batch 520/640 | kl_divergence: 17.3323 | pixelwise_bce: 8624.8164 | Cost: 8642.1484
# Epoch: 008/1000 | Batch 560/640 | kl_divergence: 19.1741 | pixelwise_bce: 8604.4795 | Cost: 8623.6533
# Epoch: 008/1000 | Batch 600/640 | kl_divergence: 27.3782 | pixelwise_bce: 8629.2617 | Cost: 8656.6396
# Time elapsed: 0.73 min
# Epoch: 009/1000 | Batch 000/640 | kl_divergence: 30.5320 | pixelwise_bce: 8541.1699 | Cost: 8571.7021
# Epoch: 009/1000 | Batch 040/640 | kl_divergence: 18.8029 | pixelwise_bce: 8606.9043 | Cost: 8625.7070
# Epoch: 009/1000 | Batch 080/640 | kl_divergence: 21.9400 | pixelwise_bce: 8587.6855 | Cost: 8609.6260
# Epoch: 009/1000 | Batch 120/640 | kl_divergence: 29.6081 | pixelwise_bce: 8498.9873 | Cost: 8528.5957
# Epoch: 009/1000 | Batch 160/640 | kl_divergence: 21.5711 | pixelwise_bce: 8568.9131 | Cost: 8590.4844
# Epoch: 009/1000 | Batch 200/640 | kl_divergence: 15.9207 | pixelwise_bce: 8637.7939 | Cost: 8653.7148
# Epoch: 009/1000 | Batch 240/640 | kl_divergence: 17.4944 | pixelwise_bce: 8650.3301 | Cost: 8667.8242
# Epoch: 009/1000 | Batch 280/640 | kl_divergence: 18.1234 | pixelwise_bce: 8646.3135 | Cost: 8664.4365
# Epoch: 009/1000 | Batch 320/640 | kl_divergence: 30.4035 | pixelwise_bce: 8501.2852 | Cost: 8531.6885
# Epoch: 009/1000 | Batch 360/640 | kl_divergence: 15.5426 | pixelwise_bce: 8613.4678 | Cost: 8629.0107
# Epoch: 009/1000 | Batch 400/640 | kl_divergence: 12.6078 | pixelwise_bce: 8667.0713 | Cost: 8679.6787
# Epoch: 009/1000 | Batch 440/640 | kl_divergence: 37.6797 | pixelwise_bce: 8483.2266 | Cost: 8520.9062
# Epoch: 009/1000 | Batch 480/640 | kl_divergence: 24.7246 | pixelwise_bce: 8587.9219 | Cost: 8612.6465
# Epoch: 009/1000 | Batch 520/640 | kl_divergence: 17.2631 | pixelwise_bce: 8635.8242 | Cost: 8653.0869
# Epoch: 009/1000 | Batch 560/640 | kl_divergence: 17.8216 | pixelwise_bce: 8606.1074 | Cost: 8623.9287
# Epoch: 009/1000 | Batch 600/640 | kl_divergence: 24.7065 | pixelwise_bce: 8615.2363 | Cost: 8639.9424
# Time elapsed: 0.82 min
# Epoch: 010/1000 | Batch 000/640 | kl_divergence: 31.1068 | pixelwise_bce: 8559.2305 | Cost: 8590.3369
# Epoch: 010/1000 | Batch 040/640 | kl_divergence: 17.3723 | pixelwise_bce: 8620.4893 | Cost: 8637.8613
# Epoch: 010/1000 | Batch 080/640 | kl_divergence: 21.6892 | pixelwise_bce: 8603.1074 | Cost: 8624.7969
# Epoch: 010/1000 | Batch 120/640 | kl_divergence: 33.0600 | pixelwise_bce: 8506.9160 | Cost: 8539.9756
# Epoch: 010/1000 | Batch 160/640 | kl_divergence: 20.7057 | pixelwise_bce: 8578.6260 | Cost: 8599.3320
# Epoch: 010/1000 | Batch 200/640 | kl_divergence: 19.9690 | pixelwise_bce: 8638.3281 | Cost: 8658.2969
# Epoch: 010/1000 | Batch 240/640 | kl_divergence: 24.6403 | pixelwise_bce: 8648.5107 | Cost: 8673.1514
# Epoch: 010/1000 | Batch 280/640 | kl_divergence: 20.3359 | pixelwise_bce: 8664.8701 | Cost: 8685.2061
# Epoch: 010/1000 | Batch 320/640 | kl_divergence: 32.9522 | pixelwise_bce: 8486.1270 | Cost: 8519.0791
# Epoch: 010/1000 | Batch 360/640 | kl_divergence: 19.6832 | pixelwise_bce: 8607.4336 | Cost: 8627.1172
# Epoch: 010/1000 | Batch 400/640 | kl_divergence: 11.0167 | pixelwise_bce: 8670.3447 | Cost: 8681.3613
# Epoch: 010/1000 | Batch 440/640 | kl_divergence: 35.6824 | pixelwise_bce: 8493.7100 | Cost: 8529.3926
# Epoch: 010/1000 | Batch 480/640 | kl_divergence: 22.0989 | pixelwise_bce: 8616.4922 | Cost: 8638.5908
# Epoch: 010/1000 | Batch 520/640 | kl_divergence: 16.7623 | pixelwise_bce: 8621.1543 | Cost: 8637.9170
# Epoch: 010/1000 | Batch 560/640 | kl_divergence: 19.4218 | pixelwise_bce: 8592.2129 | Cost: 8611.6348
# Epoch: 010/1000 | Batch 600/640 | kl_divergence: 23.3720 | pixelwise_bce: 8621.7324 | Cost: 8645.1045
# Time elapsed: 0.91 min
# Epoch: 011/1000 | Batch 000/640 | kl_divergence: 29.2656 | pixelwise_bce: 8544.6855 | Cost: 8573.9512
# Epoch: 011/1000 | Batch 040/640 | kl_divergence: 20.3146 | pixelwise_bce: 8605.3965 | Cost: 8625.7109
# Epoch: 011/1000 | Batch 080/640 | kl_divergence: 20.0033 | pixelwise_bce: 8600.6689 | Cost: 8620.6719
# Epoch: 011/1000 | Batch 120/640 | kl_divergence: 30.7141 | pixelwise_bce: 8499.7246 | Cost: 8530.4385
# Epoch: 011/1000 | Batch 160/640 | kl_divergence: 28.9788 | pixelwise_bce: 8584.4238 | Cost: 8613.4023
# Epoch: 011/1000 | Batch 200/640 | kl_divergence: 24.7537 | pixelwise_bce: 8640.0186 | Cost: 8664.7725
# Epoch: 011/1000 | Batch 240/640 | kl_divergence: 19.1110 | pixelwise_bce: 8647.1904 | Cost: 8666.3018
# Epoch: 011/1000 | Batch 280/640 | kl_divergence: 13.6526 | pixelwise_bce: 8652.9355 | Cost: 8666.5879
# Epoch: 011/1000 | Batch 320/640 | kl_divergence: 29.5188 | pixelwise_bce: 8498.1240 | Cost: 8527.6426
# Epoch: 011/1000 | Batch 360/640 | kl_divergence: 21.2104 | pixelwise_bce: 8602.8574 | Cost: 8624.0674
# Epoch: 011/1000 | Batch 400/640 | kl_divergence: 14.3128 | pixelwise_bce: 8659.3145 | Cost: 8673.6270
# Epoch: 011/1000 | Batch 440/640 | kl_divergence: 35.7230 | pixelwise_bce: 8481.0322 | Cost: 8516.7549
# Epoch: 011/1000 | Batch 480/640 | kl_divergence: 22.0038 | pixelwise_bce: 8594.4609 | Cost: 8616.4648
# Epoch: 011/1000 | Batch 520/640 | kl_divergence: 16.6136 | pixelwise_bce: 8645.3770 | Cost: 8661.9902
# Epoch: 011/1000 | Batch 560/640 | kl_divergence: 20.8910 | pixelwise_bce: 8603.9102 | Cost: 8624.8008
# Epoch: 011/1000 | Batch 600/640 | kl_divergence: 23.2746 | pixelwise_bce: 8595.2314 | Cost: 8618.5059
# Time elapsed: 1.00 min
# Epoch: 012/1000 | Batch 000/640 | kl_divergence: 29.5122 | pixelwise_bce: 8538.2275 | Cost: 8567.7393
# Epoch: 012/1000 | Batch 040/640 | kl_divergence: 20.9770 | pixelwise_bce: 8620.1650 | Cost: 8641.1416
# Epoch: 012/1000 | Batch 080/640 | kl_divergence: 19.8138 | pixelwise_bce: 8616.0020 | Cost: 8635.8154
# Epoch: 012/1000 | Batch 120/640 | kl_divergence: 31.6972 | pixelwise_bce: 8518.0430 | Cost: 8549.7402
# Epoch: 012/1000 | Batch 160/640 | kl_divergence: 27.1845 | pixelwise_bce: 8565.5439 | Cost: 8592.7285
# Epoch: 012/1000 | Batch 200/640 | kl_divergence: 16.7006 | pixelwise_bce: 8652.4453 | Cost: 8669.1455
# Epoch: 012/1000 | Batch 240/640 | kl_divergence: 17.3380 | pixelwise_bce: 8639.8271 | Cost: 8657.1650
# Epoch: 012/1000 | Batch 280/640 | kl_divergence: 15.5861 | pixelwise_bce: 8640.9775 | Cost: 8656.5635
# Epoch: 012/1000 | Batch 320/640 | kl_divergence: 28.2124 | pixelwise_bce: 8495.8428 | Cost: 8524.0557
# Epoch: 012/1000 | Batch 360/640 | kl_divergence: 18.0204 | pixelwise_bce: 8620.5381 | Cost: 8638.5586
# Epoch: 012/1000 | Batch 400/640 | kl_divergence: 11.7045 | pixelwise_bce: 8682.1514 | Cost: 8693.8555
# Epoch: 012/1000 | Batch 440/640 | kl_divergence: 34.3590 | pixelwise_bce: 8511.7568 | Cost: 8546.1162
# Epoch: 012/1000 | Batch 480/640 | kl_divergence: 29.7440 | pixelwise_bce: 8601.2891 | Cost: 8631.0332
# Epoch: 012/1000 | Batch 520/640 | kl_divergence: 18.0627 | pixelwise_bce: 8639.4512 | Cost: 8657.5137
# Epoch: 012/1000 | Batch 560/640 | kl_divergence: 20.8033 | pixelwise_bce: 8610.9395 | Cost: 8631.7432
# Epoch: 012/1000 | Batch 600/640 | kl_divergence: 32.0451 | pixelwise_bce: 8634.2500 | Cost: 8666.2949
# Time elapsed: 1.10 min
# Epoch: 013/1000 | Batch 000/640 | kl_divergence: 25.8179 | pixelwise_bce: 8554.2695 | Cost: 8580.0879
# Epoch: 013/1000 | Batch 040/640 | kl_divergence: 25.2801 | pixelwise_bce: 8614.2188 | Cost: 8639.4990
# Epoch: 013/1000 | Batch 080/640 | kl_divergence: 22.4422 | pixelwise_bce: 8582.6816 | Cost: 8605.1240
# Epoch: 013/1000 | Batch 120/640 | kl_divergence: 35.2191 | pixelwise_bce: 8521.3232 | Cost: 8556.5420
# Epoch: 013/1000 | Batch 160/640 | kl_divergence: 18.7574 | pixelwise_bce: 8592.0664 | Cost: 8610.8242
# Epoch: 013/1000 | Batch 200/640 | kl_divergence: 19.1189 | pixelwise_bce: 8658.8906 | Cost: 8678.0098
# Epoch: 013/1000 | Batch 240/640 | kl_divergence: 21.7998 | pixelwise_bce: 8629.3369 | Cost: 8651.1367
# Epoch: 013/1000 | Batch 280/640 | kl_divergence: 17.8400 | pixelwise_bce: 8628.9180 | Cost: 8646.7578
# Epoch: 013/1000 | Batch 320/640 | kl_divergence: 30.0608 | pixelwise_bce: 8482.4023 | Cost: 8512.4629
# Epoch: 013/1000 | Batch 360/640 | kl_divergence: 20.6902 | pixelwise_bce: 8614.6357 | Cost: 8635.3262
# Epoch: 013/1000 | Batch 400/640 | kl_divergence: 16.3623 | pixelwise_bce: 8685.1914 | Cost: 8701.5537
# Epoch: 013/1000 | Batch 440/640 | kl_divergence: 40.9562 | pixelwise_bce: 8471.9326 | Cost: 8512.8887
# Epoch: 013/1000 | Batch 480/640 | kl_divergence: 23.1416 | pixelwise_bce: 8591.1631 | Cost: 8614.3047
# Epoch: 013/1000 | Batch 520/640 | kl_divergence: 19.8978 | pixelwise_bce: 8637.8428 | Cost: 8657.7402
# Epoch: 013/1000 | Batch 560/640 | kl_divergence: 17.7077 | pixelwise_bce: 8603.3955 | Cost: 8621.1035
# Epoch: 013/1000 | Batch 600/640 | kl_divergence: 26.8853 | pixelwise_bce: 8606.1455 | Cost: 8633.0312
# Time elapsed: 1.19 min
# Epoch: 014/1000 | Batch 000/640 | kl_divergence: 32.6598 | pixelwise_bce: 8544.5713 | Cost: 8577.2314
# Epoch: 014/1000 | Batch 040/640 | kl_divergence: 20.1121 | pixelwise_bce: 8605.4395 | Cost: 8625.5518
# Epoch: 014/1000 | Batch 080/640 | kl_divergence: 25.0082 | pixelwise_bce: 8575.1230 | Cost: 8600.1309
# Epoch: 014/1000 | Batch 120/640 | kl_divergence: 35.2108 | pixelwise_bce: 8504.9893 | Cost: 8540.2002
# Epoch: 014/1000 | Batch 160/640 | kl_divergence: 21.9225 | pixelwise_bce: 8608.0820 | Cost: 8630.0049
# Epoch: 014/1000 | Batch 200/640 | kl_divergence: 25.2107 | pixelwise_bce: 8626.4160 | Cost: 8651.6270
# Epoch: 014/1000 | Batch 240/640 | kl_divergence: 20.5076 | pixelwise_bce: 8676.8604 | Cost: 8697.3682
# Epoch: 014/1000 | Batch 280/640 | kl_divergence: 16.2926 | pixelwise_bce: 8657.4844 | Cost: 8673.7773
# Epoch: 014/1000 | Batch 320/640 | kl_divergence: 31.3222 | pixelwise_bce: 8516.8457 | Cost: 8548.1680
# Epoch: 014/1000 | Batch 360/640 | kl_divergence: 19.4530 | pixelwise_bce: 8612.2891 | Cost: 8631.7422
# Epoch: 014/1000 | Batch 400/640 | kl_divergence: 12.8481 | pixelwise_bce: 8668.3711 | Cost: 8681.2188
# Epoch: 014/1000 | Batch 440/640 | kl_divergence: 36.5944 | pixelwise_bce: 8513.5703 | Cost: 8550.1650
# Epoch: 014/1000 | Batch 480/640 | kl_divergence: 22.0217 | pixelwise_bce: 8606.6562 | Cost: 8628.6777
# Epoch: 014/1000 | Batch 520/640 | kl_divergence: 19.3820 | pixelwise_bce: 8632.0547 | Cost: 8651.4365
# Epoch: 014/1000 | Batch 560/640 | kl_divergence: 20.8782 | pixelwise_bce: 8597.9326 | Cost: 8618.8105
# Epoch: 014/1000 | Batch 600/640 | kl_divergence: 25.5211 | pixelwise_bce: 8592.5576 | Cost: 8618.0791
# Time elapsed: 1.28 min
# Epoch: 015/1000 | Batch 000/640 | kl_divergence: 28.2167 | pixelwise_bce: 8541.3604 | Cost: 8569.5771
# Epoch: 015/1000 | Batch 040/640 | kl_divergence: 21.3355 | pixelwise_bce: 8611.6230 | Cost: 8632.9590
# Epoch: 015/1000 | Batch 080/640 | kl_divergence: 22.6300 | pixelwise_bce: 8603.1924 | Cost: 8625.8223
# Epoch: 015/1000 | Batch 120/640 | kl_divergence: 34.6039 | pixelwise_bce: 8513.5195 | Cost: 8548.1230
# Epoch: 015/1000 | Batch 160/640 | kl_divergence: 23.5098 | pixelwise_bce: 8576.4492 | Cost: 8599.9590
# Epoch: 015/1000 | Batch 200/640 | kl_divergence: 22.3448 | pixelwise_bce: 8645.4072 | Cost: 8667.7520
# Epoch: 015/1000 | Batch 240/640 | kl_divergence: 17.7486 | pixelwise_bce: 8638.1982 | Cost: 8655.9473
# Epoch: 015/1000 | Batch 280/640 | kl_divergence: 24.4269 | pixelwise_bce: 8657.5713 | Cost: 8681.9980
# Epoch: 015/1000 | Batch 320/640 | kl_divergence: 28.0707 | pixelwise_bce: 8491.9141 | Cost: 8519.9844
# Epoch: 015/1000 | Batch 360/640 | kl_divergence: 18.4949 | pixelwise_bce: 8602.0117 | Cost: 8620.5068
# Epoch: 015/1000 | Batch 400/640 | kl_divergence: 15.2562 | pixelwise_bce: 8679.0361 | Cost: 8694.2920
# Epoch: 015/1000 | Batch 440/640 | kl_divergence: 37.0155 | pixelwise_bce: 8513.0117 | Cost: 8550.0273
# Epoch: 015/1000 | Batch 480/640 | kl_divergence: 21.5651 | pixelwise_bce: 8581.0430 | Cost: 8602.6084
# Epoch: 015/1000 | Batch 520/640 | kl_divergence: 23.9693 | pixelwise_bce: 8622.4863 | Cost: 8646.4561
# Epoch: 015/1000 | Batch 560/640 | kl_divergence: 19.9292 | pixelwise_bce: 8599.8926 | Cost: 8619.8213
# Epoch: 015/1000 | Batch 600/640 | kl_divergence: 23.8083 | pixelwise_bce: 8609.5068 | Cost: 8633.3154
# Time elapsed: 1.37 min
# Epoch: 016/1000 | Batch 000/640 | kl_divergence: 33.3533 | pixelwise_bce: 8572.9805 | Cost: 8606.3340
# Epoch: 016/1000 | Batch 040/640 | kl_divergence: 20.0328 | pixelwise_bce: 8608.8145 | Cost: 8628.8477
# Epoch: 016/1000 | Batch 080/640 | kl_divergence: 20.5248 | pixelwise_bce: 8582.7119 | Cost: 8603.2363
# Epoch: 016/1000 | Batch 120/640 | kl_divergence: 34.2031 | pixelwise_bce: 8503.6074 | Cost: 8537.8105
# Epoch: 016/1000 | Batch 160/640 | kl_divergence: 23.1466 | pixelwise_bce: 8566.4209 | Cost: 8589.5674
# Epoch: 016/1000 | Batch 200/640 | kl_divergence: 20.1453 | pixelwise_bce: 8649.0664 | Cost: 8669.2119
# Epoch: 016/1000 | Batch 240/640 | kl_divergence: 21.4120 | pixelwise_bce: 8625.9854 | Cost: 8647.3975
# Epoch: 016/1000 | Batch 280/640 | kl_divergence: 17.0251 | pixelwise_bce: 8643.3584 | Cost: 8660.3838
# Epoch: 016/1000 | Batch 320/640 | kl_divergence: 29.9214 | pixelwise_bce: 8480.8242 | Cost: 8510.7451
# Epoch: 016/1000 | Batch 360/640 | kl_divergence: 20.5986 | pixelwise_bce: 8610.1621 | Cost: 8630.7607
# Epoch: 016/1000 | Batch 400/640 | kl_divergence: 13.9391 | pixelwise_bce: 8663.0664 | Cost: 8677.0059
# Epoch: 016/1000 | Batch 440/640 | kl_divergence: 40.1772 | pixelwise_bce: 8474.6260 | Cost: 8514.8027
# Epoch: 016/1000 | Batch 480/640 | kl_divergence: 22.1665 | pixelwise_bce: 8585.8564 | Cost: 8608.0234
# Epoch: 016/1000 | Batch 520/640 | kl_divergence: 16.1752 | pixelwise_bce: 8634.0498 | Cost: 8650.2246
# Epoch: 016/1000 | Batch 560/640 | kl_divergence: 19.8337 | pixelwise_bce: 8610.7783 | Cost: 8630.6123
# Epoch: 016/1000 | Batch 600/640 | kl_divergence: 27.7049 | pixelwise_bce: 8615.9844 | Cost: 8643.6895
# Time elapsed: 1.46 min
# Epoch: 017/1000 | Batch 000/640 | kl_divergence: 29.1491 | pixelwise_bce: 8559.7168 | Cost: 8588.8662
# Epoch: 017/1000 | Batch 040/640 | kl_divergence: 21.1976 | pixelwise_bce: 8603.7490 | Cost: 8624.9463
# Epoch: 017/1000 | Batch 080/640 | kl_divergence: 19.8560 | pixelwise_bce: 8576.2031 | Cost: 8596.0596
# Epoch: 017/1000 | Batch 120/640 | kl_divergence: 35.2586 | pixelwise_bce: 8528.5059 | Cost: 8563.7646
# Epoch: 017/1000 | Batch 160/640 | kl_divergence: 27.2395 | pixelwise_bce: 8610.1680 | Cost: 8637.4072
# Epoch: 017/1000 | Batch 200/640 | kl_divergence: 18.1501 | pixelwise_bce: 8645.2871 | Cost: 8663.4375
# Epoch: 017/1000 | Batch 240/640 | kl_divergence: 17.2088 | pixelwise_bce: 8621.2832 | Cost: 8638.4922
# Epoch: 017/1000 | Batch 280/640 | kl_divergence: 15.9373 | pixelwise_bce: 8639.3643 | Cost: 8655.3018
# Epoch: 017/1000 | Batch 320/640 | kl_divergence: 27.1261 | pixelwise_bce: 8496.9600 | Cost: 8524.0859
# Epoch: 017/1000 | Batch 360/640 | kl_divergence: 21.6124 | pixelwise_bce: 8601.8203 | Cost: 8623.4326
# Epoch: 017/1000 | Batch 400/640 | kl_divergence: 13.0784 | pixelwise_bce: 8667.0186 | Cost: 8680.0967
# Epoch: 017/1000 | Batch 440/640 | kl_divergence: 34.9456 | pixelwise_bce: 8478.8418 | Cost: 8513.7871
# Epoch: 017/1000 | Batch 480/640 | kl_divergence: 24.5490 | pixelwise_bce: 8588.6172 | Cost: 8613.1660
# Epoch: 017/1000 | Batch 520/640 | kl_divergence: 19.4075 | pixelwise_bce: 8617.2842 | Cost: 8636.6914
# Epoch: 017/1000 | Batch 560/640 | kl_divergence: 20.8402 | pixelwise_bce: 8595.1709 | Cost: 8616.0107
# Epoch: 017/1000 | Batch 600/640 | kl_divergence: 27.6713 | pixelwise_bce: 8589.2520 | Cost: 8616.9229
# Time elapsed: 1.55 min
# Epoch: 018/1000 | Batch 000/640 | kl_divergence: 30.1569 | pixelwise_bce: 8555.0742 | Cost: 8585.2314
# Epoch: 018/1000 | Batch 040/640 | kl_divergence: 23.8811 | pixelwise_bce: 8613.1387 | Cost: 8637.0195
# Epoch: 018/1000 | Batch 080/640 | kl_divergence: 20.5851 | pixelwise_bce: 8598.4268 | Cost: 8619.0117
# Epoch: 018/1000 | Batch 120/640 | kl_divergence: 32.4674 | pixelwise_bce: 8495.8613 | Cost: 8528.3291
# Epoch: 018/1000 | Batch 160/640 | kl_divergence: 23.2175 | pixelwise_bce: 8599.3867 | Cost: 8622.6045
# Epoch: 018/1000 | Batch 200/640 | kl_divergence: 16.7302 | pixelwise_bce: 8669.8232 | Cost: 8686.5537
# Epoch: 018/1000 | Batch 240/640 | kl_divergence: 18.9031 | pixelwise_bce: 8654.3076 | Cost: 8673.2109
# Epoch: 018/1000 | Batch 280/640 | kl_divergence: 18.7032 | pixelwise_bce: 8635.4551 | Cost: 8654.1582
# Epoch: 018/1000 | Batch 320/640 | kl_divergence: 31.0542 | pixelwise_bce: 8486.3994 | Cost: 8517.4541
# Epoch: 018/1000 | Batch 360/640 | kl_divergence: 18.6149 | pixelwise_bce: 8601.9951 | Cost: 8620.6104
# Epoch: 018/1000 | Batch 400/640 | kl_divergence: 12.1204 | pixelwise_bce: 8665.6973 | Cost: 8677.8174
# Epoch: 018/1000 | Batch 440/640 | kl_divergence: 36.5882 | pixelwise_bce: 8478.9424 | Cost: 8515.5303
# Epoch: 018/1000 | Batch 480/640 | kl_divergence: 21.7674 | pixelwise_bce: 8594.6709 | Cost: 8616.4385
# Epoch: 018/1000 | Batch 520/640 | kl_divergence: 18.1039 | pixelwise_bce: 8623.6426 | Cost: 8641.7461
# Epoch: 018/1000 | Batch 560/640 | kl_divergence: 24.0501 | pixelwise_bce: 8603.1689 | Cost: 8627.2188
# Epoch: 018/1000 | Batch 600/640 | kl_divergence: 22.7012 | pixelwise_bce: 8584.1250 | Cost: 8606.8262
# Time elapsed: 1.64 min
# Epoch: 019/1000 | Batch 000/640 | kl_divergence: 30.4733 | pixelwise_bce: 8536.6807 | Cost: 8567.1543
# Epoch: 019/1000 | Batch 040/640 | kl_divergence: 21.3411 | pixelwise_bce: 8610.4941 | Cost: 8631.8350
# Epoch: 019/1000 | Batch 080/640 | kl_divergence: 22.1790 | pixelwise_bce: 8579.6777 | Cost: 8601.8564
# Epoch: 019/1000 | Batch 120/640 | kl_divergence: 30.8191 | pixelwise_bce: 8497.2852 | Cost: 8528.1045
# Epoch: 019/1000 | Batch 160/640 | kl_divergence: 23.8494 | pixelwise_bce: 8576.2920 | Cost: 8600.1416
# Epoch: 019/1000 | Batch 200/640 | kl_divergence: 19.1272 | pixelwise_bce: 8647.9434 | Cost: 8667.0703
# Epoch: 019/1000 | Batch 240/640 | kl_divergence: 18.3044 | pixelwise_bce: 8643.2920 | Cost: 8661.5967
# Epoch: 019/1000 | Batch 280/640 | kl_divergence: 16.3384 | pixelwise_bce: 8654.2832 | Cost: 8670.6211
# Epoch: 019/1000 | Batch 320/640 | kl_divergence: 26.1000 | pixelwise_bce: 8479.0635 | Cost: 8505.1631
# Epoch: 019/1000 | Batch 360/640 | kl_divergence: 21.0063 | pixelwise_bce: 8604.2764 | Cost: 8625.2822
# Epoch: 019/1000 | Batch 400/640 | kl_divergence: 12.0512 | pixelwise_bce: 8664.4062 | Cost: 8676.4570
# Epoch: 019/1000 | Batch 440/640 | kl_divergence: 36.3103 | pixelwise_bce: 8480.2715 | Cost: 8516.5820
# Epoch: 019/1000 | Batch 480/640 | kl_divergence: 23.3562 | pixelwise_bce: 8628.6240 | Cost: 8651.9805
# Epoch: 019/1000 | Batch 520/640 | kl_divergence: 20.1170 | pixelwise_bce: 8642.3105 | Cost: 8662.4277
# Epoch: 019/1000 | Batch 560/640 | kl_divergence: 19.3498 | pixelwise_bce: 8612.6387 | Cost: 8631.9883
# Epoch: 019/1000 | Batch 600/640 | kl_divergence: 25.3284 | pixelwise_bce: 8595.7715 | Cost: 8621.0996
# Time elapsed: 1.74 min
# Epoch: 020/1000 | Batch 000/640 | kl_divergence: 31.6595 | pixelwise_bce: 8530.4961 | Cost: 8562.1553
# Epoch: 020/1000 | Batch 040/640 | kl_divergence: 23.1135 | pixelwise_bce: 8613.9990 | Cost: 8637.1123
# Epoch: 020/1000 | Batch 080/640 | kl_divergence: 20.6180 | pixelwise_bce: 8581.0117 | Cost: 8601.6299
# Epoch: 020/1000 | Batch 120/640 | kl_divergence: 27.5735 | pixelwise_bce: 8515.1914 | Cost: 8542.7646
# Epoch: 020/1000 | Batch 160/640 | kl_divergence: 22.9777 | pixelwise_bce: 8583.2549 | Cost: 8606.2324
# Epoch: 020/1000 | Batch 200/640 | kl_divergence: 19.3835 | pixelwise_bce: 8652.7119 | Cost: 8672.0957
# Epoch: 020/1000 | Batch 240/640 | kl_divergence: 17.5450 | pixelwise_bce: 8638.1221 | Cost: 8655.6670
# Epoch: 020/1000 | Batch 280/640 | kl_divergence: 16.6377 | pixelwise_bce: 8660.7617 | Cost: 8677.3994
# Epoch: 020/1000 | Batch 320/640 | kl_divergence: 28.9782 | pixelwise_bce: 8506.0225 | Cost: 8535.0010
# Epoch: 020/1000 | Batch 360/640 | kl_divergence: 18.3672 | pixelwise_bce: 8609.8975 | Cost: 8628.2646
# Epoch: 020/1000 | Batch 400/640 | kl_divergence: 11.7447 | pixelwise_bce: 8662.2422 | Cost: 8673.9873
# Epoch: 020/1000 | Batch 440/640 | kl_divergence: 35.3647 | pixelwise_bce: 8496.6797 | Cost: 8532.0439
# Epoch: 020/1000 | Batch 480/640 | kl_divergence: 32.8745 | pixelwise_bce: 8594.9434 | Cost: 8627.8174
# Epoch: 020/1000 | Batch 520/640 | kl_divergence: 19.0521 | pixelwise_bce: 8619.5059 | Cost: 8638.5576
# Epoch: 020/1000 | Batch 560/640 | kl_divergence: 20.6456 | pixelwise_bce: 8595.7188 | Cost: 8616.3643
# Epoch: 020/1000 | Batch 600/640 | kl_divergence: 26.4248 | pixelwise_bce: 8603.2910 | Cost: 8629.7158
# Time elapsed: 1.83 min
# Epoch: 021/1000 | Batch 000/640 | kl_divergence: 27.1634 | pixelwise_bce: 8554.4307 | Cost: 8581.5938
# Epoch: 021/1000 | Batch 040/640 | kl_divergence: 25.5987 | pixelwise_bce: 8596.6172 | Cost: 8622.2158
# Epoch: 021/1000 | Batch 080/640 | kl_divergence: 20.4187 | pixelwise_bce: 8597.8945 | Cost: 8618.3135
# Epoch: 021/1000 | Batch 120/640 | kl_divergence: 32.0821 | pixelwise_bce: 8507.4727 | Cost: 8539.5547
# Epoch: 021/1000 | Batch 160/640 | kl_divergence: 32.2570 | pixelwise_bce: 8588.6768 | Cost: 8620.9336
# Epoch: 021/1000 | Batch 200/640 | kl_divergence: 17.2478 | pixelwise_bce: 8648.7344 | Cost: 8665.9824
# Epoch: 021/1000 | Batch 240/640 | kl_divergence: 18.4835 | pixelwise_bce: 8658.4375 | Cost: 8676.9209
# Epoch: 021/1000 | Batch 280/640 | kl_divergence: 16.4529 | pixelwise_bce: 8653.4248 | Cost: 8669.8779
# Epoch: 021/1000 | Batch 320/640 | kl_divergence: 27.4820 | pixelwise_bce: 8504.8223 | Cost: 8532.3047
# Epoch: 021/1000 | Batch 360/640 | kl_divergence: 18.3267 | pixelwise_bce: 8609.0938 | Cost: 8627.4209
# Epoch: 021/1000 | Batch 400/640 | kl_divergence: 13.0047 | pixelwise_bce: 8658.7344 | Cost: 8671.7393
# Epoch: 021/1000 | Batch 440/640 | kl_divergence: 32.3148 | pixelwise_bce: 8481.5391 | Cost: 8513.8535
# Epoch: 021/1000 | Batch 480/640 | kl_divergence: 21.7207 | pixelwise_bce: 8596.8662 | Cost: 8618.5869
# Epoch: 021/1000 | Batch 520/640 | kl_divergence: 16.3721 | pixelwise_bce: 8643.0557 | Cost: 8659.4277
# Epoch: 021/1000 | Batch 560/640 | kl_divergence: 19.8449 | pixelwise_bce: 8615.1787 | Cost: 8635.0234
# Epoch: 021/1000 | Batch 600/640 | kl_divergence: 23.0151 | pixelwise_bce: 8584.9580 | Cost: 8607.9727
# Time elapsed: 1.92 min
# Epoch: 022/1000 | Batch 000/640 | kl_divergence: 28.8895 | pixelwise_bce: 8539.0029 | Cost: 8567.8926
# Epoch: 022/1000 | Batch 040/640 | kl_divergence: 17.3357 | pixelwise_bce: 8594.2607 | Cost: 8611.5967
# Epoch: 022/1000 | Batch 080/640 | kl_divergence: 18.7824 | pixelwise_bce: 8574.3701 | Cost: 8593.1523
# Epoch: 022/1000 | Batch 120/640 | kl_divergence: 29.7716 | pixelwise_bce: 8499.8018 | Cost: 8529.5732
# Epoch: 022/1000 | Batch 160/640 | kl_divergence: 22.1778 | pixelwise_bce: 8571.9844 | Cost: 8594.1621
# Epoch: 022/1000 | Batch 200/640 | kl_divergence: 20.2451 | pixelwise_bce: 8637.9814 | Cost: 8658.2266
# Epoch: 022/1000 | Batch 240/640 | kl_divergence: 20.2336 | pixelwise_bce: 8632.8506 | Cost: 8653.0840
# Epoch: 022/1000 | Batch 280/640 | kl_divergence: 18.5558 | pixelwise_bce: 8635.9424 | Cost: 8654.4980
# Epoch: 022/1000 | Batch 320/640 | kl_divergence: 25.2938 | pixelwise_bce: 8492.5615 | Cost: 8517.8555
# Epoch: 022/1000 | Batch 360/640 | kl_divergence: 17.8576 | pixelwise_bce: 8602.2090 | Cost: 8620.0664
# Epoch: 022/1000 | Batch 400/640 | kl_divergence: 14.5350 | pixelwise_bce: 8663.8135 | Cost: 8678.3486
# Epoch: 022/1000 | Batch 440/640 | kl_divergence: 34.5254 | pixelwise_bce: 8482.2207 | Cost: 8516.7461
# Epoch: 022/1000 | Batch 480/640 | kl_divergence: 20.4197 | pixelwise_bce: 8585.2480 | Cost: 8605.6680
# Epoch: 022/1000 | Batch 520/640 | kl_divergence: 19.0984 | pixelwise_bce: 8616.4180 | Cost: 8635.5166
# Epoch: 022/1000 | Batch 560/640 | kl_divergence: 19.3777 | pixelwise_bce: 8594.8057 | Cost: 8614.1836
# Epoch: 022/1000 | Batch 600/640 | kl_divergence: 19.4234 | pixelwise_bce: 8601.8447 | Cost: 8621.2686
# Time elapsed: 2.01 min
# Epoch: 023/1000 | Batch 000/640 | kl_divergence: 25.3141 | pixelwise_bce: 8539.2480 | Cost: 8564.5625
# Epoch: 023/1000 | Batch 040/640 | kl_divergence: 20.6850 | pixelwise_bce: 8601.5518 | Cost: 8622.2363
# Epoch: 023/1000 | Batch 080/640 | kl_divergence: 21.6734 | pixelwise_bce: 8569.4336 | Cost: 8591.1074
# Epoch: 023/1000 | Batch 120/640 | kl_divergence: 26.3978 | pixelwise_bce: 8503.2041 | Cost: 8529.6016
# Epoch: 023/1000 | Batch 160/640 | kl_divergence: 19.1078 | pixelwise_bce: 8581.4639 | Cost: 8600.5713
# Epoch: 023/1000 | Batch 200/640 | kl_divergence: 19.9467 | pixelwise_bce: 8632.0645 | Cost: 8652.0107
# Epoch: 023/1000 | Batch 240/640 | kl_divergence: 20.4757 | pixelwise_bce: 8629.9004 | Cost: 8650.3760
# Epoch: 023/1000 | Batch 280/640 | kl_divergence: 17.6763 | pixelwise_bce: 8641.9023 | Cost: 8659.5791
# Epoch: 023/1000 | Batch 320/640 | kl_divergence: 22.6272 | pixelwise_bce: 8475.0137 | Cost: 8497.6406
# Epoch: 023/1000 | Batch 360/640 | kl_divergence: 18.4519 | pixelwise_bce: 8598.2363 | Cost: 8616.6885
# Epoch: 023/1000 | Batch 400/640 | kl_divergence: 15.9121 | pixelwise_bce: 8654.1562 | Cost: 8670.0684
# Epoch: 023/1000 | Batch 440/640 | kl_divergence: 27.4492 | pixelwise_bce: 8465.4160 | Cost: 8492.8652
# Epoch: 023/1000 | Batch 480/640 | kl_divergence: 19.4332 | pixelwise_bce: 8587.0693 | Cost: 8606.5029
# Epoch: 023/1000 | Batch 520/640 | kl_divergence: 17.1235 | pixelwise_bce: 8614.2188 | Cost: 8631.3418
# Epoch: 023/1000 | Batch 560/640 | kl_divergence: 18.6173 | pixelwise_bce: 8602.7461 | Cost: 8621.3633
# Epoch: 023/1000 | Batch 600/640 | kl_divergence: 20.1537 | pixelwise_bce: 8585.6826 | Cost: 8605.8359
# Time elapsed: 2.10 min
# Epoch: 024/1000 | Batch 000/640 | kl_divergence: 22.2810 | pixelwise_bce: 8525.8535 | Cost: 8548.1348
# Epoch: 024/1000 | Batch 040/640 | kl_divergence: 19.2897 | pixelwise_bce: 8600.6611 | Cost: 8619.9512
# Epoch: 024/1000 | Batch 080/640 | kl_divergence: 18.0593 | pixelwise_bce: 8569.2129 | Cost: 8587.2725
# Epoch: 024/1000 | Batch 120/640 | kl_divergence: 25.5288 | pixelwise_bce: 8495.2842 | Cost: 8520.8125
# Epoch: 024/1000 | Batch 160/640 | kl_divergence: 20.0958 | pixelwise_bce: 8567.3936 | Cost: 8587.4893
# Epoch: 024/1000 | Batch 200/640 | kl_divergence: 17.1318 | pixelwise_bce: 8631.9648 | Cost: 8649.0967
# Epoch: 024/1000 | Batch 240/640 | kl_divergence: 18.7815 | pixelwise_bce: 8630.6416 | Cost: 8649.4229
# Epoch: 024/1000 | Batch 280/640 | kl_divergence: 17.1654 | pixelwise_bce: 8635.8516 | Cost: 8653.0166
# Epoch: 024/1000 | Batch 320/640 | kl_divergence: 28.1135 | pixelwise_bce: 8480.0537 | Cost: 8508.1670
# Epoch: 024/1000 | Batch 360/640 | kl_divergence: 19.8922 | pixelwise_bce: 8609.4277 | Cost: 8629.3203
# Epoch: 024/1000 | Batch 400/640 | kl_divergence: 15.7080 | pixelwise_bce: 8654.1611 | Cost: 8669.8691
# Epoch: 024/1000 | Batch 440/640 | kl_divergence: 26.5491 | pixelwise_bce: 8469.4453 | Cost: 8495.9941
# Epoch: 024/1000 | Batch 480/640 | kl_divergence: 20.5013 | pixelwise_bce: 8595.9580 | Cost: 8616.4590
# Epoch: 024/1000 | Batch 520/640 | kl_divergence: 17.8631 | pixelwise_bce: 8617.1113 | Cost: 8634.9746
# Epoch: 024/1000 | Batch 560/640 | kl_divergence: 19.6499 | pixelwise_bce: 8602.3184 | Cost: 8621.9678
# Epoch: 024/1000 | Batch 600/640 | kl_divergence: 21.0134 | pixelwise_bce: 8586.7842 | Cost: 8607.7979
# Time elapsed: 2.19 min
# Epoch: 025/1000 | Batch 000/640 | kl_divergence: 24.8737 | pixelwise_bce: 8538.7852 | Cost: 8563.6592
# Epoch: 025/1000 | Batch 040/640 | kl_divergence: 19.1781 | pixelwise_bce: 8601.0615 | Cost: 8620.2393
# Epoch: 025/1000 | Batch 080/640 | kl_divergence: 18.5821 | pixelwise_bce: 8575.5361 | Cost: 8594.1182
# Epoch: 025/1000 | Batch 120/640 | kl_divergence: 25.9627 | pixelwise_bce: 8485.0371 | Cost: 8511.0000
# Epoch: 025/1000 | Batch 160/640 | kl_divergence: 19.7453 | pixelwise_bce: 8569.7480 | Cost: 8589.4932
# Epoch: 025/1000 | Batch 200/640 | kl_divergence: 20.2188 | pixelwise_bce: 8626.0283 | Cost: 8646.2471
# Epoch: 025/1000 | Batch 240/640 | kl_divergence: 20.1648 | pixelwise_bce: 8620.9443 | Cost: 8641.1094
# Epoch: 025/1000 | Batch 280/640 | kl_divergence: 18.6497 | pixelwise_bce: 8635.2979 | Cost: 8653.9473
# Epoch: 025/1000 | Batch 320/640 | kl_divergence: 23.4969 | pixelwise_bce: 8477.0645 | Cost: 8500.5615
# Epoch: 025/1000 | Batch 360/640 | kl_divergence: 19.1109 | pixelwise_bce: 8598.6494 | Cost: 8617.7607
# Epoch: 025/1000 | Batch 400/640 | kl_divergence: 16.4964 | pixelwise_bce: 8649.3887 | Cost: 8665.8848
# Epoch: 025/1000 | Batch 440/640 | kl_divergence: 26.5548 | pixelwise_bce: 8476.9141 | Cost: 8503.4688
# Epoch: 025/1000 | Batch 480/640 | kl_divergence: 21.1099 | pixelwise_bce: 8581.3984 | Cost: 8602.5088
# Epoch: 025/1000 | Batch 520/640 | kl_divergence: 17.8167 | pixelwise_bce: 8616.5312 | Cost: 8634.3477
# Epoch: 025/1000 | Batch 560/640 | kl_divergence: 20.1016 | pixelwise_bce: 8591.0879 | Cost: 8611.1895
# Epoch: 025/1000 | Batch 600/640 | kl_divergence: 21.7542 | pixelwise_bce: 8580.3457 | Cost: 8602.0996
# Time elapsed: 2.28 min
# Epoch: 026/1000 | Batch 000/640 | kl_divergence: 24.0750 | pixelwise_bce: 8517.6523 | Cost: 8541.7275
# Epoch: 026/1000 | Batch 040/640 | kl_divergence: 18.7694 | pixelwise_bce: 8590.7051 | Cost: 8609.4746
# Epoch: 026/1000 | Batch 080/640 | kl_divergence: 19.0648 | pixelwise_bce: 8570.8457 | Cost: 8589.9102
# Epoch: 026/1000 | Batch 120/640 | kl_divergence: 24.1065 | pixelwise_bce: 8495.5938 | Cost: 8519.7002
# Epoch: 026/1000 | Batch 160/640 | kl_divergence: 21.5401 | pixelwise_bce: 8565.3701 | Cost: 8586.9102
# Epoch: 026/1000 | Batch 200/640 | kl_divergence: 18.2836 | pixelwise_bce: 8631.4521 | Cost: 8649.7354
# Epoch: 026/1000 | Batch 240/640 | kl_divergence: 18.7769 | pixelwise_bce: 8624.4844 | Cost: 8643.2617
# Epoch: 026/1000 | Batch 280/640 | kl_divergence: 19.5583 | pixelwise_bce: 8624.9141 | Cost: 8644.4727
# Epoch: 026/1000 | Batch 320/640 | kl_divergence: 23.1823 | pixelwise_bce: 8469.5312 | Cost: 8492.7139
# Epoch: 026/1000 | Batch 360/640 | kl_divergence: 17.9097 | pixelwise_bce: 8594.3857 | Cost: 8612.2949
# Epoch: 026/1000 | Batch 400/640 | kl_divergence: 15.6199 | pixelwise_bce: 8655.8164 | Cost: 8671.4365
# Epoch: 026/1000 | Batch 440/640 | kl_divergence: 25.3917 | pixelwise_bce: 8480.3672 | Cost: 8505.7588
# Epoch: 026/1000 | Batch 480/640 | kl_divergence: 20.5314 | pixelwise_bce: 8571.8262 | Cost: 8592.3574
# Epoch: 026/1000 | Batch 520/640 | kl_divergence: 19.0984 | pixelwise_bce: 8617.3945 | Cost: 8636.4932
# Epoch: 026/1000 | Batch 560/640 | kl_divergence: 19.4878 | pixelwise_bce: 8591.2549 | Cost: 8610.7432
# Epoch: 026/1000 | Batch 600/640 | kl_divergence: 20.9237 | pixelwise_bce: 8578.0332 | Cost: 8598.9570
# Time elapsed: 2.38 min
# Epoch: 027/1000 | Batch 000/640 | kl_divergence: 24.7072 | pixelwise_bce: 8517.1895 | Cost: 8541.8965
# Epoch: 027/1000 | Batch 040/640 | kl_divergence: 18.5829 | pixelwise_bce: 8594.4082 | Cost: 8612.9912
# Epoch: 027/1000 | Batch 080/640 | kl_divergence: 19.8041 | pixelwise_bce: 8569.6221 | Cost: 8589.4258
# Epoch: 027/1000 | Batch 120/640 | kl_divergence: 24.1646 | pixelwise_bce: 8486.7988 | Cost: 8510.9639
# Epoch: 027/1000 | Batch 160/640 | kl_divergence: 20.7306 | pixelwise_bce: 8567.2148 | Cost: 8587.9453
# Epoch: 027/1000 | Batch 200/640 | kl_divergence: 19.2762 | pixelwise_bce: 8630.9688 | Cost: 8650.2451
# Epoch: 027/1000 | Batch 240/640 | kl_divergence: 19.9047 | pixelwise_bce: 8622.3037 | Cost: 8642.2080
# Epoch: 027/1000 | Batch 280/640 | kl_divergence: 19.0828 | pixelwise_bce: 8627.8242 | Cost: 8646.9072
# Epoch: 027/1000 | Batch 320/640 | kl_divergence: 22.9547 | pixelwise_bce: 8468.8594 | Cost: 8491.8145
# Epoch: 027/1000 | Batch 360/640 | kl_divergence: 18.8224 | pixelwise_bce: 8592.6631 | Cost: 8611.4854
# Epoch: 027/1000 | Batch 400/640 | kl_divergence: 17.0047 | pixelwise_bce: 8661.2637 | Cost: 8678.2686
# Epoch: 027/1000 | Batch 440/640 | kl_divergence: 27.8342 | pixelwise_bce: 8459.2344 | Cost: 8487.0684
# Epoch: 027/1000 | Batch 480/640 | kl_divergence: 21.8257 | pixelwise_bce: 8578.4160 | Cost: 8600.2422
# Epoch: 027/1000 | Batch 520/640 | kl_divergence: 19.0641 | pixelwise_bce: 8615.8818 | Cost: 8634.9463
# Epoch: 027/1000 | Batch 560/640 | kl_divergence: 19.2431 | pixelwise_bce: 8603.3203 | Cost: 8622.5635
# Epoch: 027/1000 | Batch 600/640 | kl_divergence: 21.8309 | pixelwise_bce: 8579.8418 | Cost: 8601.6729
# Time elapsed: 2.47 min
# Epoch: 028/1000 | Batch 000/640 | kl_divergence: 22.9895 | pixelwise_bce: 8519.9238 | Cost: 8542.9131
# Epoch: 028/1000 | Batch 040/640 | kl_divergence: 19.0635 | pixelwise_bce: 8602.0000 | Cost: 8621.0635
# Epoch: 028/1000 | Batch 080/640 | kl_divergence: 19.2846 | pixelwise_bce: 8572.7676 | Cost: 8592.0518
# Epoch: 028/1000 | Batch 120/640 | kl_divergence: 25.8267 | pixelwise_bce: 8487.2607 | Cost: 8513.0879
# Epoch: 028/1000 | Batch 160/640 | kl_divergence: 19.8961 | pixelwise_bce: 8567.7930 | Cost: 8587.6895
# Epoch: 028/1000 | Batch 200/640 | kl_divergence: 17.8585 | pixelwise_bce: 8632.0059 | Cost: 8649.8643
# Epoch: 028/1000 | Batch 240/640 | kl_divergence: 19.5251 | pixelwise_bce: 8621.7305 | Cost: 8641.2559
# Epoch: 028/1000 | Batch 280/640 | kl_divergence: 18.5609 | pixelwise_bce: 8629.4570 | Cost: 8648.0176
# Epoch: 028/1000 | Batch 320/640 | kl_divergence: 25.3955 | pixelwise_bce: 8484.1201 | Cost: 8509.5156
# Epoch: 028/1000 | Batch 360/640 | kl_divergence: 18.0164 | pixelwise_bce: 8592.6191 | Cost: 8610.6357
# Epoch: 028/1000 | Batch 400/640 | kl_divergence: 15.7686 | pixelwise_bce: 8651.2764 | Cost: 8667.0449
# Epoch: 028/1000 | Batch 440/640 | kl_divergence: 24.5861 | pixelwise_bce: 8471.3682 | Cost: 8495.9541
# Epoch: 028/1000 | Batch 480/640 | kl_divergence: 20.4754 | pixelwise_bce: 8592.6475 | Cost: 8613.1230
# Epoch: 028/1000 | Batch 520/640 | kl_divergence: 18.4351 | pixelwise_bce: 8627.9570 | Cost: 8646.3926
# Epoch: 028/1000 | Batch 560/640 | kl_divergence: 18.5659 | pixelwise_bce: 8591.8574 | Cost: 8610.4238
# Epoch: 028/1000 | Batch 600/640 | kl_divergence: 20.2316 | pixelwise_bce: 8579.6064 | Cost: 8599.8379
# Time elapsed: 2.56 min
# Epoch: 029/1000 | Batch 000/640 | kl_divergence: 23.8718 | pixelwise_bce: 8521.1875 | Cost: 8545.0596
# Epoch: 029/1000 | Batch 040/640 | kl_divergence: 18.8143 | pixelwise_bce: 8595.6963 | Cost: 8614.5107
# Epoch: 029/1000 | Batch 080/640 | kl_divergence: 20.6596 | pixelwise_bce: 8570.6797 | Cost: 8591.3389
# Epoch: 029/1000 | Batch 120/640 | kl_divergence: 25.5026 | pixelwise_bce: 8503.1641 | Cost: 8528.6670
# Epoch: 029/1000 | Batch 160/640 | kl_divergence: 19.1174 | pixelwise_bce: 8567.4541 | Cost: 8586.5713
# Epoch: 029/1000 | Batch 200/640 | kl_divergence: 19.2071 | pixelwise_bce: 8625.9336 | Cost: 8645.1406
# Epoch: 029/1000 | Batch 240/640 | kl_divergence: 21.6620 | pixelwise_bce: 8624.6172 | Cost: 8646.2793
# Epoch: 029/1000 | Batch 280/640 | kl_divergence: 19.5172 | pixelwise_bce: 8627.2881 | Cost: 8646.8057
# Epoch: 029/1000 | Batch 320/640 | kl_divergence: 24.3745 | pixelwise_bce: 8469.3975 | Cost: 8493.7725
# Epoch: 029/1000 | Batch 360/640 | kl_divergence: 19.2521 | pixelwise_bce: 8590.6738 | Cost: 8609.9258
# Epoch: 029/1000 | Batch 400/640 | kl_divergence: 17.7531 | pixelwise_bce: 8650.2500 | Cost: 8668.0029
# Epoch: 029/1000 | Batch 440/640 | kl_divergence: 28.0684 | pixelwise_bce: 8464.8906 | Cost: 8492.9590
# Epoch: 029/1000 | Batch 480/640 | kl_divergence: 21.5440 | pixelwise_bce: 8588.3975 | Cost: 8609.9414
# Epoch: 029/1000 | Batch 520/640 | kl_divergence: 19.2295 | pixelwise_bce: 8614.0986 | Cost: 8633.3281
# Epoch: 029/1000 | Batch 560/640 | kl_divergence: 20.0153 | pixelwise_bce: 8587.9141 | Cost: 8607.9297
# ...
# Epoch: 190/1000 | Batch 200/640 | kl_divergence: 22.9655 | pixelwise_bce: 8622.5801 | Cost: 8645.5459
# Epoch: 190/1000 | Batch 240/640 | kl_divergence: 21.8441 | pixelwise_bce: 8618.4326 | Cost: 8640.2764
# Epoch: 190/1000 | Batch 280/640 | kl_divergence: 21.0476 | pixelwise_bce: 8627.0000 | Cost: 8648.0479
# Epoch: 190/1000 | Batch 320/640 | kl_divergence: 25.9700 | pixelwise_bce: 8468.5723 | Cost: 8494.5420
# Epoch: 190/1000 | Batch 360/640 | kl_divergence: 21.8956 | pixelwise_bce: 8585.6699 | Cost: 8607.5654
# Epoch: 190/1000 | Batch 400/640 | kl_divergence: 19.7733 | pixelwise_bce: 8666.9922 | Cost: 8686.7656
# Epoch: 190/1000 | Batch 440/640 | kl_divergence: 27.3822 | pixelwise_bce: 8465.6465 | Cost: 8493.0283
# Epoch: 190/1000 | Batch 480/640 | kl_divergence: 23.9160 | pixelwise_bce: 8579.0322 | Cost: 8602.9482
# Epoch: 190/1000 | Batch 520/640 | kl_divergence: 21.6048 | pixelwise_bce: 8616.4326 | Cost: 8638.0371
# Epoch: 190/1000 | Batch 560/640 | kl_divergence: 22.4859 | pixelwise_bce: 8581.1289 | Cost: 8603.6152
# Epoch: 190/1000 | Batch 600/640 | kl_divergence: 25.2788 | pixelwise_bce: 8581.6162 | Cost: 8606.8955
# Time elapsed: 17.40 min
# Epoch: 191/1000 | Batch 000/640 | kl_divergence: 24.9590 | pixelwise_bce: 8533.4609 | Cost: 8558.4199
# Epoch: 191/1000 | Batch 040/640 | kl_divergence: 21.5707 | pixelwise_bce: 8597.8115 | Cost: 8619.3818
# Epoch: 191/1000 | Batch 080/640 | kl_divergence: 22.2794 | pixelwise_bce: 8559.8809 | Cost: 8582.1602
# Epoch: 191/1000 | Batch 120/640 | kl_divergence: 25.8240 | pixelwise_bce: 8489.5625 | Cost: 8515.3867
# Epoch: 191/1000 | Batch 160/640 | kl_divergence: 24.6216 | pixelwise_bce: 8551.2002 | Cost: 8575.8213
# Epoch: 191/1000 | Batch 200/640 | kl_divergence: 23.8426 | pixelwise_bce: 8628.0293 | Cost: 8651.8721
# Epoch: 191/1000 | Batch 240/640 | kl_divergence: 24.6877 | pixelwise_bce: 8631.9697 | Cost: 8656.6572
# Epoch: 191/1000 | Batch 280/640 | kl_divergence: 21.2044 | pixelwise_bce: 8623.2246 | Cost: 8644.4287
# Epoch: 191/1000 | Batch 320/640 | kl_divergence: 26.3103 | pixelwise_bce: 8465.9893 | Cost: 8492.2998
# Epoch: 191/1000 | Batch 360/640 | kl_divergence: 22.7159 | pixelwise_bce: 8588.3447 | Cost: 8611.0605
# Epoch: 191/1000 | Batch 400/640 | kl_divergence: 18.5384 | pixelwise_bce: 8655.3135 | Cost: 8673.8516
# Epoch: 191/1000 | Batch 440/640 | kl_divergence: 26.1242 | pixelwise_bce: 8456.6992 | Cost: 8482.8232
# Epoch: 191/1000 | Batch 480/640 | kl_divergence: 23.4737 | pixelwise_bce: 8572.4170 | Cost: 8595.8906
# Epoch: 191/1000 | Batch 520/640 | kl_divergence: 21.5484 | pixelwise_bce: 8614.2861 | Cost: 8635.8350
# Epoch: 191/1000 | Batch 560/640 | kl_divergence: 22.6016 | pixelwise_bce: 8580.3818 | Cost: 8602.9834
# Epoch: 191/1000 | Batch 600/640 | kl_divergence: 24.4086 | pixelwise_bce: 8582.5488 | Cost: 8606.9570
# Time elapsed: 17.49 min
# Epoch: 192/1000 | Batch 000/640 | kl_divergence: 26.4860 | pixelwise_bce: 8527.5557 | Cost: 8554.0420
# Epoch: 192/1000 | Batch 040/640 | kl_divergence: 21.1383 | pixelwise_bce: 8591.1797 | Cost: 8612.3184
# Epoch: 192/1000 | Batch 080/640 | kl_divergence: 22.4900 | pixelwise_bce: 8568.4629 | Cost: 8590.9531
# Epoch: 192/1000 | Batch 120/640 | kl_divergence: 26.8109 | pixelwise_bce: 8482.0283 | Cost: 8508.8389
# Epoch: 192/1000 | Batch 160/640 | kl_divergence: 24.1823 | pixelwise_bce: 8557.3135 | Cost: 8581.4961
# Epoch: 192/1000 | Batch 200/640 | kl_divergence: 23.8656 | pixelwise_bce: 8622.8906 | Cost: 8646.7559
# Epoch: 192/1000 | Batch 240/640 | kl_divergence: 24.4932 | pixelwise_bce: 8615.5645 | Cost: 8640.0576
# Epoch: 192/1000 | Batch 280/640 | kl_divergence: 22.4995 | pixelwise_bce: 8620.2676 | Cost: 8642.7666
# Epoch: 192/1000 | Batch 320/640 | kl_divergence: 26.4038 | pixelwise_bce: 8474.7354 | Cost: 8501.1387
# Epoch: 192/1000 | Batch 360/640 | kl_divergence: 23.5458 | pixelwise_bce: 8586.2549 | Cost: 8609.8008
# Epoch: 192/1000 | Batch 400/640 | kl_divergence: 17.6556 | pixelwise_bce: 8652.6465 | Cost: 8670.3018
# Epoch: 192/1000 | Batch 440/640 | kl_divergence: 27.3634 | pixelwise_bce: 8459.1641 | Cost: 8486.5273
# Epoch: 192/1000 | Batch 480/640 | kl_divergence: 23.3505 | pixelwise_bce: 8584.0430 | Cost: 8607.3936
# Epoch: 192/1000 | Batch 520/640 | kl_divergence: 21.5376 | pixelwise_bce: 8610.4902 | Cost: 8632.0283
# Epoch: 192/1000 | Batch 560/640 | kl_divergence: 22.2095 | pixelwise_bce: 8585.1104 | Cost: 8607.3203
# Epoch: 192/1000 | Batch 600/640 | kl_divergence: 22.9429 | pixelwise_bce: 8588.8936 | Cost: 8611.8369
# Time elapsed: 17.58 min
# Epoch: 193/1000 | Batch 000/640 | kl_divergence: 24.0380 | pixelwise_bce: 8524.8887 | Cost: 8548.9268
# Epoch: 193/1000 | Batch 040/640 | kl_divergence: 20.6566 | pixelwise_bce: 8597.1504 | Cost: 8617.8066
# Epoch: 193/1000 | Batch 080/640 | kl_divergence: 22.3852 | pixelwise_bce: 8558.1865 | Cost: 8580.5713
# Epoch: 193/1000 | Batch 120/640 | kl_divergence: 26.3727 | pixelwise_bce: 8481.5801 | Cost: 8507.9531
# Epoch: 193/1000 | Batch 160/640 | kl_divergence: 24.9744 | pixelwise_bce: 8550.9199 | Cost: 8575.8945
# Epoch: 193/1000 | Batch 200/640 | kl_divergence: 26.2282 | pixelwise_bce: 8624.0498 | Cost: 8650.2783
# Epoch: 193/1000 | Batch 240/640 | kl_divergence: 23.6080 | pixelwise_bce: 8614.6240 | Cost: 8638.2324
# Epoch: 193/1000 | Batch 280/640 | kl_divergence: 20.5891 | pixelwise_bce: 8621.8789 | Cost: 8642.4678
# Epoch: 193/1000 | Batch 320/640 | kl_divergence: 26.0930 | pixelwise_bce: 8473.5869 | Cost: 8499.6797
# Epoch: 193/1000 | Batch 360/640 | kl_divergence: 22.8185 | pixelwise_bce: 8582.6934 | Cost: 8605.5117
# Epoch: 193/1000 | Batch 400/640 | kl_divergence: 18.7902 | pixelwise_bce: 8650.1670 | Cost: 8668.9570
# Epoch: 193/1000 | Batch 440/640 | kl_divergence: 28.2683 | pixelwise_bce: 8459.1367 | Cost: 8487.4053
# Epoch: 193/1000 | Batch 480/640 | kl_divergence: 23.9213 | pixelwise_bce: 8571.9434 | Cost: 8595.8643
# Epoch: 193/1000 | Batch 520/640 | kl_divergence: 21.2642 | pixelwise_bce: 8608.4316 | Cost: 8629.6963
# Epoch: 193/1000 | Batch 560/640 | kl_divergence: 24.1722 | pixelwise_bce: 8579.8691 | Cost: 8604.0410
# Epoch: 193/1000 | Batch 600/640 | kl_divergence: 24.0263 | pixelwise_bce: 8578.6152 | Cost: 8602.6416
# Time elapsed: 17.67 min
# Epoch: 194/1000 | Batch 000/640 | kl_divergence: 26.0884 | pixelwise_bce: 8512.4971 | Cost: 8538.5859
# Epoch: 194/1000 | Batch 040/640 | kl_divergence: 21.0762 | pixelwise_bce: 8590.6670 | Cost: 8611.7432
# Epoch: 194/1000 | Batch 080/640 | kl_divergence: 23.6105 | pixelwise_bce: 8559.4355 | Cost: 8583.0459
# Epoch: 194/1000 | Batch 120/640 | kl_divergence: 26.1102 | pixelwise_bce: 8483.3252 | Cost: 8509.4355
# Epoch: 194/1000 | Batch 160/640 | kl_divergence: 23.7961 | pixelwise_bce: 8558.8545 | Cost: 8582.6504
# Epoch: 194/1000 | Batch 200/640 | kl_divergence: 22.4034 | pixelwise_bce: 8626.7715 | Cost: 8649.1748
# Epoch: 194/1000 | Batch 240/640 | kl_divergence: 22.0791 | pixelwise_bce: 8618.0332 | Cost: 8640.1123
# Epoch: 194/1000 | Batch 280/640 | kl_divergence: 20.6486 | pixelwise_bce: 8630.0898 | Cost: 8650.7383
# Epoch: 194/1000 | Batch 320/640 | kl_divergence: 26.0864 | pixelwise_bce: 8469.7812 | Cost: 8495.8672
# Epoch: 194/1000 | Batch 360/640 | kl_divergence: 21.8635 | pixelwise_bce: 8585.1719 | Cost: 8607.0352
# Epoch: 194/1000 | Batch 400/640 | kl_divergence: 18.9566 | pixelwise_bce: 8651.2148 | Cost: 8670.1719
# Epoch: 194/1000 | Batch 440/640 | kl_divergence: 26.6343 | pixelwise_bce: 8452.1494 | Cost: 8478.7842
# Epoch: 194/1000 | Batch 480/640 | kl_divergence: 22.4243 | pixelwise_bce: 8565.6152 | Cost: 8588.0391
# Epoch: 194/1000 | Batch 520/640 | kl_divergence: 20.6492 | pixelwise_bce: 8615.9385 | Cost: 8636.5879
# Epoch: 194/1000 | Batch 560/640 | kl_divergence: 22.7212 | pixelwise_bce: 8587.3555 | Cost: 8610.0762
# Epoch: 194/1000 | Batch 600/640 | kl_divergence: 24.4313 | pixelwise_bce: 8570.5615 | Cost: 8594.9932
# Time elapsed: 17.77 min
# Epoch: 195/1000 | Batch 000/640 | kl_divergence: 27.2352 | pixelwise_bce: 8518.1240 | Cost: 8545.3594
# Epoch: 195/1000 | Batch 040/640 | kl_divergence: 23.4482 | pixelwise_bce: 8587.3398 | Cost: 8610.7881
# Epoch: 195/1000 | Batch 080/640 | kl_divergence: 20.2476 | pixelwise_bce: 8568.9697 | Cost: 8589.2178
# Epoch: 195/1000 | Batch 120/640 | kl_divergence: 26.6874 | pixelwise_bce: 8487.5840 | Cost: 8514.2715
# Epoch: 195/1000 | Batch 160/640 | kl_divergence: 23.6983 | pixelwise_bce: 8557.5420 | Cost: 8581.2402
# Epoch: 195/1000 | Batch 200/640 | kl_divergence: 24.4965 | pixelwise_bce: 8618.9014 | Cost: 8643.3975
# Epoch: 195/1000 | Batch 240/640 | kl_divergence: 24.6387 | pixelwise_bce: 8628.2666 | Cost: 8652.9053
# Epoch: 195/1000 | Batch 280/640 | kl_divergence: 19.8854 | pixelwise_bce: 8630.6953 | Cost: 8650.5811
# Epoch: 195/1000 | Batch 320/640 | kl_divergence: 25.8392 | pixelwise_bce: 8469.5078 | Cost: 8495.3467
# Epoch: 195/1000 | Batch 360/640 | kl_divergence: 21.5418 | pixelwise_bce: 8584.4102 | Cost: 8605.9521
# Epoch: 195/1000 | Batch 400/640 | kl_divergence: 19.1695 | pixelwise_bce: 8647.7637 | Cost: 8666.9336
# Epoch: 195/1000 | Batch 440/640 | kl_divergence: 31.4818 | pixelwise_bce: 8466.1182 | Cost: 8497.5996
# Epoch: 195/1000 | Batch 480/640 | kl_divergence: 25.7548 | pixelwise_bce: 8572.7285 | Cost: 8598.4834
# Epoch: 195/1000 | Batch 520/640 | kl_divergence: 21.4329 | pixelwise_bce: 8620.9775 | Cost: 8642.4102
# Epoch: 195/1000 | Batch 560/640 | kl_divergence: 24.1261 | pixelwise_bce: 8584.0586 | Cost: 8608.1846
# Epoch: 195/1000 | Batch 600/640 | kl_divergence: 27.0005 | pixelwise_bce: 8572.3066 | Cost: 8599.3076
# Time elapsed: 17.86 min
# Epoch: 196/1000 | Batch 000/640 | kl_divergence: 26.1434 | pixelwise_bce: 8518.8418 | Cost: 8544.9854
# Epoch: 196/1000 | Batch 040/640 | kl_divergence: 21.5960 | pixelwise_bce: 8594.1416 | Cost: 8615.7373
# Epoch: 196/1000 | Batch 080/640 | kl_divergence: 20.7834 | pixelwise_bce: 8562.9961 | Cost: 8583.7793
# Epoch: 196/1000 | Batch 120/640 | kl_divergence: 29.1666 | pixelwise_bce: 8480.8125 | Cost: 8509.9795
# Epoch: 196/1000 | Batch 160/640 | kl_divergence: 25.4464 | pixelwise_bce: 8561.3936 | Cost: 8586.8398
# Epoch: 196/1000 | Batch 200/640 | kl_divergence: 24.8397 | pixelwise_bce: 8617.1016 | Cost: 8641.9414
# Epoch: 196/1000 | Batch 240/640 | kl_divergence: 25.9987 | pixelwise_bce: 8622.0000 | Cost: 8647.9990
# Epoch: 196/1000 | Batch 280/640 | kl_divergence: 21.2643 | pixelwise_bce: 8624.0938 | Cost: 8645.3584
# Epoch: 196/1000 | Batch 320/640 | kl_divergence: 26.8114 | pixelwise_bce: 8465.8730 | Cost: 8492.6846
# Epoch: 196/1000 | Batch 360/640 | kl_divergence: 23.4193 | pixelwise_bce: 8591.8789 | Cost: 8615.2979
# Epoch: 196/1000 | Batch 400/640 | kl_divergence: 20.2046 | pixelwise_bce: 8646.9365 | Cost: 8667.1416
# Epoch: 196/1000 | Batch 440/640 | kl_divergence: 28.2639 | pixelwise_bce: 8470.6943 | Cost: 8498.9580
# Epoch: 196/1000 | Batch 480/640 | kl_divergence: 24.1341 | pixelwise_bce: 8567.9141 | Cost: 8592.0479
# Epoch: 196/1000 | Batch 520/640 | kl_divergence: 21.1209 | pixelwise_bce: 8609.6592 | Cost: 8630.7803
# Epoch: 196/1000 | Batch 560/640 | kl_divergence: 24.4471 | pixelwise_bce: 8575.1377 | Cost: 8599.5850
# Epoch: 196/1000 | Batch 600/640 | kl_divergence: 26.1694 | pixelwise_bce: 8567.1641 | Cost: 8593.3330
# Time elapsed: 17.95 min
# Epoch: 197/1000 | Batch 000/640 | kl_divergence: 26.9517 | pixelwise_bce: 8511.9297 | Cost: 8538.8818
# Epoch: 197/1000 | Batch 040/640 | kl_divergence: 22.4725 | pixelwise_bce: 8592.6865 | Cost: 8615.1592
# Epoch: 197/1000 | Batch 080/640 | kl_divergence: 21.2939 | pixelwise_bce: 8559.9150 | Cost: 8581.2090
# Epoch: 197/1000 | Batch 120/640 | kl_divergence: 26.7835 | pixelwise_bce: 8482.3945 | Cost: 8509.1777
# Epoch: 197/1000 | Batch 160/640 | kl_divergence: 24.6932 | pixelwise_bce: 8552.9277 | Cost: 8577.6211
# Epoch: 197/1000 | Batch 200/640 | kl_divergence: 22.1374 | pixelwise_bce: 8616.5068 | Cost: 8638.6445
# Epoch: 197/1000 | Batch 240/640 | kl_divergence: 24.7636 | pixelwise_bce: 8609.0059 | Cost: 8633.7695
# Epoch: 197/1000 | Batch 280/640 | kl_divergence: 21.9944 | pixelwise_bce: 8625.1016 | Cost: 8647.0957
# Epoch: 197/1000 | Batch 320/640 | kl_divergence: 26.8922 | pixelwise_bce: 8471.0732 | Cost: 8497.9658
# Epoch: 197/1000 | Batch 360/640 | kl_divergence: 23.2053 | pixelwise_bce: 8586.2197 | Cost: 8609.4248
# Epoch: 197/1000 | Batch 400/640 | kl_divergence: 19.4886 | pixelwise_bce: 8645.5996 | Cost: 8665.0879
# Epoch: 197/1000 | Batch 440/640 | kl_divergence: 29.0761 | pixelwise_bce: 8445.5713 | Cost: 8474.6475
# Epoch: 197/1000 | Batch 480/640 | kl_divergence: 24.0115 | pixelwise_bce: 8569.1094 | Cost: 8593.1211
# Epoch: 197/1000 | Batch 520/640 | kl_divergence: 21.2832 | pixelwise_bce: 8604.7715 | Cost: 8626.0547
# Epoch: 197/1000 | Batch 560/640 | kl_divergence: 23.0469 | pixelwise_bce: 8590.7891 | Cost: 8613.8359
# Epoch: 197/1000 | Batch 600/640 | kl_divergence: 27.4948 | pixelwise_bce: 8572.7832 | Cost: 8600.2783
# Time elapsed: 18.04 min
# Epoch: 198/1000 | Batch 000/640 | kl_divergence: 27.6908 | pixelwise_bce: 8505.2998 | Cost: 8532.9902
# Epoch: 198/1000 | Batch 040/640 | kl_divergence: 23.0918 | pixelwise_bce: 8590.0410 | Cost: 8613.1328
# Epoch: 198/1000 | Batch 080/640 | kl_divergence: 21.4071 | pixelwise_bce: 8577.0762 | Cost: 8598.4834
# Epoch: 198/1000 | Batch 120/640 | kl_divergence: 28.4780 | pixelwise_bce: 8487.0996 | Cost: 8515.5781
# Epoch: 198/1000 | Batch 160/640 | kl_divergence: 25.9550 | pixelwise_bce: 8557.5576 | Cost: 8583.5127
# Epoch: 198/1000 | Batch 200/640 | kl_divergence: 24.8902 | pixelwise_bce: 8621.2969 | Cost: 8646.1875
# Epoch: 198/1000 | Batch 240/640 | kl_divergence: 23.9765 | pixelwise_bce: 8616.7500 | Cost: 8640.7266
# Epoch: 198/1000 | Batch 280/640 | kl_divergence: 21.8813 | pixelwise_bce: 8622.6211 | Cost: 8644.5020
# Epoch: 198/1000 | Batch 320/640 | kl_divergence: 26.7367 | pixelwise_bce: 8463.3027 | Cost: 8490.0391
# Epoch: 198/1000 | Batch 360/640 | kl_divergence: 22.3635 | pixelwise_bce: 8590.8926 | Cost: 8613.2559
# Epoch: 198/1000 | Batch 400/640 | kl_divergence: 22.7753 | pixelwise_bce: 8650.0137 | Cost: 8672.7891
# Epoch: 198/1000 | Batch 440/640 | kl_divergence: 28.3810 | pixelwise_bce: 8455.9893 | Cost: 8484.3701
# Epoch: 198/1000 | Batch 480/640 | kl_divergence: 24.0706 | pixelwise_bce: 8567.9385 | Cost: 8592.0088
# Epoch: 198/1000 | Batch 520/640 | kl_divergence: 20.5546 | pixelwise_bce: 8610.8428 | Cost: 8631.3975
# Epoch: 198/1000 | Batch 560/640 | kl_divergence: 22.8369 | pixelwise_bce: 8582.1182 | Cost: 8604.9551
# Epoch: 198/1000 | Batch 600/640 | kl_divergence: 27.9134 | pixelwise_bce: 8569.7070 | Cost: 8597.6201
# Time elapsed: 18.13 min
# Epoch: 199/1000 | Batch 000/640 | kl_divergence: 26.9535 | pixelwise_bce: 8521.2773 | Cost: 8548.2305
# Epoch: 199/1000 | Batch 040/640 | kl_divergence: 21.4002 | pixelwise_bce: 8590.6748 | Cost: 8612.0752
# Epoch: 199/1000 | Batch 080/640 | kl_divergence: 22.3160 | pixelwise_bce: 8577.0811 | Cost: 8599.3975
# Epoch: 199/1000 | Batch 120/640 | kl_divergence: 26.1566 | pixelwise_bce: 8480.9082 | Cost: 8507.0645
# Epoch: 199/1000 | Batch 160/640 | kl_divergence: 25.6987 | pixelwise_bce: 8564.2246 | Cost: 8589.9229
# Epoch: 199/1000 | Batch 200/640 | kl_divergence: 24.9126 | pixelwise_bce: 8613.1514 | Cost: 8638.0645
# Epoch: 199/1000 | Batch 240/640 | kl_divergence: 27.4216 | pixelwise_bce: 8619.3506 | Cost: 8646.7725
# Epoch: 199/1000 | Batch 280/640 | kl_divergence: 21.1003 | pixelwise_bce: 8627.2656 | Cost: 8648.3662
# Epoch: 199/1000 | Batch 320/640 | kl_divergence: 27.8471 | pixelwise_bce: 8458.4365 | Cost: 8486.2832
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-cb4a11d77f83> in <module>
#      31
#      32         ### UPDATE MODEL PARAMETERS
# ---> 33         optimizer.step()
#      34
#      35         ### LOGGING
#
# /usr/local/lib/python3.5/dist-packages/torch/optim/adam.py in step(self, closure)
#      99                     denom = max_exp_avg_sq.sqrt().add_(group['eps'])
#     100                 else:
# --> 101                     denom = exp_avg_sq.sqrt().add_(group['eps'])
#     102
#     103                 bias_correction1 = 1 - beta1 ** state['step']
#
# KeyboardInterrupt:

# %%
state = {'net':model.state_dict(), 'optimizer':optimizer.state_dict(), 'epoch':epoch }
dir_name = 'model_lstm_' + str(epoch) + '.pth'
torch.save(state, dir_name)
print (dir_name)
print('done!------------------------------------------------------------------------------')
# Out:
# model_lstm_198.pth
# done!------------------------------------------------------------------------------

# %%
# infer 
Batch = 64
iters = 214 #13735/64 = 134
val_datas_process = data_in_one(val_data[:iters*Batch])
val_label = val_label[:iters*Batch]
z_runs = []
model.eval()
for batch_idx in range(iters):
    features_val = val_datas_process[batch_idx*Batch:(batch_idx+1)*Batch]
#    targets_val = val_label[batch_idx*Batch:(batch_idx+1)*Batch]
#    targets_val = np.transpose(targets_val)
    features_val = torch.from_numpy(features_val)
#    targets_val = torch.from_numpy(targets_val)
    features_val = features_val.to(device,torch.float32)
    features_val = features_val.view(-1,time_step,input_size)
    features_val = Variable(features_val)
#    targets_val = targets_val.to(device,dtype=torch.int64)

    ### infer
    z_mean, z_log_var, encoded, decoded = model(features_val)
    z_run = z_mean.to(torch.device('cpu'))
    z_run = z_run.detach().numpy()
    z_runs.append(z_run)

z_runs = np.array(z_runs)
z_runs = np.reshape(z_runs,(iters*Batch,num_latent))
np.shape(z_runs)
# Out:
# (13696, 256)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['savefig.dpi'] = 120
plt.rcParams['figure.dpi'] = 120

# from sklearn.manifold import TSNE
from sklearn.decomposition import TruncatedSVD

#z_run = z_mean.to(torch.device('cpu'))
#z_run = z_run.detach().numpy()
PCA_model = TruncatedSVD(n_components=3).fit(z_runs)
z_run_reduced = PCA_model.transform(z_runs)
print (np.shape(z_run_reduced))
#ground_truth = targets_val.to(torch.device('cpu'))
ground_truth = val_label[:Batch*iters]
for k in range(Batch*iters):
    if ground_truth[k] ==1:
#z_mean, z_log_var, encoded, decoded = model(features, targets)
        plot1 = plt.scatter(z_run_reduced[k, 0], z_run_reduced[k, 1], c='b', marker='*', linewidths=0)
    else:
        plot2 = plt.scatter(z_run_reduced[k, 0], z_run_reduced[k, 1], c='r', marker='o', linewidths=0)        
plt.legend([plot1, plot2],('normal','abnormal'), loc='best')
plt.title('PCA on z_run')
plt.grid()
plt.show()
# Out:
# (13696, 3)

# %%
# save latenct vecotor dim = 20
np.savetxt('z_runs_136966_256.txt',z_runs)
np.savetxt('ground_truth_13696.txt',ground_truth)

# %%
def data_to_real(inputdata):
    inputdata = inputdata * (inputdata.max()-inputdata.min()) + inputdata.min()
#    inputdata = 2.0 * inputdata - 1.0
    return inputdata

#features1 = features.view(-1,28*28)
input_data = features_val.to(torch.device('cpu'))
input_data = input_data.detach().numpy()
input_data = data_to_real(input_data)
print(np.shape(input_data))
input_data = np.reshape(input_data,(Batch,784))
input_data = input_data[:,:783]
de = model.decoder(encoded) # replace decoded by z_mean

decoded_data = de.to(torch.device('cpu'))
#decoded_data = decoded_data.view(-1,28*28)
decoded_data = decoded_data.detach().numpy()
decoded_data = data_to_real(decoded_data)
decoded_data = np.reshape(decoded_data,(Batch,784))
decoded_data = decoded_data[:,:783]
idxx = np.random.randint(0,64)
plt.plot(input_data[idxx],'b')
plt.plot(decoded_data[idxx],'r')
plt.grid()
plt.show()
# Out:
# (64, 1, 784)
